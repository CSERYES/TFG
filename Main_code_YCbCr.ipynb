# %% [markdown]
# ## Modulos necesarios

# %%
import numpy as np
  
from keras.models import Model
from keras.layers import *
from keras.optimizers import *
import keras.backend as K
from keras.callbacks import EarlyStopping
import keras.utils as image

import tensorflow as tf

import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.metrics import roc_curve, roc_auc_score, confusion_matrix 
from sklearn.model_selection import KFold

import os
from os import listdir

import natsort # it may need to be installed by 'pip install natsort'

import datetime
now = datetime.datetime.now
# Out:
# 2023-12-07 11:28:25.989439: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-07 11:28:26.026530: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-07 11:28:26.026554: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-07 11:28:26.027695: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-07 11:28:26.033566: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-07 11:28:26.034036: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-07 11:28:28.021929: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import numpy as np
from glob import glob

from tensorflow import keras
from tensorflow.keras.backend import max
from tensorflow.keras.metrics import BinaryAccuracy
import keras_unet_collection
from keras_unet_collection import models, base, utils
import cv2

# %%
import keras.backend as K

# %% [markdown]
# # Extracción de imágenes

# %%
# Introduce parameters
img_row = 128
img_col = 128
img_chan = 1
epochnum = 100
batchnum = 16 
num_imgs = 780
input_size = (img_row, img_col, img_chan)

# %%
path = r'images/'

images = []
masks = []


for f_name in os.listdir(path):
    file_name = os.path.join(path,f_name)
    for name in os.listdir(file_name):
        file = os.path.join(file_name,name)
            
        if 'lesion' in file:
            tmp_mask = image.load_img(os.path.join(file_name, name, name + ".bmp"), target_size=(img_row, img_col, img_chan))
            mask = image.img_to_array(tmp_mask)
            mask = cv2.cvtColor(mask, cv2.COLOR_RGB2YCrCb)
            masks.append(mask[:,:,0]/255.0) 

        elif "Dermoscopic" in file:
            tmp_img = image.load_img(os.path.join(file_name, name, f_name + ".bmp"), target_size=(img_row, img_col, img_chan))
            img = image.img_to_array(tmp_img)
            img = cv2.cvtColor(img, cv2.COLOR_RGB2YCrCb)
            images.append(img[:,:,0]/255.0)

# %%
plt.imshow(images[0])
plt.title("Image")
plt.show()

plt.imshow(masks[0])  
plt.title("Mask")
plt.show()

# %%
num_imgs = len(images)
print(num_imgs)
num_masks = len(masks)
print(num_masks)
imgs = np.zeros((num_imgs, img_row, img_col))
masks_ = np.zeros_like(imgs)

for i in range(num_imgs):
    imgs[i] = images[i]
    
for i in range(num_imgs):
    masks_[i] = masks[i]
# Out:
# 200
# 200

# %% [markdown]
# # Métricas de evaluación y entrenamiento (DICE)

# %%
# Define loss and performance metrics
# Partially from Abraham and Khan (2019) - A Novel Focal Tversly Loss Function for Lesion Segmentation

# Dice score coefficient and Dice loss 
def dsc(y_true, y_pred):
    smooth = 1.
    # masks
    y_true_fm = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_fm * y_pred_f)
    score = (2. * intersection + smooth) / (K.sum(y_true_fm) + K.sum(y_pred_f) + smooth) 
    return score

def dice_loss(y_true, y_pred):
    loss = 1 - dsc(y_true, y_pred)
    return loss

# Performance metrics: Dice score coefficient, IOU, recall, sensitivity
def auc(y_true, y_pred):
    y_pred_pos = np.round(np.clip(y_pred, 0, 1))
    y_pred_neg = 1 - y_pred_pos
    y_pos = np.round(np.clip(y_true, 0, 1)) # ground truth
    y_neg = 1 - y_pos
    tp = np.sum(y_pos * y_pred_pos)
    tn = np.sum(y_neg * y_pred_neg)
    fp = np.sum(y_neg * y_pred_pos)
    fn = np.sum(y_pos * y_pred_neg)
    tpr = (tp + K.epsilon()) / (tp + fn + K.epsilon()) #recall
    tnr = (tn + K.epsilon()) / (tn + fp + K.epsilon())
    prec = (tp + K.epsilon()) / (tp + fp + K.epsilon()) #precision
    iou = (tp + K.epsilon()) / (tp + fn + fp + K.epsilon()) #intersection over union
    dsc = (2*tp + K.epsilon()) / (2*tp + fn + fp + K.epsilon()) #dice score
    return [dsc, iou, tpr, prec]

# %% [markdown]
# ## Separación train y test

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(imgs, masks_, test_size=0.3, random_state = 0)
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size = 0.2, random_state = 0)

# %% [markdown]
# ## Representación de train y validación

# %%
def Representacion(history,epochnum, batchnum):
    print('Training time: %s' % (now() - t))

    #Plot the loss and accuracy
    train_loss = history.history['loss']
    val_loss = history.history['val_loss']
    acc = history.history['dsc'] 
    val_acc = history.history['val_dsc']

    epochsn = np.arange(1, len(train_loss)+1,1)
    plt.figure(figsize = (12,5))
    plt.subplot(121)
    plt.plot(epochsn,train_loss, 'b', label='Training Loss')
    plt.plot(epochsn,val_loss, 'r', label='Validation Loss')
    plt.grid(color='gray', linestyle='--')
    plt.legend()
    plt.title('LOSS, Epochs={}, Batch={}'.format(epochnum, batchnum))
    plt.xlabel('Epochs')
    plt.ylabel('Loss')

    plt.subplot(122)
    plt.plot(epochsn, acc, 'b', label='Training Dice Coefficient')
    plt.plot(epochsn, val_acc, 'r', label='Validation Dice Coefficient')
    plt.grid(color='gray', linestyle='--')
    plt.legend()            
    plt.title('DSC, Epochs={}, Batch={}'.format(epochnum, batchnum))
    plt.xlabel('Epochs')
    plt.ylabel('CSC')
    
    plt.savefig('Graph_UNET.png')
    plt.show()

# %% [markdown]
# # U-NET

# %%
# Convolutional block for UNet
def ConvBlock(in_fmaps, num_fmaps):
    # Inputs: feature maps for UNet, number of output feature maps
    conv1 = Conv2D(num_fmaps, (3, 3), activation='relu', padding='same')(in_fmaps)
    conv_out = Conv2D(num_fmaps, (3, 3), activation='relu', padding='same')(conv1)
    return conv_out

# %%
# Build the model
def Network():
    
    input = Input(shape=input_size)

    conv1 = ConvBlock(input, 32)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = ConvBlock(pool1, 32)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = ConvBlock(pool2, 64)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = ConvBlock(pool3, 64)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = ConvBlock(pool4, 128)

    up6 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = ConvBlock(up6, 64)

    up7 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = ConvBlock(up7, 64)

    up8 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = ConvBlock(up8, 32)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = ConvBlock(up9, 32)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(conv9)

    model = Model(inputs = input, outputs = conv10)

    return model

# %%
model = Network()
model.compile(optimizer = Adam(learning_rate = 0.0001), loss = dice_loss, metrics = [dsc])

# %%
t = now()

history = model.fit(X_train, Y_train, validation_data = (X_val, Y_val), batch_size=batchnum, epochs=epochnum, verbose=1)
# Out:
# Epoch 1/100
# 2023-12-07 11:28:39.082005: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 33554432 exceeds 10% of free system memory.
# 2023-12-07 11:28:39.208865: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 33554432 exceeds 10% of free system memory.
# 2023-12-07 11:28:39.347141: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 20971520 exceeds 10% of free system memory.
# 2023-12-07 11:28:39.371398: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 20447232 exceeds 10% of free system memory.
# 2023-12-07 11:28:39.377519: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 16777216 exceeds 10% of free system memory.
# 7/7 [==============================] - 16s 2s/step - loss: 0.6108 - dsc: 0.3892 - val_loss: 0.5909 - val_dsc: 0.4105
# Epoch 2/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.6089 - dsc: 0.3911 - val_loss: 0.5894 - val_dsc: 0.4120
# Epoch 3/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.6087 - dsc: 0.3913 - val_loss: 0.5880 - val_dsc: 0.4135
# Epoch 4/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.6038 - dsc: 0.3962 - val_loss: 0.5859 - val_dsc: 0.4155
# Epoch 5/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.6010 - dsc: 0.3990 - val_loss: 0.5825 - val_dsc: 0.4190
# Epoch 6/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.5970 - dsc: 0.4030 - val_loss: 0.5750 - val_dsc: 0.4265
# Epoch 7/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.5926 - dsc: 0.4074 - val_loss: 0.5491 - val_dsc: 0.4524
# Epoch 8/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.5416 - dsc: 0.4584 - val_loss: 0.4864 - val_dsc: 0.5156
# Epoch 9/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.5137 - dsc: 0.4863 - val_loss: 0.4861 - val_dsc: 0.5161
# Epoch 10/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.5153 - dsc: 0.4847 - val_loss: 0.4866 - val_dsc: 0.5156
# Epoch 11/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.5139 - dsc: 0.4861 - val_loss: 0.4857 - val_dsc: 0.5165
# Epoch 12/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.5130 - dsc: 0.4870 - val_loss: 0.4830 - val_dsc: 0.5191
# Epoch 13/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.5131 - dsc: 0.4869 - val_loss: 0.4786 - val_dsc: 0.5234
# Epoch 14/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.5040 - dsc: 0.4960 - val_loss: 0.4680 - val_dsc: 0.5338
# Epoch 15/100
# 7/7 [==============================] - 10s 1s/step - loss: 0.4888 - dsc: 0.5112 - val_loss: 0.4379 - val_dsc: 0.5631
# Epoch 16/100
# 7/7 [==============================] - 10s 1s/step - loss: 0.4612 - dsc: 0.5388 - val_loss: 0.4199 - val_dsc: 0.5808
# Epoch 17/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.4388 - dsc: 0.5612 - val_loss: 0.3979 - val_dsc: 0.6024
# Epoch 18/100
# 7/7 [==============================] - 10s 1s/step - loss: 0.4107 - dsc: 0.5893 - val_loss: 0.3712 - val_dsc: 0.6285
# Epoch 19/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.3840 - dsc: 0.6160 - val_loss: 0.3496 - val_dsc: 0.6496
# Epoch 20/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.3618 - dsc: 0.6382 - val_loss: 0.3361 - val_dsc: 0.6625
# Epoch 21/100
# 7/7 [==============================] - 10s 1s/step - loss: 0.3565 - dsc: 0.6435 - val_loss: 0.3188 - val_dsc: 0.6774
# Epoch 22/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.3354 - dsc: 0.6646 - val_loss: 0.3192 - val_dsc: 0.6778
# Epoch 23/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.3370 - dsc: 0.6630 - val_loss: 0.3117 - val_dsc: 0.6847
# Epoch 24/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.3288 - dsc: 0.6712 - val_loss: 0.3169 - val_dsc: 0.6788
# Epoch 25/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.3278 - dsc: 0.6722 - val_loss: 0.3050 - val_dsc: 0.6910
# Epoch 26/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.3255 - dsc: 0.6745 - val_loss: 0.3144 - val_dsc: 0.6828
# Epoch 27/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.3360 - dsc: 0.6640 - val_loss: 0.3246 - val_dsc: 0.6710
# Epoch 28/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.3191 - dsc: 0.6809 - val_loss: 0.3075 - val_dsc: 0.6895
# Epoch 29/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.3203 - dsc: 0.6797 - val_loss: 0.2985 - val_dsc: 0.6972
# Epoch 30/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.3152 - dsc: 0.6848 - val_loss: 0.2956 - val_dsc: 0.7000
# Epoch 31/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.3099 - dsc: 0.6901 - val_loss: 0.2836 - val_dsc: 0.7122
# Epoch 32/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.3023 - dsc: 0.6977 - val_loss: 0.2971 - val_dsc: 0.6997
# Epoch 33/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.3155 - dsc: 0.6845 - val_loss: 0.3091 - val_dsc: 0.6867
# Epoch 34/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.2994 - dsc: 0.7006 - val_loss: 0.2698 - val_dsc: 0.7260
# Epoch 35/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.2889 - dsc: 0.7111 - val_loss: 0.2647 - val_dsc: 0.7312
# Epoch 36/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.2795 - dsc: 0.7205 - val_loss: 0.2508 - val_dsc: 0.7452
# Epoch 37/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.2672 - dsc: 0.7328 - val_loss: 0.2362 - val_dsc: 0.7601
# Epoch 38/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.2603 - dsc: 0.7397 - val_loss: 0.2446 - val_dsc: 0.7521
# Epoch 39/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.2578 - dsc: 0.7422 - val_loss: 0.2447 - val_dsc: 0.7524
# Epoch 40/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.2372 - dsc: 0.7628 - val_loss: 0.1902 - val_dsc: 0.8073
# Epoch 41/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.2163 - dsc: 0.7837 - val_loss: 0.2170 - val_dsc: 0.7809
# Epoch 42/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.2287 - dsc: 0.7713 - val_loss: 0.1592 - val_dsc: 0.8391
# Epoch 43/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.2065 - dsc: 0.7935 - val_loss: 0.1613 - val_dsc: 0.8381
# Epoch 44/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1913 - dsc: 0.8087 - val_loss: 0.1838 - val_dsc: 0.8141
# Epoch 45/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1861 - dsc: 0.8139 - val_loss: 0.1357 - val_dsc: 0.8633
# Epoch 46/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1685 - dsc: 0.8315 - val_loss: 0.1365 - val_dsc: 0.8622
# Epoch 47/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1475 - dsc: 0.8525 - val_loss: 0.1144 - val_dsc: 0.8851
# Epoch 48/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1469 - dsc: 0.8531 - val_loss: 0.1142 - val_dsc: 0.8850
# Epoch 49/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1424 - dsc: 0.8576 - val_loss: 0.1088 - val_dsc: 0.8907
# Epoch 50/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1394 - dsc: 0.8606 - val_loss: 0.1053 - val_dsc: 0.8943
# Epoch 51/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1328 - dsc: 0.8672 - val_loss: 0.0995 - val_dsc: 0.9006
# Epoch 52/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1321 - dsc: 0.8679 - val_loss: 0.1008 - val_dsc: 0.8991
# Epoch 53/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1289 - dsc: 0.8711 - val_loss: 0.1016 - val_dsc: 0.8986
# Epoch 54/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.1346 - dsc: 0.8654 - val_loss: 0.0980 - val_dsc: 0.9020
# Epoch 55/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.1275 - dsc: 0.8725 - val_loss: 0.0987 - val_dsc: 0.9013
# Epoch 56/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.1251 - dsc: 0.8749 - val_loss: 0.0936 - val_dsc: 0.9068
# Epoch 57/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.1237 - dsc: 0.8763 - val_loss: 0.0940 - val_dsc: 0.9060
# Epoch 58/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.1250 - dsc: 0.8750 - val_loss: 0.1092 - val_dsc: 0.8903
# Epoch 59/100
# 7/7 [==============================] - 10s 1s/step - loss: 0.1285 - dsc: 0.8715 - val_loss: 0.0920 - val_dsc: 0.9086
# Epoch 60/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.1196 - dsc: 0.8804 - val_loss: 0.0953 - val_dsc: 0.9047
# Epoch 61/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.1201 - dsc: 0.8799 - val_loss: 0.0943 - val_dsc: 0.9055
# Epoch 62/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.1174 - dsc: 0.8826 - val_loss: 0.0935 - val_dsc: 0.9063
# Epoch 63/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.1135 - dsc: 0.8865 - val_loss: 0.0908 - val_dsc: 0.9096
# Epoch 64/100
# 7/7 [==============================] - 10s 1s/step - loss: 0.1149 - dsc: 0.8851 - val_loss: 0.0962 - val_dsc: 0.9035
# Epoch 65/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1167 - dsc: 0.8833 - val_loss: 0.0930 - val_dsc: 0.9069
# Epoch 66/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.1216 - dsc: 0.8784 - val_loss: 0.0837 - val_dsc: 0.9168
# Epoch 67/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1156 - dsc: 0.8844 - val_loss: 0.0971 - val_dsc: 0.9027
# Epoch 68/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1109 - dsc: 0.8891 - val_loss: 0.0867 - val_dsc: 0.9131
# Epoch 69/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.1046 - dsc: 0.8954 - val_loss: 0.0821 - val_dsc: 0.9181
# Epoch 70/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.1052 - dsc: 0.8948 - val_loss: 0.0907 - val_dsc: 0.9100
# Epoch 71/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.1094 - dsc: 0.8906 - val_loss: 0.0938 - val_dsc: 0.9059
# Epoch 72/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.1111 - dsc: 0.8889 - val_loss: 0.0832 - val_dsc: 0.9165
# Epoch 73/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.1047 - dsc: 0.8953 - val_loss: 0.0779 - val_dsc: 0.9228
# Epoch 74/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.1023 - dsc: 0.8977 - val_loss: 0.0828 - val_dsc: 0.9178
# Epoch 75/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.1043 - dsc: 0.8957 - val_loss: 0.0754 - val_dsc: 0.9253
# Epoch 76/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0987 - dsc: 0.9013 - val_loss: 0.0787 - val_dsc: 0.9212
# Epoch 77/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0977 - dsc: 0.9023 - val_loss: 0.0734 - val_dsc: 0.9273
# Epoch 78/100
# 7/7 [==============================] - 10s 1s/step - loss: 0.1019 - dsc: 0.8981 - val_loss: 0.0790 - val_dsc: 0.9208
# Epoch 79/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0948 - dsc: 0.9052 - val_loss: 0.0984 - val_dsc: 0.9019
# Epoch 80/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.1018 - dsc: 0.8982 - val_loss: 0.0729 - val_dsc: 0.9279
# Epoch 81/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.0936 - dsc: 0.9064 - val_loss: 0.0727 - val_dsc: 0.9279
# Epoch 82/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0918 - dsc: 0.9082 - val_loss: 0.0789 - val_dsc: 0.9215
# Epoch 83/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.1022 - dsc: 0.8978 - val_loss: 0.0778 - val_dsc: 0.9220
# Epoch 84/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.1038 - dsc: 0.8962 - val_loss: 0.0867 - val_dsc: 0.9136
# Epoch 85/100
# 7/7 [==============================] - 10s 1s/step - loss: 0.1025 - dsc: 0.8975 - val_loss: 0.0754 - val_dsc: 0.9249
# Epoch 86/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.0926 - dsc: 0.9074 - val_loss: 0.0783 - val_dsc: 0.9213
# Epoch 87/100
# 7/7 [==============================] - 10s 1s/step - loss: 0.0907 - dsc: 0.9093 - val_loss: 0.0726 - val_dsc: 0.9277
# Epoch 88/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0883 - dsc: 0.9117 - val_loss: 0.0700 - val_dsc: 0.9307
# Epoch 89/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0889 - dsc: 0.9111 - val_loss: 0.0751 - val_dsc: 0.9249
# Epoch 90/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.0861 - dsc: 0.9139 - val_loss: 0.0720 - val_dsc: 0.9282
# Epoch 91/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0862 - dsc: 0.9138 - val_loss: 0.0701 - val_dsc: 0.9306
# Epoch 92/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0898 - dsc: 0.9102 - val_loss: 0.0740 - val_dsc: 0.9263
# Epoch 93/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0875 - dsc: 0.9125 - val_loss: 0.0731 - val_dsc: 0.9269
# Epoch 94/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0853 - dsc: 0.9147 - val_loss: 0.0799 - val_dsc: 0.9203
# Epoch 95/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.0905 - dsc: 0.9095 - val_loss: 0.0688 - val_dsc: 0.9316
# Epoch 96/100
# 7/7 [==============================] - 10s 1s/step - loss: 0.0829 - dsc: 0.9171 - val_loss: 0.0767 - val_dsc: 0.9224
# Epoch 97/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.0866 - dsc: 0.9134 - val_loss: 0.0744 - val_dsc: 0.9251
# Epoch 98/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0870 - dsc: 0.9130 - val_loss: 0.0780 - val_dsc: 0.9226
# Epoch 99/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.0941 - dsc: 0.9059 - val_loss: 0.0804 - val_dsc: 0.9189
# Epoch 100/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.0974 - dsc: 0.9026 - val_loss: 0.0886 - val_dsc: 0.9103

# %%
# Make predictions
t = now()
preds_UNET = model.predict(X_test)
print('Testing time: %s' % (now() - t))
print(len(X_train[112:140]))
# Out:
# 2/2 [==============================] - 1s 366ms/step
# Testing time: 0:00:01.478749
# 0

# %%
Representacion(history,epochnum, batchnum)
# Out:
# Training time: 0:00:01.482841

# %%
train_loss = history.history['loss']
epochsn = np.arange(1, len(train_loss)+1,1)
# Evaluate model
num_test = len(X_test)

# Calculate performance metrics
dsc_sc = np.zeros((num_test,1))
iou_sc = np.zeros_like(dsc_sc)
rec_sc = np.zeros_like(dsc_sc)
tn_sc = np.zeros_like(dsc_sc)
prec_sc = np.zeros_like(dsc_sc)
thresh = 0.5
for i in range(num_test):
    dsc_sc[i], iou_sc[i], rec_sc[i], prec_sc[i] = auc(Y_test[i], preds_UNET[i,:,:,0] >thresh)
print('-'*30)
print('USING THRESHOLD', thresh)
print('\n DSC \t\t{0:^.3f} \n IOU \t\t{1:^.3f} \n Recall \t{2:^.3f} \n Precision\t{3:^.3f}'.format(
        np.sum(dsc_sc)/num_test,  
        np.sum(iou_sc)/num_test,  
        np.sum(rec_sc)/num_test,
        np.sum(prec_sc)/num_test))
    
# Confusion matrix
confusion = confusion_matrix(Y_test.ravel(),preds_UNET.ravel()>thresh)
accuracy = 0
if float(np.sum(confusion))!=0:
    accuracy = float(confusion[0,0]+confusion[1,1])/float(np.sum(confusion))
print(' Global Acc \t{0:^.3f}'.format(accuracy))
    
# Area under the ROC curve
AUC_ROC = roc_auc_score(preds_UNET.ravel()>thresh, Y_test.ravel())
print(' AUC ROC \t{0:^.3f}'.format(AUC_ROC))
print('\n')
print('*'*60)
    
# Save outputs 
numepochs = epochsn[-1]
dice_score = np.sum(dsc_sc)/num_test
iou_score = np.sum(iou_sc)/num_test
rec_score = np.sum(rec_sc)/num_test
prec_score = np.sum(prec_sc)/num_test
globacc_score = accuracy
auc_roc_score = AUC_ROC
# Out:
# ------------------------------
# USING THRESHOLD 0.5
#
#  DSC 		0.881
#  IOU 		0.794
#  Recall 	0.955
#  Precision	0.834
#  Global Acc 	0.926
#  AUC ROC 	0.908
#
#
# ************************************************************

# %%
preds_UNET_val = model.predict(X_val)
val_loss = history.history['val_loss']
epochsn = np.arange(1, len(val_loss)+1,1)
# Evaluate model
num_val = len(X_val)

# Calculate performance metrics
dsc_sc = np.zeros((num_val,1))
iou_sc = np.zeros_like(dsc_sc)
rec_sc = np.zeros_like(dsc_sc)
tn_sc = np.zeros_like(dsc_sc)
prec_sc = np.zeros_like(dsc_sc)
thresh = 0.5
for i in range(num_val):
    dsc_sc[i], iou_sc[i], rec_sc[i], prec_sc[i] = auc(Y_test[i], preds_UNET_val[i,:,:,0] >thresh)
print('-'*30)
print('USING THRESHOLD', thresh)
print('\n DSC \t\t{0:^.3f} \n IOU \t\t{1:^.3f} \n Recall \t{2:^.3f} \n Precision\t{3:^.3f}'.format(
        np.sum(dsc_sc)/num_val,  
        np.sum(iou_sc)/num_val,  
        np.sum(rec_sc)/num_val,
        np.sum(prec_sc)/num_val))
    
# Confusion matrix
confusion = confusion_matrix(Y_val.ravel(),preds_UNET_val.ravel()>thresh)
accuracy = 0
if float(np.sum(confusion))!=0:
    accuracy = float(confusion[0,0]+confusion[1,1])/float(np.sum(confusion))
print(' Global Acc \t{0:^.3f}'.format(accuracy))
    
# Area under the ROC curve
AUC_ROC = roc_auc_score(preds_UNET_val.ravel()>thresh, Y_val.ravel())
print(' AUC ROC \t{0:^.3f}'.format(AUC_ROC))
print('\n')
print('*'*60)
    
# Save outputs 
numepochs = epochsn[-1]
dice_score = np.sum(dsc_sc)/num_val
iou_score = np.sum(iou_sc)/num_val
rec_score = np.sum(rec_sc)/num_val
prec_score = np.sum(prec_sc)/num_val
globacc_score = accuracy
auc_roc_score = AUC_ROC
# Out:
# 1/1 [==============================] - 0s 392ms/step
# ------------------------------
# USING THRESHOLD 0.5
#
#  DSC 		0.493
#  IOU 		0.354
#  Recall 	0.661
#  Precision	0.616
#  Global Acc 	0.937
#  AUC ROC 	0.927
#
#
# ************************************************************

# %% [markdown]
# # U-NET Dense

# %%
from keras.layers import *

def DenseBlock(channels,inputs):

    conv1_1 = Conv2D(channels, (1, 1),activation=None, padding='same')(inputs)
    conv1_1=BatchActivate(conv1_1)
    conv1_2 = Conv2D(channels//4, (3, 3), activation=None, padding='same')(conv1_1)
    conv1_2 = BatchActivate(conv1_2)

    conv2=concatenate([inputs,conv1_2])
    conv2_1 = Conv2D(channels, (1, 1), activation=None, padding='same')(conv2)
    conv2_1 = BatchActivate(conv2_1)
    conv2_2 = Conv2D(channels // 4, (3, 3), activation=None, padding='same')(conv2_1)
    conv2_2 = BatchActivate(conv2_2)

    conv3 = concatenate([inputs, conv1_2,conv2_2])
    conv3_1 = Conv2D(channels, (1, 1), activation=None, padding='same')(conv3)
    conv3_1 = BatchActivate(conv3_1)
    conv3_2 = Conv2D(channels // 4, (3, 3), activation=None, padding='same')(conv3_1)
    conv3_2 = BatchActivate(conv3_2)

    conv4 = concatenate([inputs, conv1_2, conv2_2,conv3_2])
    conv4_1 = Conv2D(channels, (1, 1), activation=None, padding='same')(conv4)
    conv4_1 = BatchActivate(conv4_1)
    conv4_2 = Conv2D(channels // 4, (3, 3), activation=None, padding='same')(conv4_1)
    conv4_2 = BatchActivate(conv4_2)
    result=concatenate([inputs,conv1_2, conv2_2,conv3_2,conv4_2])
    return result

def BatchActivate(x):
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

# %%
from keras.optimizers import *
from keras.models import *

def DenseUNet(start_neurons=16, keep_prob=0.9,block_size=7,lr=1e-3):

    inputs = Input(shape=input_size)
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(inputs)
    conv1 = BatchActivate(conv1)
    conv1 = DenseBlock(start_neurons * 1, conv1)
    pool1 = MaxPooling2D((2, 2))(conv1)

    conv2 = DenseBlock(start_neurons * 2, pool1)
    pool2 = MaxPooling2D((2, 2))(conv2)

    conv3 = DenseBlock(start_neurons * 4, pool2)
    pool3 = MaxPooling2D((2, 2))(conv3)


    convm = DenseBlock(start_neurons * 8, pool3)


    deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same")(convm)
    uconv3 = concatenate([deconv3, conv3])
    uconv3 = Conv2D(start_neurons * 4, (1, 1), activation=None, padding="same")(uconv3)
    uconv3 = BatchActivate(uconv3)
    uconv3 = DenseBlock(start_neurons * 4, uconv3)


    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(uconv3)
    uconv2 = concatenate([deconv2, conv2])
    uconv2 = Conv2D(start_neurons * 2, (1, 1), activation=None, padding="same")(uconv2)
    uconv2 = BatchActivate(uconv2)
    uconv2 = DenseBlock(start_neurons * 2, uconv2)

    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    uconv1 = Conv2D(start_neurons * 1, (1, 1), activation=None, padding="same")(uconv1)
    uconv1 = BatchActivate(uconv1)
    uconv1 = DenseBlock(start_neurons * 1, uconv1)

    output_layer_noActi = Conv2D(1, (1, 1), padding="same", activation=None)(uconv1)
    output_layer = Activation('sigmoid')(output_layer_noActi)
    
    model = Model(inputs=inputs, outputs=output_layer)
    model.compile(optimizer=Adam(lr=1e-3), loss=dice_loss, metrics=[dsc])

    return model

# %%
model = DenseUNet()
t = now()

history = model.fit(X_train, Y_train, validation_data = (X_val, Y_val), batch_size=batchnum, epochs=epochnum, verbose=1)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/100
# 7/7 [==============================] - 31s 2s/step - loss: 0.5604 - dsc: 0.4396 - val_loss: 0.5919 - val_dsc: 0.4095
# Epoch 2/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.3907 - dsc: 0.6093 - val_loss: 0.5961 - val_dsc: 0.4052
# Epoch 3/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.3010 - dsc: 0.6990 - val_loss: 0.6095 - val_dsc: 0.3918
# Epoch 4/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.2590 - dsc: 0.7410 - val_loss: 0.6336 - val_dsc: 0.3675
# Epoch 5/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.2176 - dsc: 0.7824 - val_loss: 0.6444 - val_dsc: 0.3566
# Epoch 6/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.1991 - dsc: 0.8009 - val_loss: 0.6831 - val_dsc: 0.3176
# Epoch 7/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.1889 - dsc: 0.8111 - val_loss: 0.6873 - val_dsc: 0.3134
# Epoch 8/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.1682 - dsc: 0.8318 - val_loss: 0.7406 - val_dsc: 0.2597
# Epoch 9/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.1673 - dsc: 0.8327 - val_loss: 0.7748 - val_dsc: 0.2253
# Epoch 10/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.1489 - dsc: 0.8511 - val_loss: 0.8150 - val_dsc: 0.1848
# Epoch 11/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.1454 - dsc: 0.8546 - val_loss: 0.8179 - val_dsc: 0.1820
# Epoch 12/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.1429 - dsc: 0.8571 - val_loss: 0.8229 - val_dsc: 0.1772
# Epoch 13/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.1256 - dsc: 0.8744 - val_loss: 0.8578 - val_dsc: 0.1423
# Epoch 14/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.1152 - dsc: 0.8848 - val_loss: 0.8864 - val_dsc: 0.1136
# Epoch 15/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.1008 - dsc: 0.8992 - val_loss: 0.8733 - val_dsc: 0.1267
# Epoch 16/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.1219 - dsc: 0.8781 - val_loss: 0.8933 - val_dsc: 0.1067
# Epoch 17/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.1062 - dsc: 0.8938 - val_loss: 0.9109 - val_dsc: 0.0891
# Epoch 18/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.1202 - dsc: 0.8798 - val_loss: 0.9298 - val_dsc: 0.0702
# Epoch 19/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.1036 - dsc: 0.8964 - val_loss: 0.9406 - val_dsc: 0.0595
# Epoch 20/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.1114 - dsc: 0.8886 - val_loss: 0.9423 - val_dsc: 0.0578
# Epoch 21/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.0885 - dsc: 0.9115 - val_loss: 0.9583 - val_dsc: 0.0418
# Epoch 22/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.1021 - dsc: 0.8979 - val_loss: 0.9544 - val_dsc: 0.0457
# Epoch 23/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0902 - dsc: 0.9098 - val_loss: 0.9608 - val_dsc: 0.0392
# Epoch 24/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0793 - dsc: 0.9207 - val_loss: 0.9661 - val_dsc: 0.0339
# Epoch 25/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0761 - dsc: 0.9239 - val_loss: 0.8783 - val_dsc: 0.1198
# Epoch 26/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.0838 - dsc: 0.9162 - val_loss: 0.9478 - val_dsc: 0.0527
# Epoch 27/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0786 - dsc: 0.9214 - val_loss: 0.9575 - val_dsc: 0.0429
# Epoch 28/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.0824 - dsc: 0.9176 - val_loss: 0.9567 - val_dsc: 0.0433
# Epoch 29/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.0762 - dsc: 0.9238 - val_loss: 0.9826 - val_dsc: 0.0174
# Epoch 30/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0879 - dsc: 0.9121 - val_loss: 0.9716 - val_dsc: 0.0282
# Epoch 31/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0732 - dsc: 0.9268 - val_loss: 0.9208 - val_dsc: 0.0753
# Epoch 32/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0726 - dsc: 0.9274 - val_loss: 0.8749 - val_dsc: 0.1243
# Epoch 33/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.0737 - dsc: 0.9263 - val_loss: 0.9514 - val_dsc: 0.0484
# Epoch 34/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.0777 - dsc: 0.9223 - val_loss: 0.7672 - val_dsc: 0.2216
# Epoch 35/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0777 - dsc: 0.9223 - val_loss: 0.7823 - val_dsc: 0.2114
# Epoch 36/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.0818 - dsc: 0.9182 - val_loss: 0.9609 - val_dsc: 0.0385
# Epoch 37/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.0968 - dsc: 0.9032 - val_loss: 0.6953 - val_dsc: 0.2932
# Epoch 38/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.0707 - dsc: 0.9293 - val_loss: 0.8019 - val_dsc: 0.1854
# Epoch 39/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0729 - dsc: 0.9271 - val_loss: 0.7107 - val_dsc: 0.2807
# Epoch 40/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0785 - dsc: 0.9215 - val_loss: 0.7561 - val_dsc: 0.2353
# Epoch 41/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.0707 - dsc: 0.9293 - val_loss: 0.5909 - val_dsc: 0.3973
# Epoch 42/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0707 - dsc: 0.9293 - val_loss: 0.5488 - val_dsc: 0.4381
# Epoch 43/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0605 - dsc: 0.9395 - val_loss: 0.4139 - val_dsc: 0.5777
# Epoch 44/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.0726 - dsc: 0.9274 - val_loss: 0.3814 - val_dsc: 0.6102
# Epoch 45/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.0864 - dsc: 0.9136 - val_loss: 0.2475 - val_dsc: 0.7462
# Epoch 46/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0681 - dsc: 0.9319 - val_loss: 0.5636 - val_dsc: 0.4221
# Epoch 47/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0741 - dsc: 0.9259 - val_loss: 0.3246 - val_dsc: 0.6657
# Epoch 48/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.0749 - dsc: 0.9251 - val_loss: 0.2837 - val_dsc: 0.7122
# Epoch 49/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.0659 - dsc: 0.9341 - val_loss: 0.4789 - val_dsc: 0.5111
# Epoch 50/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0706 - dsc: 0.9294 - val_loss: 0.4377 - val_dsc: 0.5516
# Epoch 51/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.0586 - dsc: 0.9414 - val_loss: 0.2317 - val_dsc: 0.7662
# Epoch 52/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.0613 - dsc: 0.9387 - val_loss: 0.2749 - val_dsc: 0.7245
# Epoch 53/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0484 - dsc: 0.9516 - val_loss: 0.2044 - val_dsc: 0.7958
# Epoch 54/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0474 - dsc: 0.9526 - val_loss: 0.2013 - val_dsc: 0.7993
# Epoch 55/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0477 - dsc: 0.9523 - val_loss: 0.1773 - val_dsc: 0.8232
# Epoch 56/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.0503 - dsc: 0.9497 - val_loss: 0.2173 - val_dsc: 0.7852
# Epoch 57/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.0605 - dsc: 0.9395 - val_loss: 0.2493 - val_dsc: 0.7526
# Epoch 58/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0565 - dsc: 0.9435 - val_loss: 0.1956 - val_dsc: 0.8060
# Epoch 59/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.0517 - dsc: 0.9483 - val_loss: 0.1801 - val_dsc: 0.8193
# Epoch 60/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.0494 - dsc: 0.9506 - val_loss: 0.1342 - val_dsc: 0.8658
# Epoch 61/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.0503 - dsc: 0.9497 - val_loss: 0.1335 - val_dsc: 0.8667
# Epoch 62/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0421 - dsc: 0.9579 - val_loss: 0.1475 - val_dsc: 0.8531
# Epoch 63/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0450 - dsc: 0.9550 - val_loss: 0.1494 - val_dsc: 0.8509
# Epoch 64/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0575 - dsc: 0.9425 - val_loss: 0.1314 - val_dsc: 0.8700
# Epoch 65/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.0498 - dsc: 0.9502 - val_loss: 0.1633 - val_dsc: 0.8357
# Epoch 66/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0513 - dsc: 0.9487 - val_loss: 0.1092 - val_dsc: 0.8920
# Epoch 67/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0440 - dsc: 0.9560 - val_loss: 0.1329 - val_dsc: 0.8677
# Epoch 68/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.0405 - dsc: 0.9595 - val_loss: 0.1137 - val_dsc: 0.8868
# Epoch 69/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0400 - dsc: 0.9600 - val_loss: 0.0979 - val_dsc: 0.9023
# Epoch 70/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0369 - dsc: 0.9631 - val_loss: 0.0953 - val_dsc: 0.9048
# Epoch 71/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.0367 - dsc: 0.9633 - val_loss: 0.0802 - val_dsc: 0.9202
# Epoch 72/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0364 - dsc: 0.9636 - val_loss: 0.0769 - val_dsc: 0.9236
# Epoch 73/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0368 - dsc: 0.9632 - val_loss: 0.0807 - val_dsc: 0.9191
# Epoch 74/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0369 - dsc: 0.9631 - val_loss: 0.0709 - val_dsc: 0.9296
# Epoch 75/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0386 - dsc: 0.9614 - val_loss: 0.0777 - val_dsc: 0.9229
# Epoch 76/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0386 - dsc: 0.9614 - val_loss: 0.0727 - val_dsc: 0.9272
# Epoch 77/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0414 - dsc: 0.9586 - val_loss: 0.0701 - val_dsc: 0.9314
# Epoch 78/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0509 - dsc: 0.9491 - val_loss: 0.0954 - val_dsc: 0.9047
# Epoch 79/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0476 - dsc: 0.9524 - val_loss: 0.0785 - val_dsc: 0.9205
# Epoch 80/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0425 - dsc: 0.9575 - val_loss: 0.0636 - val_dsc: 0.9374
# Epoch 81/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0366 - dsc: 0.9634 - val_loss: 0.0682 - val_dsc: 0.9317
# Epoch 82/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0347 - dsc: 0.9653 - val_loss: 0.0691 - val_dsc: 0.9306
# Epoch 83/100
# 7/7 [==============================] - 19s 3s/step - loss: 0.0485 - dsc: 0.9515 - val_loss: 0.1409 - val_dsc: 0.8621
# Epoch 84/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0472 - dsc: 0.9528 - val_loss: 0.0707 - val_dsc: 0.9319
# Epoch 85/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0460 - dsc: 0.9540 - val_loss: 0.0843 - val_dsc: 0.9149
# Epoch 86/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0460 - dsc: 0.9540 - val_loss: 0.0754 - val_dsc: 0.9243
# Epoch 87/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0450 - dsc: 0.9550 - val_loss: 0.1008 - val_dsc: 0.8982
# Epoch 88/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0365 - dsc: 0.9635 - val_loss: 0.0654 - val_dsc: 0.9336
# Epoch 89/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0354 - dsc: 0.9646 - val_loss: 0.0656 - val_dsc: 0.9337
# Epoch 90/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0342 - dsc: 0.9658 - val_loss: 0.0619 - val_dsc: 0.9379
# Epoch 91/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.0308 - dsc: 0.9692 - val_loss: 0.0897 - val_dsc: 0.9100
# Epoch 92/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0370 - dsc: 0.9630 - val_loss: 0.1352 - val_dsc: 0.8641
# Epoch 93/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0362 - dsc: 0.9638 - val_loss: 0.0803 - val_dsc: 0.9197
# Epoch 94/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.0310 - dsc: 0.9690 - val_loss: 0.0736 - val_dsc: 0.9248
# Epoch 95/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0320 - dsc: 0.9680 - val_loss: 0.0683 - val_dsc: 0.9310
# Epoch 96/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0313 - dsc: 0.9687 - val_loss: 0.0800 - val_dsc: 0.9185
# Epoch 97/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.0336 - dsc: 0.9664 - val_loss: 0.0686 - val_dsc: 0.9307
# Epoch 98/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0300 - dsc: 0.9700 - val_loss: 0.0654 - val_dsc: 0.9338
# Epoch 99/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0294 - dsc: 0.9706 - val_loss: 0.0704 - val_dsc: 0.9277
# Epoch 100/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0289 - dsc: 0.9711 - val_loss: 0.0755 - val_dsc: 0.9230

# %%
# Make predictions
t = now()
preds_Dense = model.predict(X_test)
print('Testing time: %s' % (now() - t))
# Out:
# 2/2 [==============================] - 2s 578ms/step
# Testing time: 0:00:02.049776

# %%
Representacion(history,epochnum,batchnum)
# Out:
# Training time: 0:00:02.053699

# %%
from tensorflow.python.ops.numpy_ops import np_config
np_config.enable_numpy_behavior()
# Evaluate model
num_test = len(X_test)
# Calculate performance metrics
dsc_sc = np.zeros((num_test,1))
iou_sc = np.zeros_like(dsc_sc)
rec_sc = np.zeros_like(dsc_sc)
tn_sc = np.zeros_like(dsc_sc)
prec_sc = np.zeros_like(dsc_sc)
thresh = 0.5
for i in range(num_test):
    dsc_sc[i], iou_sc[i], rec_sc[i], prec_sc[i] = auc(Y_test[i], preds_Dense[i] >thresh)
print('-'*30)
print('USING THRESHOLD', thresh)
print('\n DSC \t\t{0:^.3f} \n IOU \t\t{1:^.3f} \n Recall \t{2:^.3f} \n Precision\t{3:^.3f}'.format(
        np.sum(dsc_sc)/num_test,  
        np.sum(iou_sc)/num_test,  
        np.sum(rec_sc)/num_test,
        np.sum(prec_sc)/num_test))
    
# Confusion matrix
confusion = confusion_matrix(Y_test.ravel(),preds_Dense.ravel()>thresh)
accuracy = 0
if float(np.sum(confusion))!=0:
    accuracy = float(confusion[0,0]+confusion[1,1])/float(np.sum(confusion))
print(' Global Acc \t{0:^.3f}'.format(accuracy))
    
# Area under the ROC curve
AUC_ROC = roc_auc_score(preds_Dense.ravel()>thresh, Y_test.ravel())
print(' AUC ROC \t{0:^.3f}'.format(AUC_ROC))
print('\n')
print('*'*60)
    
# Save outputs 
numepochs = epochsn[-1]
dice_score = np.sum(dsc_sc)/num_test
iou_score = np.sum(iou_sc)/num_test
rec_score = np.sum(rec_sc)/num_test
prec_score = np.sum(prec_sc)/num_test
globacc_score = accuracy
auc_roc_score = AUC_ROC
# Out:
# ------------------------------
# USING THRESHOLD 0.5
#
#  DSC 		0.429
#  IOU 		0.295
#  Recall 	0.425
#  Precision	0.439
#  Global Acc 	0.954
#  AUC ROC 	0.952
#
#
# ************************************************************

# %%
preds_Dense_val = model.predict(X_val)
# Evaluate model
num_val = len(X_val)
# Calculate performance metrics
dsc_sc = np.zeros((num_test,1))
iou_sc = np.zeros_like(dsc_sc)
rec_sc = np.zeros_like(dsc_sc)
tn_sc = np.zeros_like(dsc_sc)
prec_sc = np.zeros_like(dsc_sc)
thresh = 0.5
for i in range(num_val):
    dsc_sc[i], iou_sc[i], rec_sc[i], prec_sc[i] = auc(Y_val[i], preds_Dense_val[i] >thresh)
print('-'*30)
print('USING THRESHOLD', thresh)
print('\n DSC \t\t{0:^.3f} \n IOU \t\t{1:^.3f} \n Recall \t{2:^.3f} \n Precision\t{3:^.3f}'.format(
        np.sum(dsc_sc)/num_val,  
        np.sum(iou_sc)/num_val,  
        np.sum(rec_sc)/num_val,
        np.sum(prec_sc)/num_val))
    
# Confusion matrix
confusion = confusion_matrix(Y_val.ravel(),preds_Dense_val.ravel()>thresh)
accuracy = 0
if float(np.sum(confusion))!=0:
    accuracy = float(confusion[0,0]+confusion[1,1])/float(np.sum(confusion))
print(' Global Acc \t{0:^.3f}'.format(accuracy))
    
# Area under the ROC curve
AUC_ROC = roc_auc_score(preds_Dense_val.ravel()>thresh, Y_val.ravel())
print(' AUC ROC \t{0:^.3f}'.format(AUC_ROC))
print('\n')
print('*'*60)
    
# Save outputs 
numepochs = epochsn[-1]
dice_score = np.sum(dsc_sc)/num_val
iou_score = np.sum(iou_sc)/num_val
rec_score = np.sum(rec_sc)/num_val
prec_score = np.sum(prec_sc)/num_val
globacc_score = accuracy
auc_roc_score = AUC_ROC
# Out:
# 1/1 [==============================] - 1s 668ms/step
# ------------------------------
# USING THRESHOLD 0.5
#
#  DSC 		0.445
#  IOU 		0.307
#  Recall 	0.433
#  Precision	0.464
#  Global Acc 	0.951
#  AUC ROC 	0.955
#
#
# ************************************************************

# %% [markdown]
# # Attention U-NET

# %%
from sklearn.model_selection import train_test_split
import tensorflow as tf

X_train, X_test, Y_train, Y_test = train_test_split(imgs, masks_, test_size=0.3, random_state = 0)
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size = 0.2, random_state = 0)

X_train = tf.convert_to_tensor(X_train)
X_train = tf.reshape(X_train, [X_train.shape[0],X_train.shape[1],X_train.shape[2],1])

X_test = tf.convert_to_tensor(X_test)
X_test = tf.reshape(X_test, [X_test.shape[0],X_test.shape[1],X_test.shape[2],1])

Y_train = tf.convert_to_tensor(Y_train)
Y_train = tf.reshape(Y_train, [Y_train.shape[0],Y_train.shape[1],Y_train.shape[2],1])

Y_test = tf.convert_to_tensor(Y_test)
Y_test = tf.reshape(Y_test, [Y_test.shape[0],Y_test.shape[1],Y_test.shape[2],1])

X_val = tf.convert_to_tensor(X_val)
X_val = tf.reshape(X_val, [X_val.shape[0],X_val.shape[1],X_val.shape[2],1])

Y_val = tf.convert_to_tensor(Y_val)
Y_val = tf.reshape(Y_val, [Y_val.shape[0],Y_val.shape[1],Y_val.shape[2],1])

# %%
import keras_unet_collection
from keras_unet_collection._model_att_unet_2d import att_unet_2d

model = att_unet_2d(input_size, filter_num=[64, 128, 256, 512, 1024], n_labels=1, 
                           stack_num_down=2, stack_num_up=1, activation='ReLU', 
                           atten_activation='ReLU', attention='add', output_activation='Sigmoid', 
                           batch_norm=True, pool='max', unpool=False,  
                           name='attunet')

# %%
model.compile(loss=dice_loss,optimizer=keras.optimizers.Adam(learning_rate=1e-4), metrics=dsc)
import datetime
now = datetime.datetime.now
t = now()

history = model.fit(X_train, Y_train, validation_data = (X_val, Y_val), batch_size=batchnum, epochs=epochnum, verbose=1)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 55s 7s/step - loss: 0.4917 - dsc: 0.5083 - val_loss: 0.5938 - val_dsc: 0.4075
# Epoch 2/100
# 7/7 [==============================] - 55s 8s/step - loss: 0.3240 - dsc: 0.6760 - val_loss: 0.5976 - val_dsc: 0.4037
# Epoch 3/100
# 7/7 [==============================] - 51s 7s/step - loss: 0.2522 - dsc: 0.7478 - val_loss: 0.6042 - val_dsc: 0.3971
# Epoch 4/100
# 7/7 [==============================] - 51s 7s/step - loss: 0.1922 - dsc: 0.8078 - val_loss: 0.6128 - val_dsc: 0.3884
# Epoch 5/100
# 7/7 [==============================] - 53s 7s/step - loss: 0.1906 - dsc: 0.8094 - val_loss: 0.6216 - val_dsc: 0.3796
# Epoch 6/100
# 7/7 [==============================] - 56s 8s/step - loss: 0.1595 - dsc: 0.8405 - val_loss: 0.6325 - val_dsc: 0.3686
# Epoch 7/100
# 7/7 [==============================] - 56s 8s/step - loss: 0.1420 - dsc: 0.8580 - val_loss: 0.6427 - val_dsc: 0.3584
# Epoch 8/100
# 7/7 [==============================] - 54s 8s/step - loss: 0.1467 - dsc: 0.8533 - val_loss: 0.6556 - val_dsc: 0.3454
# Epoch 9/100
# 7/7 [==============================] - 56s 8s/step - loss: 0.1308 - dsc: 0.8692 - val_loss: 0.6653 - val_dsc: 0.3356
# Epoch 10/100
# 7/7 [==============================] - 54s 8s/step - loss: 0.1422 - dsc: 0.8578 - val_loss: 0.6801 - val_dsc: 0.3207
# Epoch 11/100
# 7/7 [==============================] - 52s 8s/step - loss: 0.1435 - dsc: 0.8565 - val_loss: 0.6874 - val_dsc: 0.3134
# Epoch 12/100
# 7/7 [==============================] - 54s 8s/step - loss: 0.1105 - dsc: 0.8895 - val_loss: 0.7006 - val_dsc: 0.3001
# Epoch 13/100
# 7/7 [==============================] - 51s 7s/step - loss: 0.1086 - dsc: 0.8914 - val_loss: 0.7128 - val_dsc: 0.2879
# Epoch 14/100
# 7/7 [==============================] - 51s 7s/step - loss: 0.1139 - dsc: 0.8861 - val_loss: 0.7297 - val_dsc: 0.2709
# Epoch 15/100
# 7/7 [==============================] - 74s 11s/step - loss: 0.0944 - dsc: 0.9056 - val_loss: 0.7391 - val_dsc: 0.2615
# Epoch 16/100
# 7/7 [==============================] - 80s 11s/step - loss: 0.0920 - dsc: 0.9080 - val_loss: 0.7522 - val_dsc: 0.2483
# Epoch 17/100
# 7/7 [==============================] - 61s 9s/step - loss: 0.1015 - dsc: 0.8985 - val_loss: 0.7651 - val_dsc: 0.2354
# Epoch 18/100
# 7/7 [==============================] - 59s 9s/step - loss: 0.0879 - dsc: 0.9121 - val_loss: 0.7723 - val_dsc: 0.2281
# Epoch 19/100
# 7/7 [==============================] - 57s 8s/step - loss: 0.0780 - dsc: 0.9220 - val_loss: 0.7844 - val_dsc: 0.2160
# Epoch 20/100
# 7/7 [==============================] - 60s 9s/step - loss: 0.0789 - dsc: 0.9211 - val_loss: 0.7941 - val_dsc: 0.2063
# Epoch 21/100
# 7/7 [==============================] - 64s 9s/step - loss: 0.0713 - dsc: 0.9287 - val_loss: 0.8013 - val_dsc: 0.1991
# Epoch 22/100
# 7/7 [==============================] - 62s 9s/step - loss: 0.0683 - dsc: 0.9317 - val_loss: 0.8128 - val_dsc: 0.1875
# Epoch 23/100
# 7/7 [==============================] - 60s 9s/step - loss: 0.0828 - dsc: 0.9172 - val_loss: 0.8274 - val_dsc: 0.1728
# Epoch 24/100
# 7/7 [==============================] - 62s 9s/step - loss: 0.0684 - dsc: 0.9316 - val_loss: 0.8414 - val_dsc: 0.1588
# Epoch 25/100
# 7/7 [==============================] - 64s 9s/step - loss: 0.0710 - dsc: 0.9290 - val_loss: 0.8483 - val_dsc: 0.1519
# Epoch 26/100
# 7/7 [==============================] - 54s 8s/step - loss: 0.0701 - dsc: 0.9299 - val_loss: 0.8616 - val_dsc: 0.1385
# Epoch 27/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0596 - dsc: 0.9404 - val_loss: 0.8672 - val_dsc: 0.1330
# Epoch 28/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0617 - dsc: 0.9383 - val_loss: 0.8775 - val_dsc: 0.1227
# Epoch 29/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0656 - dsc: 0.9344 - val_loss: 0.8781 - val_dsc: 0.1221
# Epoch 30/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0673 - dsc: 0.9327 - val_loss: 0.8905 - val_dsc: 0.1096
# Epoch 31/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0690 - dsc: 0.9310 - val_loss: 0.8997 - val_dsc: 0.1005
# Epoch 32/100
# 7/7 [==============================] - 51s 7s/step - loss: 0.0576 - dsc: 0.9424 - val_loss: 0.9064 - val_dsc: 0.0938
# Epoch 33/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0836 - dsc: 0.9164 - val_loss: 0.9104 - val_dsc: 0.0898
# Epoch 34/100
# 7/7 [==============================] - 50s 7s/step - loss: 0.0760 - dsc: 0.9240 - val_loss: 0.9182 - val_dsc: 0.0819
# Epoch 35/100
# 7/7 [==============================] - 54s 8s/step - loss: 0.0778 - dsc: 0.9222 - val_loss: 0.9257 - val_dsc: 0.0741
# Epoch 36/100
# 7/7 [==============================] - 48s 7s/step - loss: 0.0663 - dsc: 0.9337 - val_loss: 0.9332 - val_dsc: 0.0666
# Epoch 37/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0585 - dsc: 0.9415 - val_loss: 0.9343 - val_dsc: 0.0652
# Epoch 38/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0633 - dsc: 0.9367 - val_loss: 0.9411 - val_dsc: 0.0589
# Epoch 39/100
# 7/7 [==============================] - 53s 8s/step - loss: 0.0491 - dsc: 0.9509 - val_loss: 0.9396 - val_dsc: 0.0600
# Epoch 40/100
# 7/7 [==============================] - 56s 8s/step - loss: 0.0545 - dsc: 0.9455 - val_loss: 0.9343 - val_dsc: 0.0652
# Epoch 41/100
# 7/7 [==============================] - 55s 8s/step - loss: 0.0483 - dsc: 0.9517 - val_loss: 0.9342 - val_dsc: 0.0649
# Epoch 42/100
# 7/7 [==============================] - 55s 8s/step - loss: 0.0400 - dsc: 0.9600 - val_loss: 0.9261 - val_dsc: 0.0726
# Epoch 43/100
# 7/7 [==============================] - 52s 8s/step - loss: 0.0461 - dsc: 0.9539 - val_loss: 0.9293 - val_dsc: 0.0694
# Epoch 44/100
# 7/7 [==============================] - 53s 8s/step - loss: 0.0551 - dsc: 0.9449 - val_loss: 0.9379 - val_dsc: 0.0606
# Epoch 45/100
# 7/7 [==============================] - 53s 8s/step - loss: 0.0412 - dsc: 0.9588 - val_loss: 0.9332 - val_dsc: 0.0650
# Epoch 46/100
# 7/7 [==============================] - 58s 8s/step - loss: 0.0414 - dsc: 0.9586 - val_loss: 0.9189 - val_dsc: 0.0777
# Epoch 47/100
# 7/7 [==============================] - 52s 8s/step - loss: 0.0416 - dsc: 0.9584 - val_loss: 0.9290 - val_dsc: 0.0691
# Epoch 48/100
# 7/7 [==============================] - 54s 8s/step - loss: 0.0446 - dsc: 0.9554 - val_loss: 0.9216 - val_dsc: 0.0755
# Epoch 49/100
# 7/7 [==============================] - 54s 8s/step - loss: 0.0390 - dsc: 0.9610 - val_loss: 0.9123 - val_dsc: 0.0841
# Epoch 50/100
# 7/7 [==============================] - 85s 13s/step - loss: 0.0509 - dsc: 0.9491 - val_loss: 0.5410 - val_dsc: 0.4545
# Epoch 51/100
# 7/7 [==============================] - 118s 17s/step - loss: 0.0411 - dsc: 0.9589 - val_loss: 0.4968 - val_dsc: 0.4998
# Epoch 52/100
# 7/7 [==============================] - 117s 16s/step - loss: 0.0446 - dsc: 0.9554 - val_loss: 0.5320 - val_dsc: 0.4623
# Epoch 53/100
# 7/7 [==============================] - 102s 15s/step - loss: 0.0507 - dsc: 0.9493 - val_loss: 0.4401 - val_dsc: 0.5545
# Epoch 54/100
# 7/7 [==============================] - 56s 7s/step - loss: 0.0443 - dsc: 0.9557 - val_loss: 0.3748 - val_dsc: 0.6204
# Epoch 55/100
# 7/7 [==============================] - 88s 13s/step - loss: 0.0395 - dsc: 0.9605 - val_loss: 0.5435 - val_dsc: 0.4507
# Epoch 56/100
# 7/7 [==============================] - 98s 14s/step - loss: 0.0365 - dsc: 0.9635 - val_loss: 0.5675 - val_dsc: 0.4239
# Epoch 57/100
# 7/7 [==============================] - 100s 14s/step - loss: 0.0368 - dsc: 0.9632 - val_loss: 0.5809 - val_dsc: 0.4105
# Epoch 58/100
# 7/7 [==============================] - 100s 14s/step - loss: 0.0385 - dsc: 0.9615 - val_loss: 0.5351 - val_dsc: 0.4567
# Epoch 59/100
# 7/7 [==============================] - 50s 7s/step - loss: 0.0485 - dsc: 0.9515 - val_loss: 0.3160 - val_dsc: 0.6779
# Epoch 60/100
# 7/7 [==============================] - 56s 8s/step - loss: 0.0369 - dsc: 0.9631 - val_loss: 0.2339 - val_dsc: 0.7625
# Epoch 61/100
# 7/7 [==============================] - 111s 16s/step - loss: 0.0341 - dsc: 0.9659 - val_loss: 0.2110 - val_dsc: 0.7864
# Epoch 62/100
# 7/7 [==============================] - 106s 15s/step - loss: 0.0328 - dsc: 0.9672 - val_loss: 0.2020 - val_dsc: 0.7955
# Epoch 63/100
# 7/7 [==============================] - 100s 14s/step - loss: 0.0287 - dsc: 0.9713 - val_loss: 0.2536 - val_dsc: 0.7429
# Epoch 64/100
# 7/7 [==============================] - 81s 11s/step - loss: 0.0288 - dsc: 0.9712 - val_loss: 0.2613 - val_dsc: 0.7346
# Epoch 65/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0313 - dsc: 0.9687 - val_loss: 0.2894 - val_dsc: 0.7051
# Epoch 66/100
# 7/7 [==============================] - 48s 7s/step - loss: 0.0263 - dsc: 0.9737 - val_loss: 0.3079 - val_dsc: 0.6855
# Epoch 67/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0307 - dsc: 0.9693 - val_loss: 0.2986 - val_dsc: 0.6951
# Epoch 68/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0237 - dsc: 0.9763 - val_loss: 0.2946 - val_dsc: 0.6994
# Epoch 69/100
# 7/7 [==============================] - 86s 13s/step - loss: 0.0257 - dsc: 0.9743 - val_loss: 0.2661 - val_dsc: 0.7287
# Epoch 70/100
# 7/7 [==============================] - 100s 14s/step - loss: 0.0238 - dsc: 0.9762 - val_loss: 0.2554 - val_dsc: 0.7404
# Epoch 71/100
# 7/7 [==============================] - 108s 16s/step - loss: 0.0236 - dsc: 0.9764 - val_loss: 0.2530 - val_dsc: 0.7429
# Epoch 72/100
# 7/7 [==============================] - 101s 15s/step - loss: 0.0228 - dsc: 0.9772 - val_loss: 0.2359 - val_dsc: 0.7605
# Epoch 73/100
# 7/7 [==============================] - 53s 7s/step - loss: 0.0354 - dsc: 0.9646 - val_loss: 0.2332 - val_dsc: 0.7630
# Epoch 74/100
# 7/7 [==============================] - 51s 7s/step - loss: 0.0246 - dsc: 0.9754 - val_loss: 0.2545 - val_dsc: 0.7397
# Epoch 75/100
# 7/7 [==============================] - 53s 8s/step - loss: 0.0262 - dsc: 0.9738 - val_loss: 0.2434 - val_dsc: 0.7513
# Epoch 76/100
# 7/7 [==============================] - 54s 8s/step - loss: 0.0249 - dsc: 0.9751 - val_loss: 0.2032 - val_dsc: 0.7934
# Epoch 77/100
# 7/7 [==============================] - 53s 8s/step - loss: 0.0255 - dsc: 0.9745 - val_loss: 0.1825 - val_dsc: 0.8150
# Epoch 78/100
# 7/7 [==============================] - 58s 8s/step - loss: 0.0216 - dsc: 0.9784 - val_loss: 0.1769 - val_dsc: 0.8213
# Epoch 79/100
# 7/7 [==============================] - 54s 8s/step - loss: 0.0215 - dsc: 0.9785 - val_loss: 0.1539 - val_dsc: 0.8447
# Epoch 80/100
# 7/7 [==============================] - 50s 7s/step - loss: 0.0198 - dsc: 0.9802 - val_loss: 0.1415 - val_dsc: 0.8573
# Epoch 81/100
# 7/7 [==============================] - 56s 8s/step - loss: 0.0221 - dsc: 0.9779 - val_loss: 0.1315 - val_dsc: 0.8674
# Epoch 82/100
# 7/7 [==============================] - 59s 9s/step - loss: 0.0206 - dsc: 0.9794 - val_loss: 0.1232 - val_dsc: 0.8756
# Epoch 83/100
# 7/7 [==============================] - 84s 13s/step - loss: 0.0200 - dsc: 0.9800 - val_loss: 0.1154 - val_dsc: 0.8834
# Epoch 84/100
# 7/7 [==============================] - 122s 18s/step - loss: 0.0223 - dsc: 0.9777 - val_loss: 0.1137 - val_dsc: 0.8854
# Epoch 85/100
# 7/7 [==============================] - 106s 15s/step - loss: 0.0222 - dsc: 0.9778 - val_loss: 0.1072 - val_dsc: 0.8919
# Epoch 86/100
# 7/7 [==============================] - 98s 14s/step - loss: 0.0192 - dsc: 0.9808 - val_loss: 0.1047 - val_dsc: 0.8943
# Epoch 87/100
# 7/7 [==============================] - 76s 10s/step - loss: 0.0187 - dsc: 0.9813 - val_loss: 0.1042 - val_dsc: 0.8948
# Epoch 88/100
# 7/7 [==============================] - 97s 14s/step - loss: 0.0218 - dsc: 0.9782 - val_loss: 0.1021 - val_dsc: 0.8970
# Epoch 89/100
# 7/7 [==============================] - 98s 14s/step - loss: 0.0178 - dsc: 0.9822 - val_loss: 0.0969 - val_dsc: 0.9021
# Epoch 90/100
# 7/7 [==============================] - 97s 14s/step - loss: 0.0212 - dsc: 0.9788 - val_loss: 0.0981 - val_dsc: 0.9008
# Epoch 91/100
# 7/7 [==============================] - 102s 15s/step - loss: 0.0169 - dsc: 0.9831 - val_loss: 0.0993 - val_dsc: 0.8997
# Epoch 92/100
# 7/7 [==============================] - 98s 14s/step - loss: 0.0214 - dsc: 0.9786 - val_loss: 0.0953 - val_dsc: 0.9035
# Epoch 93/100
# 7/7 [==============================] - 99s 14s/step - loss: 0.0199 - dsc: 0.9801 - val_loss: 0.0963 - val_dsc: 0.9023
# Epoch 94/100
# 7/7 [==============================] - 98s 14s/step - loss: 0.0175 - dsc: 0.9825 - val_loss: 0.1005 - val_dsc: 0.8981
# Epoch 95/100
# 7/7 [==============================] - 97s 14s/step - loss: 0.0166 - dsc: 0.9834 - val_loss: 0.0908 - val_dsc: 0.9080
# Epoch 96/100
# 7/7 [==============================] - 98s 14s/step - loss: 0.0180 - dsc: 0.9820 - val_loss: 0.0882 - val_dsc: 0.9105
# Epoch 97/100
# 7/7 [==============================] - 99s 14s/step - loss: 0.0157 - dsc: 0.9843 - val_loss: 0.0930 - val_dsc: 0.9057
# Epoch 98/100
# 7/7 [==============================] - 96s 14s/step - loss: 0.0164 - dsc: 0.9836 - val_loss: 0.0896 - val_dsc: 0.9092
# Epoch 99/100
# 7/7 [==============================] - 77s 12s/step - loss: 0.0160 - dsc: 0.9840 - val_loss: 0.0872 - val_dsc: 0.9119
# Epoch 100/100
# 7/7 [==============================] - 97s 14s/step - loss: 0.0140 - dsc: 0.9860 - val_loss: 0.0835 - val_dsc: 0.9157

# %%
# Make predictions
t = now()
preds_Att = model.predict(X_test)
print('Testing time: %s' % (now() - t))
# Out:
# 2/2 [==============================] - 14s 5s/step
# Testing time: 0:00:13.962731

# %%
Representacion(history,epochnum,batchnum)
# Out:
# Training time: 0:00:13.981593

# %%
# Evaluate model
num_test = len(X_test)
# Calculate performance metrics
dsc_sc = np.zeros((num_test,1))
iou_sc = np.zeros_like(dsc_sc)
rec_sc = np.zeros_like(dsc_sc)
tn_sc = np.zeros_like(dsc_sc)
prec_sc = np.zeros_like(dsc_sc)
thresh = 0.5
for i in range(num_test):
    dsc_sc[i], iou_sc[i], rec_sc[i], prec_sc[i] = auc(Y_test[i], preds_Att[i] >thresh)
print('-'*30)
print('USING THRESHOLD', thresh)
print('\n DSC \t\t{0:^.3f} \n IOU \t\t{1:^.3f} \n Recall \t{2:^.3f} \n Precision\t{3:^.3f}'.format(
        np.sum(dsc_sc)/num_test,  
        np.sum(iou_sc)/num_test,  
        np.sum(rec_sc)/num_test,
        np.sum(prec_sc)/num_test))
    
# Confusion matrix
confusion = confusion_matrix(Y_test.ravel(),preds_Att.ravel()>thresh)
accuracy = 0
if float(np.sum(confusion))!=0:
    accuracy = float(confusion[0,0]+confusion[1,1])/float(np.sum(confusion))
print(' Global Acc \t{0:^.3f}'.format(accuracy))
    
# Area under the ROC curve
AUC_ROC = roc_auc_score(preds_Att.ravel()>thresh, Y_test.ravel())
print(' AUC ROC \t{0:^.3f}'.format(AUC_ROC))
print('\n')
print('*'*60)
    
# Save outputs 
numepochs = epochsn[-1]
dice_score = np.sum(dsc_sc)/num_test
iou_score = np.sum(iou_sc)/num_test
rec_score = np.sum(rec_sc)/num_test
prec_score = np.sum(prec_sc)/num_test
globacc_score = accuracy
auc_roc_score = AUC_ROC
# Out:
# ------------------------------
# USING THRESHOLD 0.5
#
#  DSC 		0.915
#  IOU 		0.849
#  Recall 	0.894
#  Precision	0.952
#  Global Acc 	0.948
#  AUC ROC 	0.951
#
#
# ************************************************************

# %%
preds_Att_val = model.predict(X_val)
num_val = len(X_val)
# Calculate performance metrics
dsc_sc = np.zeros((num_val,1))
iou_sc = np.zeros_like(dsc_sc)
rec_sc = np.zeros_like(dsc_sc)
tn_sc = np.zeros_like(dsc_sc)
prec_sc = np.zeros_like(dsc_sc)
thresh = 0.5
for i in range(num_val):
    dsc_sc[i], iou_sc[i], rec_sc[i], prec_sc[i] = auc(Y_val[i], preds_Att_val[i] >thresh)
print('-'*30)
print('USING THRESHOLD', thresh)
print('\n DSC \t\t{0:^.3f} \n IOU \t\t{1:^.3f} \n Recall \t{2:^.3f} \n Precision\t{3:^.3f}'.format(
        np.sum(dsc_sc)/num_val,  
        np.sum(iou_sc)/num_val,  
        np.sum(rec_sc)/num_val,
        np.sum(prec_sc)/num_val))
    
# Confusion matrix
confusion = confusion_matrix(Y_val.ravel(),preds_Att_val.ravel()>thresh)
accuracy = 0
if float(np.sum(confusion))!=0:
    accuracy = float(confusion[0,0]+confusion[1,1])/float(np.sum(confusion))
print(' Global Acc \t{0:^.3f}'.format(accuracy))
    
# Area under the ROC curve
AUC_ROC = roc_auc_score(preds_Att_val.ravel()>thresh, Y_val.ravel())
print(' AUC ROC \t{0:^.3f}'.format(AUC_ROC))
print('\n')
print('*'*60)
    
# Save outputs 
numepochs = epochsn[-1]
dice_score = np.sum(dsc_sc)/num_val
iou_score = np.sum(iou_sc)/num_val
rec_score = np.sum(rec_sc)/num_val
prec_score = np.sum(prec_sc)/num_val
globacc_score = accuracy
auc_roc_score = AUC_ROC
# Out:
# 1/1 [==============================] - 6s 6s/step
# ------------------------------
# USING THRESHOLD 0.5
#
#  DSC 		0.923
#  IOU 		0.861
#  Recall 	0.887
#  Precision	0.970
#  Global Acc 	0.950
#  AUC ROC 	0.958
#
#
# ************************************************************

# %% [markdown]
# # U-NET Dense + Attended

# %%
from keras.layers import *

def DenseBlock(channels,inputs):

    conv1_1 = Conv2D(channels, (1, 1),activation=None, padding='same')(inputs)
    conv1_1=BatchActivate(conv1_1)
    conv1_2 = Conv2D(channels//4, (3, 3), activation=None, padding='same')(conv1_1)
    conv1_2 = BatchActivate(conv1_2)

    conv2=concatenate([inputs,conv1_2])
    conv2_1 = Conv2D(channels, (1, 1), activation=None, padding='same')(conv2)
    conv2_1 = BatchActivate(conv2_1)
    conv2_2 = Conv2D(channels // 4, (3, 3), activation=None, padding='same')(conv2_1)
    conv2_2 = BatchActivate(conv2_2)

    conv3 = concatenate([inputs, conv1_2,conv2_2])
    conv3_1 = Conv2D(channels, (1, 1), activation=None, padding='same')(conv3)
    conv3_1 = BatchActivate(conv3_1)
    conv3_2 = Conv2D(channels // 4, (3, 3), activation=None, padding='same')(conv3_1)
    conv3_2 = BatchActivate(conv3_2)

    conv4 = concatenate([inputs, conv1_2, conv2_2,conv3_2])
    conv4_1 = Conv2D(channels, (1, 1), activation=None, padding='same')(conv4)
    conv4_1 = BatchActivate(conv4_1)
    conv4_2 = Conv2D(channels // 4, (3, 3), activation=None, padding='same')(conv4_1)
    conv4_2 = BatchActivate(conv4_2)
    result=concatenate([inputs,conv1_2, conv2_2,conv3_2,conv4_2])
    return result

def BatchActivate(x):
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

def Attention_gate(g, s, num_filters):
    Wg = Conv2D(num_filters, 1, padding="same")(g)
    Wg = BatchNormalization()(Wg)
 
    Ws = Conv2D(num_filters, 1, padding="same")(s)
    Ws = BatchNormalization()(Ws)
    
    w = Add()([Wg,Ws])
 
    out = Activation("relu")(w)
    out = Conv2D(num_filters, 1, padding="same")(out)
    out = Activation("sigmoid")(out)
    return Multiply()([out,s])

# %%
from keras.optimizers import *
from keras.models import *

def DenseUNet_AttGate(start_neurons=16, keep_prob=0.9,block_size=7,lr=1e-3):

    inputs = Input(shape=input_size)
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(inputs)
    conv1 = BatchActivate(conv1)
    conv1 = DenseBlock(start_neurons * 1, conv1)
    pool1 = MaxPooling2D((2, 2))(conv1)

    conv2 = DenseBlock(start_neurons * 2, pool1)
    pool2 = MaxPooling2D((2, 2))(conv2)

    conv3 = DenseBlock(start_neurons * 4, pool2)
    pool3 = MaxPooling2D((2, 2))(conv3)


    convm = DenseBlock(start_neurons * 8, pool3)


    deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same")(convm)
    Att3 = Attention_gate(conv3,deconv3,start_neurons * 4)  
    uconv3 = concatenate([deconv3, Att3])
    uconv3 = Conv2D(start_neurons * 4, (1, 1), activation=None, padding="same")(uconv3)
    uconv3 = BatchActivate(uconv3)
    uconv3 = DenseBlock(start_neurons * 4, uconv3)


    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(uconv3)
    Att2 = Attention_gate(conv2,deconv2,start_neurons * 2)  
    uconv2 = concatenate([deconv2, Att2])
    uconv2 = Conv2D(start_neurons * 2, (1, 1), activation=None, padding="same")(uconv2)
    uconv2 = BatchActivate(uconv2)
    uconv2 = DenseBlock(start_neurons * 2, uconv2)

    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv2)
    Att1 = Attention_gate(conv1,deconv1,start_neurons * 1)  
    uconv1 = concatenate([deconv1, Att1])
    uconv1 = Conv2D(start_neurons * 1, (1, 1), activation=None, padding="same")(uconv1)
    uconv1 = BatchActivate(uconv1)
    uconv1 = DenseBlock(start_neurons * 1, uconv1)

    output_layer_noActi = Conv2D(1, (1, 1), padding="same", activation=None)(uconv1)
    output_layer = Activation('sigmoid')(output_layer_noActi)
    
    model = Model(inputs=inputs, outputs=output_layer)
    model.compile(optimizer=Adam(lr=1e-3), loss=dice_loss, metrics=[dsc])

    return model

# %%
from sklearn.model_selection import train_test_split
keras.backend.clear_session()
X_train, X_test, Y_train, Y_test = train_test_split(imgs, masks_, test_size=0.3, random_state = 0)
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size = 0.2, random_state = 0)
model2 = DenseUNet_AttGate()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
t = now()

history = model2.fit(X_train, Y_train, validation_data = (X_val, Y_val), batch_size=batchnum, epochs=epochnum, verbose=1)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 85s 6s/step - loss: 0.4590 - dsc: 0.5410 - val_loss: 0.5948 - val_dsc: 0.4066
# Epoch 2/100
# 7/7 [==============================] - 36s 5s/step - loss: 0.3204 - dsc: 0.6796 - val_loss: 0.6035 - val_dsc: 0.3978
# Epoch 3/100
# 7/7 [==============================] - 29s 4s/step - loss: 0.2711 - dsc: 0.7289 - val_loss: 0.6199 - val_dsc: 0.3813
# Epoch 4/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.2361 - dsc: 0.7639 - val_loss: 0.6400 - val_dsc: 0.3611
# Epoch 5/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.2084 - dsc: 0.7916 - val_loss: 0.6633 - val_dsc: 0.3377
# Epoch 6/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.1897 - dsc: 0.8103 - val_loss: 0.6887 - val_dsc: 0.3121
# Epoch 7/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.1871 - dsc: 0.8129 - val_loss: 0.7151 - val_dsc: 0.2856
# Epoch 8/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.1804 - dsc: 0.8196 - val_loss: 0.7414 - val_dsc: 0.2591
# Epoch 9/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.1697 - dsc: 0.8303 - val_loss: 0.7663 - val_dsc: 0.2342
# Epoch 10/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.1658 - dsc: 0.8342 - val_loss: 0.7905 - val_dsc: 0.2099
# Epoch 11/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.1595 - dsc: 0.8405 - val_loss: 0.8116 - val_dsc: 0.1887
# Epoch 12/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.1512 - dsc: 0.8488 - val_loss: 0.8307 - val_dsc: 0.1695
# Epoch 13/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.1466 - dsc: 0.8534 - val_loss: 0.8516 - val_dsc: 0.1486
# Epoch 14/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.1361 - dsc: 0.8639 - val_loss: 0.8657 - val_dsc: 0.1349
# Epoch 15/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.1105 - dsc: 0.8895 - val_loss: 0.8814 - val_dsc: 0.1187
# Epoch 16/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.1043 - dsc: 0.8957 - val_loss: 0.8927 - val_dsc: 0.1076
# Epoch 17/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.1193 - dsc: 0.8807 - val_loss: 0.9040 - val_dsc: 0.0960
# Epoch 18/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.1058 - dsc: 0.8942 - val_loss: 0.9133 - val_dsc: 0.0869
# Epoch 19/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0979 - dsc: 0.9021 - val_loss: 0.9086 - val_dsc: 0.0929
# Epoch 20/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0985 - dsc: 0.9015 - val_loss: 0.9301 - val_dsc: 0.0700
# Epoch 21/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0925 - dsc: 0.9075 - val_loss: 0.9294 - val_dsc: 0.0718
# Epoch 22/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.1202 - dsc: 0.8798 - val_loss: 0.9380 - val_dsc: 0.0625
# Epoch 23/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.1058 - dsc: 0.8942 - val_loss: 0.9465 - val_dsc: 0.0545
# Epoch 24/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.1047 - dsc: 0.8953 - val_loss: 0.9306 - val_dsc: 0.0712
# Epoch 25/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0905 - dsc: 0.9095 - val_loss: 0.4142 - val_dsc: 0.5760
# Epoch 26/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0887 - dsc: 0.9113 - val_loss: 0.9495 - val_dsc: 0.0529
# Epoch 27/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0870 - dsc: 0.9130 - val_loss: 0.9351 - val_dsc: 0.0664
# Epoch 28/100
# 7/7 [==============================] - 17s 3s/step - loss: 0.0727 - dsc: 0.9273 - val_loss: 0.9588 - val_dsc: 0.0432
# Epoch 29/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0875 - dsc: 0.9125 - val_loss: 0.9552 - val_dsc: 0.0466
# Epoch 30/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0682 - dsc: 0.9318 - val_loss: 0.9474 - val_dsc: 0.0526
# Epoch 31/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0736 - dsc: 0.9264 - val_loss: 0.9459 - val_dsc: 0.0544
# Epoch 32/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0655 - dsc: 0.9345 - val_loss: 0.9114 - val_dsc: 0.0905
# Epoch 33/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0707 - dsc: 0.9293 - val_loss: 0.8928 - val_dsc: 0.1076
# Epoch 34/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0742 - dsc: 0.9258 - val_loss: 0.9222 - val_dsc: 0.0799
# Epoch 35/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0665 - dsc: 0.9335 - val_loss: 0.8041 - val_dsc: 0.1909
# Epoch 36/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0702 - dsc: 0.9298 - val_loss: 0.9270 - val_dsc: 0.0755
# Epoch 37/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0609 - dsc: 0.9391 - val_loss: 0.9027 - val_dsc: 0.0987
# Epoch 38/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0644 - dsc: 0.9356 - val_loss: 0.9136 - val_dsc: 0.0871
# Epoch 39/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0640 - dsc: 0.9360 - val_loss: 0.9026 - val_dsc: 0.0962
# Epoch 40/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0513 - dsc: 0.9487 - val_loss: 0.9460 - val_dsc: 0.0546
# Epoch 41/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0448 - dsc: 0.9552 - val_loss: 0.7811 - val_dsc: 0.2128
# Epoch 42/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0495 - dsc: 0.9505 - val_loss: 0.9523 - val_dsc: 0.0483
# Epoch 43/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0467 - dsc: 0.9533 - val_loss: 0.8276 - val_dsc: 0.1692
# Epoch 44/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0451 - dsc: 0.9549 - val_loss: 0.8444 - val_dsc: 0.1538
# Epoch 45/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0527 - dsc: 0.9473 - val_loss: 0.8150 - val_dsc: 0.1811
# Epoch 46/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0500 - dsc: 0.9500 - val_loss: 0.7772 - val_dsc: 0.2205
# Epoch 47/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0428 - dsc: 0.9572 - val_loss: 0.7345 - val_dsc: 0.2597
# Epoch 48/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0404 - dsc: 0.9596 - val_loss: 0.7225 - val_dsc: 0.2700
# Epoch 49/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0411 - dsc: 0.9589 - val_loss: 0.6645 - val_dsc: 0.3258
# Epoch 50/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0394 - dsc: 0.9606 - val_loss: 0.5979 - val_dsc: 0.3910
# Epoch 51/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0410 - dsc: 0.9590 - val_loss: 0.6577 - val_dsc: 0.3313
# Epoch 52/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0507 - dsc: 0.9493 - val_loss: 0.5147 - val_dsc: 0.4769
# Epoch 53/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0527 - dsc: 0.9473 - val_loss: 0.2637 - val_dsc: 0.7313
# Epoch 54/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0518 - dsc: 0.9482 - val_loss: 0.3723 - val_dsc: 0.6191
# Epoch 55/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0533 - dsc: 0.9467 - val_loss: 0.4035 - val_dsc: 0.5894
# Epoch 56/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0696 - dsc: 0.9304 - val_loss: 0.3394 - val_dsc: 0.6517
# Epoch 57/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0817 - dsc: 0.9183 - val_loss: 0.2779 - val_dsc: 0.7192
# Epoch 58/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0679 - dsc: 0.9321 - val_loss: 0.2925 - val_dsc: 0.7074
# Epoch 59/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0581 - dsc: 0.9419 - val_loss: 0.2842 - val_dsc: 0.7152
# Epoch 60/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0510 - dsc: 0.9490 - val_loss: 0.2731 - val_dsc: 0.7252
# Epoch 61/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0465 - dsc: 0.9535 - val_loss: 0.1848 - val_dsc: 0.8140
# Epoch 62/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0461 - dsc: 0.9539 - val_loss: 0.1583 - val_dsc: 0.8408
# Epoch 63/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0369 - dsc: 0.9631 - val_loss: 0.1200 - val_dsc: 0.8810
# Epoch 64/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0404 - dsc: 0.9596 - val_loss: 0.1074 - val_dsc: 0.8937
# Epoch 65/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0352 - dsc: 0.9648 - val_loss: 0.1192 - val_dsc: 0.8810
# Epoch 66/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0345 - dsc: 0.9655 - val_loss: 0.1196 - val_dsc: 0.8798
# Epoch 67/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0305 - dsc: 0.9695 - val_loss: 0.1222 - val_dsc: 0.8782
# Epoch 68/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0335 - dsc: 0.9665 - val_loss: 0.1046 - val_dsc: 0.8966
# Epoch 69/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0327 - dsc: 0.9673 - val_loss: 0.1104 - val_dsc: 0.8889
# Epoch 70/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0313 - dsc: 0.9687 - val_loss: 0.1542 - val_dsc: 0.8448
# Epoch 71/100
# 7/7 [==============================] - 17s 3s/step - loss: 0.0286 - dsc: 0.9714 - val_loss: 0.1182 - val_dsc: 0.8827
# Epoch 72/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0284 - dsc: 0.9716 - val_loss: 0.1172 - val_dsc: 0.8806
# Epoch 73/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0256 - dsc: 0.9744 - val_loss: 0.0680 - val_dsc: 0.9331
# Epoch 74/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0266 - dsc: 0.9734 - val_loss: 0.0715 - val_dsc: 0.9295
# Epoch 75/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0237 - dsc: 0.9763 - val_loss: 0.0826 - val_dsc: 0.9186
# Epoch 76/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0239 - dsc: 0.9761 - val_loss: 0.0765 - val_dsc: 0.9250
# Epoch 77/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0223 - dsc: 0.9777 - val_loss: 0.0637 - val_dsc: 0.9378
# Epoch 78/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0275 - dsc: 0.9725 - val_loss: 0.0685 - val_dsc: 0.9323
# Epoch 79/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0553 - dsc: 0.9447 - val_loss: 0.0933 - val_dsc: 0.9082
# Epoch 80/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0626 - dsc: 0.9374 - val_loss: 0.0758 - val_dsc: 0.9233
# Epoch 81/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0411 - dsc: 0.9589 - val_loss: 0.0856 - val_dsc: 0.9152
# Epoch 82/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0364 - dsc: 0.9636 - val_loss: 0.0892 - val_dsc: 0.9112
# Epoch 83/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0357 - dsc: 0.9643 - val_loss: 0.1034 - val_dsc: 0.8953
# Epoch 84/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0403 - dsc: 0.9597 - val_loss: 0.1016 - val_dsc: 0.8973
# Epoch 85/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0374 - dsc: 0.9626 - val_loss: 0.0732 - val_dsc: 0.9261
# Epoch 86/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0299 - dsc: 0.9701 - val_loss: 0.0655 - val_dsc: 0.9349
# Epoch 87/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0303 - dsc: 0.9697 - val_loss: 0.0582 - val_dsc: 0.9425
# Epoch 88/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0283 - dsc: 0.9717 - val_loss: 0.0630 - val_dsc: 0.9376
# Epoch 89/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0304 - dsc: 0.9696 - val_loss: 0.0727 - val_dsc: 0.9265
# Epoch 90/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0284 - dsc: 0.9716 - val_loss: 0.0582 - val_dsc: 0.9421
# Epoch 91/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0275 - dsc: 0.9725 - val_loss: 0.0713 - val_dsc: 0.9282
# Epoch 92/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0240 - dsc: 0.9760 - val_loss: 0.0712 - val_dsc: 0.9282
# Epoch 93/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0302 - dsc: 0.9698 - val_loss: 0.0631 - val_dsc: 0.9366
# Epoch 94/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0240 - dsc: 0.9760 - val_loss: 0.0597 - val_dsc: 0.9405
# Epoch 95/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0247 - dsc: 0.9753 - val_loss: 0.0583 - val_dsc: 0.9425
# Epoch 96/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0209 - dsc: 0.9791 - val_loss: 0.0594 - val_dsc: 0.9407
# Epoch 97/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0194 - dsc: 0.9806 - val_loss: 0.0599 - val_dsc: 0.9401
# Epoch 98/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0195 - dsc: 0.9805 - val_loss: 0.0587 - val_dsc: 0.9425
# Epoch 99/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.0189 - dsc: 0.9811 - val_loss: 0.0599 - val_dsc: 0.9406
# Epoch 100/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0177 - dsc: 0.9823 - val_loss: 0.0562 - val_dsc: 0.9441

# %%
# Make predictions
t = now()
preds_DA = model2.predict(X_test)
print('Testing time: %s' % (now() - t))
# Out:
# 2/2 [==============================] - 2s 622ms/step
# Testing time: 0:00:02.700390

# %%
Representacion(history,epochnum,batchnum)
# Out:
# Training time: 0:00:02.709853

# %%
# Evaluate model
num_test = len(X_test)
# Calculate performance metrics
dsc_sc = np.zeros((num_test,1))
iou_sc = np.zeros_like(dsc_sc)
rec_sc = np.zeros_like(dsc_sc)
tn_sc = np.zeros_like(dsc_sc)
prec_sc = np.zeros_like(dsc_sc)
thresh = 0.5
for i in range(num_test):
    dsc_sc[i], iou_sc[i], rec_sc[i], prec_sc[i] = auc(Y_test[i], preds_DA[i,:,:,0] >thresh)
print('-'*30)
print('USING THRESHOLD', thresh)
print('\n DSC \t\t{0:^.3f} \n IOU \t\t{1:^.3f} \n Recall \t{2:^.3f} \n Precision\t{3:^.3f}'.format(
        np.sum(dsc_sc)/num_test,  
        np.sum(iou_sc)/num_test,  
        np.sum(rec_sc)/num_test,
        np.sum(prec_sc)/num_test))
    
# Confusion matrix
confusion = confusion_matrix(Y_test.ravel(),preds_DA.ravel()>thresh)
accuracy = 0
if float(np.sum(confusion))!=0:
    accuracy = float(confusion[0,0]+confusion[1,1])/float(np.sum(confusion))
print(' Global Acc \t{0:^.3f}'.format(accuracy))
    
# Area under the ROC curve
AUC_ROC = roc_auc_score(preds_DA.ravel()>thresh, Y_test.ravel())
print(' AUC ROC \t{0:^.3f}'.format(AUC_ROC))
print('\n')
print('*'*60)
    
# Save outputs 
numepochs = epochsn[-1]
dice_score = np.sum(dsc_sc)/num_test
iou_score = np.sum(iou_sc)/num_test
rec_score = np.sum(rec_sc)/num_test
prec_score = np.sum(prec_sc)/num_test
globacc_score = accuracy
auc_roc_score = AUC_ROC
# Out:
# ------------------------------
# USING THRESHOLD 0.5
#
#  DSC 		0.933
#  IOU 		0.877
#  Recall 	0.933
#  Precision	0.940
#  Global Acc 	0.961
#  AUC ROC 	0.957
#
#
# ************************************************************

# %%
preds_DA_val = model2.predict(X_val)
num_val = len(X_val)
# Calculate performance metrics
dsc_sc = np.zeros((num_val,1))
iou_sc = np.zeros_like(dsc_sc)
rec_sc = np.zeros_like(dsc_sc)
tn_sc = np.zeros_like(dsc_sc)
prec_sc = np.zeros_like(dsc_sc)
thresh = 0.5
for i in range(num_val):
    dsc_sc[i], iou_sc[i], rec_sc[i], prec_sc[i] = auc(Y_val[i], preds_DA_val[i,:,:,0] >thresh)
print('-'*30)
print('USING THRESHOLD', thresh)
print('\n DSC \t\t{0:^.3f} \n IOU \t\t{1:^.3f} \n Recall \t{2:^.3f} \n Precision\t{3:^.3f}'.format(
        np.sum(dsc_sc)/num_val,  
        np.sum(iou_sc)/num_val,  
        np.sum(rec_sc)/num_val,
        np.sum(prec_sc)/num_val))
    
# Confusion matrix
confusion = confusion_matrix(Y_val.ravel(),preds_DA_val.ravel()>thresh)
accuracy = 0
if float(np.sum(confusion))!=0:
    accuracy = float(confusion[0,0]+confusion[1,1])/float(np.sum(confusion))
print(' Global Acc \t{0:^.3f}'.format(accuracy))
    
# Area under the ROC curve
AUC_ROC = roc_auc_score(preds_DA_val.ravel()>thresh, Y_val.ravel())
print(' AUC ROC \t{0:^.3f}'.format(AUC_ROC))
print('\n')
print('*'*60)
    
# Save outputs 
numepochs = epochsn[-1]
dice_score = np.sum(dsc_sc)/num_val
iou_score = np.sum(iou_sc)/num_val
rec_score = np.sum(rec_sc)/num_val
prec_score = np.sum(prec_sc)/num_val
globacc_score = accuracy
auc_roc_score = AUC_ROC
# Out:
# 1/1 [==============================] - 1s 632ms/step
# ------------------------------
# USING THRESHOLD 0.5
#
#  DSC 		0.936
#  IOU 		0.883
#  Recall 	0.928
#  Precision	0.951
#  Global Acc 	0.963
#  AUC ROC 	0.961
#
#
# ************************************************************

# %% [markdown]
# # U-NET 3+

# %%
from keras_unet_collection import models, base, utils
model = models.unet_3plus_2d(input_size, n_labels=1, filter_num_down=[64, 128, 256, 512], 
                             filter_num_skip='auto', filter_num_aggregate='auto', 
                             stack_num_down=2, stack_num_up=1, activation='ReLU', output_activation='Sigmoid',
                             batch_norm=True, pool='max', unpool=False, deep_supervision=False, name='unet3plus')
# Out:
# Automated hyper-parameter determination is applied with the following details:
# ----------
# 	Number of convolution filters after each full-scale skip connection: filter_num_skip = [64, 64, 64]
# 	Number of channels of full-scale aggregated feature maps: filter_num_aggregate = 256

# %%
model.compile(loss=dice_loss,optimizer=keras.optimizers.Adam(learning_rate=1e-4), metrics=[dsc]) # lr adaptativo

import datetime
now = datetime.datetime.now
t = now()

history = model.fit(X_train, Y_train, validation_data = (X_val, Y_val), batch_size=batchnum, epochs=epochnum, verbose=1)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 83s 11s/step - loss: 0.4397 - dsc: 0.5603 - val_loss: 0.5975 - val_dsc: 0.4039
# Epoch 2/100
# 7/7 [==============================] - 75s 11s/step - loss: 0.2322 - dsc: 0.7678 - val_loss: 0.6169 - val_dsc: 0.3843
# Epoch 3/100
# 7/7 [==============================] - 74s 11s/step - loss: 0.1766 - dsc: 0.8234 - val_loss: 0.6496 - val_dsc: 0.3514
# Epoch 4/100
# 7/7 [==============================] - 72s 10s/step - loss: 0.1476 - dsc: 0.8524 - val_loss: 0.6948 - val_dsc: 0.3060
# Epoch 5/100
# 7/7 [==============================] - 74s 11s/step - loss: 0.1366 - dsc: 0.8634 - val_loss: 0.7476 - val_dsc: 0.2530
# Epoch 6/100
# 7/7 [==============================] - 72s 10s/step - loss: 0.1260 - dsc: 0.8740 - val_loss: 0.8004 - val_dsc: 0.1999
# Epoch 7/100
# 7/7 [==============================] - 72s 10s/step - loss: 0.1197 - dsc: 0.8803 - val_loss: 0.8488 - val_dsc: 0.1514
# Epoch 8/100
# 7/7 [==============================] - 72s 10s/step - loss: 0.1064 - dsc: 0.8936 - val_loss: 0.8870 - val_dsc: 0.1132
# Epoch 9/100
# 7/7 [==============================] - 72s 10s/step - loss: 0.1048 - dsc: 0.8952 - val_loss: 0.9187 - val_dsc: 0.0814
# Epoch 10/100
# 7/7 [==============================] - 74s 11s/step - loss: 0.0910 - dsc: 0.9090 - val_loss: 0.9406 - val_dsc: 0.0595
# Epoch 11/100
# 7/7 [==============================] - 73s 10s/step - loss: 0.1054 - dsc: 0.8946 - val_loss: 0.9574 - val_dsc: 0.0426
# Epoch 12/100
# 7/7 [==============================] - 72s 10s/step - loss: 0.0977 - dsc: 0.9023 - val_loss: 0.9683 - val_dsc: 0.0317
# Epoch 13/100
# 7/7 [==============================] - 73s 11s/step - loss: 0.0899 - dsc: 0.9101 - val_loss: 0.9765 - val_dsc: 0.0236
# Epoch 14/100
# 7/7 [==============================] - 72s 10s/step - loss: 0.0902 - dsc: 0.9098 - val_loss: 0.9829 - val_dsc: 0.0171
# Epoch 15/100
# 7/7 [==============================] - 73s 10s/step - loss: 0.0911 - dsc: 0.9089 - val_loss: 0.9872 - val_dsc: 0.0128
# Epoch 16/100
# 7/7 [==============================] - 73s 10s/step - loss: 0.0915 - dsc: 0.9085 - val_loss: 0.9898 - val_dsc: 0.0102
# Epoch 17/100
# 7/7 [==============================] - 72s 10s/step - loss: 0.0812 - dsc: 0.9188 - val_loss: 0.9921 - val_dsc: 0.0079
# Epoch 18/100
# 7/7 [==============================] - 72s 10s/step - loss: 0.0954 - dsc: 0.9046 - val_loss: 0.9935 - val_dsc: 0.0065
# Epoch 19/100
# 7/7 [==============================] - 72s 10s/step - loss: 0.0781 - dsc: 0.9219 - val_loss: 0.9947 - val_dsc: 0.0053
# Epoch 20/100
# 7/7 [==============================] - 79s 11s/step - loss: 0.0698 - dsc: 0.9302 - val_loss: 0.9958 - val_dsc: 0.0042
# Epoch 21/100
# 7/7 [==============================] - 75s 11s/step - loss: 0.0843 - dsc: 0.9157 - val_loss: 0.9963 - val_dsc: 0.0037
# Epoch 22/100
# 7/7 [==============================] - 72s 10s/step - loss: 0.0748 - dsc: 0.9252 - val_loss: 0.9971 - val_dsc: 0.0029
# Epoch 23/100
# 7/7 [==============================] - 74s 11s/step - loss: 0.0732 - dsc: 0.9268 - val_loss: 0.9975 - val_dsc: 0.0025
# Epoch 24/100
# 7/7 [==============================] - 74s 10s/step - loss: 0.0715 - dsc: 0.9285 - val_loss: 0.9979 - val_dsc: 0.0021
# Epoch 25/100
# 7/7 [==============================] - 74s 11s/step - loss: 0.0819 - dsc: 0.9181 - val_loss: 0.9982 - val_dsc: 0.0018
# Epoch 26/100
# 7/7 [==============================] - 72s 10s/step - loss: 0.0753 - dsc: 0.9247 - val_loss: 0.9985 - val_dsc: 0.0015
# Epoch 27/100
# 7/7 [==============================] - 72s 10s/step - loss: 0.0623 - dsc: 0.9377 - val_loss: 0.9989 - val_dsc: 0.0011
# Epoch 28/100
# 7/7 [==============================] - 73s 11s/step - loss: 0.0541 - dsc: 0.9459 - val_loss: 0.9990 - val_dsc: 0.0010
# Epoch 29/100
# 7/7 [==============================] - 72s 10s/step - loss: 0.0591 - dsc: 0.9409 - val_loss: 0.9990 - val_dsc: 9.7784e-04
# Epoch 30/100
# 7/7 [==============================] - 73s 10s/step - loss: 0.0573 - dsc: 0.9427 - val_loss: 0.9990 - val_dsc: 9.7414e-04
# Epoch 31/100
# 7/7 [==============================] - 72s 10s/step - loss: 0.0504 - dsc: 0.9496 - val_loss: 0.9992 - val_dsc: 8.2597e-04
# Epoch 32/100
# 7/7 [==============================] - 72s 10s/step - loss: 0.0431 - dsc: 0.9569 - val_loss: 0.9992 - val_dsc: 8.3955e-04
# Epoch 33/100
# 7/7 [==============================] - 73s 10s/step - loss: 0.0567 - dsc: 0.9433 - val_loss: 0.9992 - val_dsc: 8.5046e-04
# Epoch 34/100
# 7/7 [==============================] - 72s 10s/step - loss: 0.0475 - dsc: 0.9525 - val_loss: 0.9992 - val_dsc: 7.5482e-04
# Epoch 35/100
# 7/7 [==============================] - 72s 10s/step - loss: 0.0423 - dsc: 0.9577 - val_loss: 0.9993 - val_dsc: 7.0459e-04
# Epoch 36/100
# 7/7 [==============================] - 72s 10s/step - loss: 0.0526 - dsc: 0.9474 - val_loss: 0.9994 - val_dsc: 6.0241e-04
# Epoch 37/100
# 7/7 [==============================] - 72s 10s/step - loss: 0.0492 - dsc: 0.9508 - val_loss: 0.9995 - val_dsc: 5.4958e-04
# Epoch 38/100
# 7/7 [==============================] - 73s 10s/step - loss: 0.0395 - dsc: 0.9605 - val_loss: 0.9996 - val_dsc: 4.2243e-04
# Epoch 39/100
# 7/7 [==============================] - 72s 10s/step - loss: 0.0486 - dsc: 0.9514 - val_loss: 0.9994 - val_dsc: 6.2866e-04
# Epoch 40/100
# 7/7 [==============================] - 72s 10s/step - loss: 0.0400 - dsc: 0.9600 - val_loss: 0.9994 - val_dsc: 5.7960e-04
# Epoch 41/100
# 7/7 [==============================] - 72s 10s/step - loss: 0.0333 - dsc: 0.9667 - val_loss: 0.9994 - val_dsc: 6.0660e-04
# Epoch 42/100
# 7/7 [==============================] - 72s 10s/step - loss: 0.0393 - dsc: 0.9607 - val_loss: 0.9994 - val_dsc: 6.0032e-04
# Epoch 43/100
# 7/7 [==============================] - 73s 10s/step - loss: 0.0341 - dsc: 0.9659 - val_loss: 0.9994 - val_dsc: 5.6841e-04
# Epoch 44/100
# 7/7 [==============================] - 72s 10s/step - loss: 0.0346 - dsc: 0.9654 - val_loss: 0.9995 - val_dsc: 5.2259e-04
# Epoch 45/100
# 7/7 [==============================] - 79s 11s/step - loss: 0.0376 - dsc: 0.9624 - val_loss: 0.9995 - val_dsc: 5.0802e-04
# Epoch 46/100
# 7/7 [==============================] - 85s 12s/step - loss: 0.0292 - dsc: 0.9708 - val_loss: 0.9996 - val_dsc: 4.0780e-04
# Epoch 47/100
# 7/7 [==============================] - 75s 11s/step - loss: 0.0300 - dsc: 0.9700 - val_loss: 0.9996 - val_dsc: 4.2440e-04
# Epoch 48/100
# 7/7 [==============================] - 73s 10s/step - loss: 0.0269 - dsc: 0.9731 - val_loss: 0.9996 - val_dsc: 4.2296e-04
# Epoch 49/100
# 7/7 [==============================] - 75s 11s/step - loss: 0.0396 - dsc: 0.9604 - val_loss: 0.9996 - val_dsc: 4.1461e-04
# Epoch 50/100
# 7/7 [==============================] - 82s 12s/step - loss: 0.0335 - dsc: 0.9665 - val_loss: 0.9997 - val_dsc: 3.0170e-04
# Epoch 51/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.0333 - dsc: 0.9667 - val_loss: 0.9997 - val_dsc: 2.9122e-04
# Epoch 52/100
# 7/7 [==============================] - 89s 13s/step - loss: 0.0252 - dsc: 0.9748 - val_loss: 0.9998 - val_dsc: 2.4788e-04
# Epoch 53/100
# 7/7 [==============================] - 91s 13s/step - loss: 0.0263 - dsc: 0.9737 - val_loss: 0.9997 - val_dsc: 2.6821e-04
# Epoch 54/100
# 7/7 [==============================] - 87s 13s/step - loss: 0.0236 - dsc: 0.9764 - val_loss: 0.9997 - val_dsc: 3.1520e-04
# Epoch 55/100
# 7/7 [==============================] - 95s 13s/step - loss: 0.0203 - dsc: 0.9797 - val_loss: 0.9997 - val_dsc: 3.2153e-04
# Epoch 56/100
# 7/7 [==============================] - 87s 13s/step - loss: 0.0210 - dsc: 0.9790 - val_loss: 0.9997 - val_dsc: 3.4462e-04
# Epoch 57/100
# 7/7 [==============================] - 92s 13s/step - loss: 0.0233 - dsc: 0.9767 - val_loss: 0.9995 - val_dsc: 5.1585e-04
# Epoch 58/100
# 7/7 [==============================] - 93s 13s/step - loss: 0.0216 - dsc: 0.9784 - val_loss: 0.9936 - val_dsc: 0.0061
# Epoch 59/100
# 7/7 [==============================] - 87s 13s/step - loss: 0.0184 - dsc: 0.9816 - val_loss: 0.9991 - val_dsc: 8.5366e-04
# Epoch 60/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.0185 - dsc: 0.9815 - val_loss: 0.9944 - val_dsc: 0.0052
# Epoch 61/100
# 7/7 [==============================] - 72s 10s/step - loss: 0.0185 - dsc: 0.9815 - val_loss: 0.9971 - val_dsc: 0.0026
# Epoch 62/100
# 7/7 [==============================] - 73s 11s/step - loss: 0.0173 - dsc: 0.9827 - val_loss: 0.9692 - val_dsc: 0.0286
# Epoch 63/100
# 7/7 [==============================] - 79s 12s/step - loss: 0.0159 - dsc: 0.9841 - val_loss: 0.9649 - val_dsc: 0.0324
# Epoch 64/100
# 7/7 [==============================] - 79s 12s/step - loss: 0.0243 - dsc: 0.9757 - val_loss: 0.7833 - val_dsc: 0.2069
# Epoch 65/100
# 7/7 [==============================] - 85s 12s/step - loss: 0.0275 - dsc: 0.9725 - val_loss: 0.8440 - val_dsc: 0.1505
# Epoch 66/100
# 7/7 [==============================] - 85s 12s/step - loss: 0.0344 - dsc: 0.9656 - val_loss: 0.6270 - val_dsc: 0.3615
# Epoch 67/100
# 7/7 [==============================] - 86s 12s/step - loss: 0.0265 - dsc: 0.9735 - val_loss: 0.4881 - val_dsc: 0.5025
# Epoch 68/100
# 7/7 [==============================] - 82s 12s/step - loss: 0.0217 - dsc: 0.9783 - val_loss: 0.4979 - val_dsc: 0.4925
# Epoch 69/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.0196 - dsc: 0.9804 - val_loss: 0.5618 - val_dsc: 0.4276
# Epoch 70/100
# 7/7 [==============================] - 76s 11s/step - loss: 0.0174 - dsc: 0.9826 - val_loss: 0.5166 - val_dsc: 0.4733
# Epoch 71/100
# 7/7 [==============================] - 75s 11s/step - loss: 0.0206 - dsc: 0.9794 - val_loss: 0.5973 - val_dsc: 0.3924
# Epoch 72/100
# 7/7 [==============================] - 75s 11s/step - loss: 0.0179 - dsc: 0.9821 - val_loss: 0.4626 - val_dsc: 0.5290
# Epoch 73/100
# 7/7 [==============================] - 78s 11s/step - loss: 0.0185 - dsc: 0.9815 - val_loss: 0.4614 - val_dsc: 0.5296
# Epoch 74/100
# 7/7 [==============================] - 78s 11s/step - loss: 0.0143 - dsc: 0.9857 - val_loss: 0.4884 - val_dsc: 0.5027
# Epoch 75/100
# 7/7 [==============================] - 74s 11s/step - loss: 0.0171 - dsc: 0.9829 - val_loss: 0.4123 - val_dsc: 0.5798
# Epoch 76/100
# 7/7 [==============================] - 74s 11s/step - loss: 0.0131 - dsc: 0.9869 - val_loss: 0.3874 - val_dsc: 0.6054
# Epoch 77/100
# 7/7 [==============================] - 74s 11s/step - loss: 0.0152 - dsc: 0.9848 - val_loss: 0.4608 - val_dsc: 0.5311
# Epoch 78/100
# 7/7 [==============================] - 82s 12s/step - loss: 0.0131 - dsc: 0.9869 - val_loss: 0.3740 - val_dsc: 0.6195
# Epoch 79/100
# 7/7 [==============================] - 76s 11s/step - loss: 0.0121 - dsc: 0.9879 - val_loss: 0.3416 - val_dsc: 0.6525
# Epoch 80/100
# 7/7 [==============================] - 77s 11s/step - loss: 0.0110 - dsc: 0.9890 - val_loss: 0.3018 - val_dsc: 0.6935
# Epoch 81/100
# 7/7 [==============================] - 79s 11s/step - loss: 0.0117 - dsc: 0.9883 - val_loss: 0.2831 - val_dsc: 0.7128
# Epoch 82/100
# 7/7 [==============================] - 83s 12s/step - loss: 0.0113 - dsc: 0.9887 - val_loss: 0.3197 - val_dsc: 0.6746
# Epoch 83/100
# 7/7 [==============================] - 79s 11s/step - loss: 0.0108 - dsc: 0.9892 - val_loss: 0.2407 - val_dsc: 0.7549
# Epoch 84/100
# 7/7 [==============================] - 80s 11s/step - loss: 0.0104 - dsc: 0.9896 - val_loss: 0.2061 - val_dsc: 0.7912
# Epoch 85/100
# 7/7 [==============================] - 87s 13s/step - loss: 0.0101 - dsc: 0.9899 - val_loss: 0.1955 - val_dsc: 0.8024
# Epoch 86/100
# 7/7 [==============================] - 80s 12s/step - loss: 0.0101 - dsc: 0.9899 - val_loss: 0.1916 - val_dsc: 0.8064
# Epoch 87/100
# 7/7 [==============================] - 91s 13s/step - loss: 0.0101 - dsc: 0.9899 - val_loss: 0.1628 - val_dsc: 0.8357
# Epoch 88/100
# 7/7 [==============================] - 86s 12s/step - loss: 0.0091 - dsc: 0.9909 - val_loss: 0.1638 - val_dsc: 0.8344
# Epoch 89/100
# 7/7 [==============================] - 80s 12s/step - loss: 0.0105 - dsc: 0.9895 - val_loss: 0.1606 - val_dsc: 0.8373
# Epoch 90/100
# 7/7 [==============================] - 73s 11s/step - loss: 0.0092 - dsc: 0.9908 - val_loss: 0.1479 - val_dsc: 0.8503
# Epoch 91/100
# 7/7 [==============================] - 73s 11s/step - loss: 0.0086 - dsc: 0.9914 - val_loss: 0.1316 - val_dsc: 0.8665
# Epoch 92/100
# 7/7 [==============================] - 74s 11s/step - loss: 0.0148 - dsc: 0.9852 - val_loss: 0.1356 - val_dsc: 0.8625
# Epoch 93/100
# 7/7 [==============================] - 73s 11s/step - loss: 0.0111 - dsc: 0.9889 - val_loss: 0.1013 - val_dsc: 0.8972
# Epoch 94/100
# 7/7 [==============================] - 76s 11s/step - loss: 0.0100 - dsc: 0.9900 - val_loss: 0.1216 - val_dsc: 0.8757
# Epoch 95/100
# 7/7 [==============================] - 73s 11s/step - loss: 0.0096 - dsc: 0.9904 - val_loss: 0.0971 - val_dsc: 0.9012
# Epoch 96/100
# 7/7 [==============================] - 73s 11s/step - loss: 0.0108 - dsc: 0.9892 - val_loss: 0.0965 - val_dsc: 0.9014
# Epoch 97/100
# 7/7 [==============================] - 75s 11s/step - loss: 0.0085 - dsc: 0.9915 - val_loss: 0.1037 - val_dsc: 0.8937
# Epoch 98/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.0083 - dsc: 0.9917 - val_loss: 0.0964 - val_dsc: 0.9013
# Epoch 99/100
# 7/7 [==============================] - 88s 13s/step - loss: 0.0096 - dsc: 0.9904 - val_loss: 0.1062 - val_dsc: 0.8912
# Epoch 100/100
# 7/7 [==============================] - 90s 13s/step - loss: 0.0080 - dsc: 0.9920 - val_loss: 0.1021 - val_dsc: 0.8955

# %%
# Make predictions
t = now()
preds_3p = model.predict(X_test)
print('Testing time: %s' % (now() - t))
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0b07b08a60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0b07b08a60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 9s 4s/step
# Testing time: 0:00:10.189545

# %%
Representacion(history,epochnum,batchnum)
# Out:
# Training time: 0:00:10.203585

# %%
# Evaluate model
num_test = len(X_test)
# Calculate performance metrics
dsc_sc = np.zeros((num_test,1))
iou_sc = np.zeros_like(dsc_sc)
rec_sc = np.zeros_like(dsc_sc)
tn_sc = np.zeros_like(dsc_sc)
prec_sc = np.zeros_like(dsc_sc)
thresh = 0.5
for i in range(num_test):
    dsc_sc[i], iou_sc[i], rec_sc[i], prec_sc[i] = auc(Y_test[i], preds_3p[i] >thresh)
print('-'*30)
print('USING THRESHOLD', thresh)
print('\n DSC \t\t{0:^.3f} \n IOU \t\t{1:^.3f} \n Recall \t{2:^.3f} \n Precision\t{3:^.3f}'.format(
        np.sum(dsc_sc)/num_test,  
        np.sum(iou_sc)/num_test,  
        np.sum(rec_sc)/num_test,
        np.sum(prec_sc)/num_test))
    
# Confusion matrix
confusion = confusion_matrix(Y_test.ravel(),preds_3p.ravel()>thresh)
accuracy = 0
if float(np.sum(confusion))!=0:
    accuracy = float(confusion[0,0]+confusion[1,1])/float(np.sum(confusion))
print(' Global Acc \t{0:^.3f}'.format(accuracy))
    
# Area under the ROC curve
AUC_ROC = roc_auc_score(preds_3p.ravel()>thresh, Y_test.ravel())
print(' AUC ROC \t{0:^.3f}'.format(AUC_ROC))
print('\n')
print('*'*60)
    
# Save outputs 
numepochs = epochsn[-1]
dice_score = np.sum(dsc_sc)/num_test
iou_score = np.sum(iou_sc)/num_test
rec_score = np.sum(rec_sc)/num_test
prec_score = np.sum(prec_sc)/num_test
globacc_score = accuracy
auc_roc_score = AUC_ROC
# Out:
# ------------------------------
# USING THRESHOLD 0.5
#
#  DSC 		0.405
#  IOU 		0.270
#  Recall 	0.381
#  Precision	0.443
#  Global Acc 	0.934
#  AUC ROC 	0.946
#
#
# ************************************************************

# %%
preds_3p_val = model.predict(X_val)
# Evaluate model
num_val = len(X_val)
# Calculate performance metrics
dsc_sc = np.zeros((num_val,1))
iou_sc = np.zeros_like(dsc_sc)
rec_sc = np.zeros_like(dsc_sc)
tn_sc = np.zeros_like(dsc_sc)
prec_sc = np.zeros_like(dsc_sc)
thresh = 0.5
for i in range(num_val):
    dsc_sc[i], iou_sc[i], rec_sc[i], prec_sc[i] = auc(Y_val[i], preds_3p_val[i] >thresh)
print('-'*30)
print('USING THRESHOLD', thresh)
print('\n DSC \t\t{0:^.3f} \n IOU \t\t{1:^.3f} \n Recall \t{2:^.3f} \n Precision\t{3:^.3f}'.format(
        np.sum(dsc_sc)/num_val,  
        np.sum(iou_sc)/num_val,  
        np.sum(rec_sc)/num_val,
        np.sum(prec_sc)/num_val))
    
# Confusion matrix
confusion = confusion_matrix(Y_val.ravel(),preds_3p_val.ravel()>thresh)
accuracy = 0
if float(np.sum(confusion))!=0:
    accuracy = float(confusion[0,0]+confusion[1,1])/float(np.sum(confusion))
print(' Global Acc \t{0:^.3f}'.format(accuracy))
    
# Area under the ROC curve
AUC_ROC = roc_auc_score(preds_3p_val.ravel()>thresh, Y_val.ravel())
print(' AUC ROC \t{0:^.3f}'.format(AUC_ROC))
print('\n')
print('*'*60)
    
# Save outputs 
numepochs = epochsn[-1]
dice_score = np.sum(dsc_sc)/num_val
iou_score = np.sum(iou_sc)/num_val
rec_score = np.sum(rec_sc)/num_val
prec_score = np.sum(prec_sc)/num_val
globacc_score = accuracy
auc_roc_score = AUC_ROC
# Out:
# 1/1 [==============================] - 5s 5s/step
# ------------------------------
# USING THRESHOLD 0.5
#
#  DSC 		0.424
#  IOU 		0.288
#  Recall 	0.394
#  Precision	0.466
#  Global Acc 	0.936
#  AUC ROC 	0.952
#
#
# ************************************************************

# %% [markdown]
# # Representación de las mascaras

# %%
# To plot a set of images with predicted masks uncomment these lines
j = 0
import random
n1 = random.randint(0,len(X_test)-1)
n2 = random.randint(0,len(X_test)-1)
n3 = random.randint(0,len(X_test)-1)
n4 = random.randint(0,len(X_test)-1)
n5 = random.randint(0,len(X_test)-1)
n6 = random.randint(0,len(X_test)-1)
n7 = random.randint(0,len(X_test)-1)
n8 = random.randint(0,len(X_test)-1)
n9 = random.randint(0,len(X_test)-1)
n10 = random.randint(0,len(X_test)-1)

num_disp = [n1,n2,n3,n4,n5,n6,n7,n8,n9,n10]
j=1
plt.figure(figsize = (20,35))
for i in num_disp:
    plt.subplot(10,7,j)
    plt.imshow(np.squeeze(X_test[i]), cmap='gray')
    plt.title('Image')
    j +=1
    plt.subplot(10,7,j)
    plt.imshow(np.squeeze(Y_test[i]),cmap='gray')
    plt.title('Mask')
    j +=1
    plt.subplot(10,7,j)
    plt.imshow(np.squeeze(preds_UNET[i]),cmap='gray')
    plt.title('UNET')
    j +=1
    plt.subplot(10,7,j)
    plt.imshow(np.squeeze(preds_Dense[i]),cmap='gray')
    plt.title('UNET Dense')
    j +=1
    plt.subplot(10,7,j)
    plt.imshow(np.squeeze(preds_Att[i]),cmap='gray')
    plt.title('UNET Attended')
    j +=1
    plt.subplot(10,7,j)
    plt.imshow(np.squeeze(preds_DA[i]),cmap='gray')
    plt.title('UNET Dense + Att')
    j +=1
    plt.subplot(10,7,j)
    plt.imshow(np.squeeze(preds_3p[i]),cmap='gray')
    plt.title('UNET 3+')
    j +=1
    

plt.savefig('Masks.png')
plt.show()
