# %% [markdown]
# ## Modulos necesarios

# %%
import numpy as np
  
from keras.models import Model
from keras.layers import *
from keras.optimizers import *
import keras.backend as K
from keras.callbacks import EarlyStopping
import keras.utils as image

import tensorflow as tf

import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.metrics import roc_curve, roc_auc_score, confusion_matrix 
from sklearn.model_selection import KFold

import os
from os import listdir

import natsort # it may need to be installed by 'pip install natsort'

import datetime
now = datetime.datetime.now
# Out:
# 2023-12-11 17:06:01.853926: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-11 17:06:01.888445: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-11 17:06:01.888466: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-11 17:06:01.889593: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-11 17:06:01.895133: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-11 17:06:01.895697: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-11 17:06:08.343295: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import numpy as np
from glob import glob

from tensorflow import keras
from tensorflow.keras.backend import max
from tensorflow.keras.metrics import BinaryAccuracy
import keras_unet_collection
from keras_unet_collection import models, base, utils
import cv2

# %%
import keras.backend as K

# %% [markdown]
# # Extracción de imágenes

# %%
# Introduce parameters
img_row = 128
img_col = 128
img_chan = 1
epochnum = 120
batchnum = 16 
num_imgs = 780
input_size = (img_row, img_col, img_chan)

# %%
path = r'images/'

images = []
masks = []


for f_name in os.listdir(path):
    file_name = os.path.join(path,f_name)
    for name in os.listdir(file_name):
        file = os.path.join(file_name,name)
            
        if 'lesion' in file:
            tmp_mask = image.load_img(os.path.join(file_name, name, name + ".bmp"), target_size=(img_row, img_col, img_chan))
            mask = image.img_to_array(tmp_mask)
            mask = cv2.cvtColor(mask, cv2.COLOR_RGB2YCrCb)
            masks.append(mask[:,:,0]/255.0) 

        elif "Dermoscopic" in file:
            tmp_img = image.load_img(os.path.join(file_name, name, f_name + ".bmp"), target_size=(img_row, img_col, img_chan))
            img = image.img_to_array(tmp_img)
            img = cv2.cvtColor(img, cv2.COLOR_RGB2YCrCb)
            images.append(img[:,:,0]/255.0)

# %%
plt.imshow(images[0])
plt.title("Image")
plt.show()

plt.imshow(masks[0])  
plt.title("Mask")
plt.show()

# %%
num_imgs = len(images)
print(num_imgs)
num_masks = len(masks)
print(num_masks)
imgs = np.zeros((num_imgs, img_row, img_col))
masks_ = np.zeros_like(imgs)

for i in range(num_imgs):
    imgs[i] = images[i]
    
for i in range(num_imgs):
    masks_[i] = masks[i]
# Out:
# 200
# 200

# %% [markdown]
# # Métricas de evaluación y entrenamiento (DICE)

# %%
# Define loss and performance metrics
# Partially from Abraham and Khan (2019) - A Novel Focal Tversly Loss Function for Lesion Segmentation

# Dice score coefficient and Dice loss 
def dsc(y_true, y_pred):
    smooth = 1.
    # masks
    y_true_fm = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_fm * y_pred_f)
    score = (2. * intersection + smooth) / (K.sum(y_true_fm) + K.sum(y_pred_f) + smooth) 
    return score

def dice_loss(y_true, y_pred):
    loss = 1 - dsc(y_true, y_pred)
    return loss

# Performance metrics: Dice score coefficient, IOU, recall, sensitivity
def auc(y_true, y_pred):
    y_pred_pos = np.round(np.clip(y_pred, 0, 1))
    y_pred_neg = 1 - y_pred_pos
    y_pos = np.round(np.clip(y_true, 0, 1)) # ground truth
    y_neg = 1 - y_pos
    tp = np.sum(y_pos * y_pred_pos)
    tn = np.sum(y_neg * y_pred_neg)
    fp = np.sum(y_neg * y_pred_pos)
    fn = np.sum(y_pos * y_pred_neg)
    tpr = (tp + K.epsilon()) / (tp + fn + K.epsilon()) #recall
    tnr = (tn + K.epsilon()) / (tn + fp + K.epsilon())
    prec = (tp + K.epsilon()) / (tp + fp + K.epsilon()) #precision
    iou = (tp + K.epsilon()) / (tp + fn + fp + K.epsilon()) #intersection over union
    dsc = (2*tp + K.epsilon()) / (2*tp + fn + fp + K.epsilon()) #dice score
    return [dsc, iou, tpr, prec]

# %% [markdown]
# ## Separación train y test

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(imgs, masks_, test_size=0.3, random_state = 0)
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size = 0.2, random_state = 0)

# %% [markdown]
# ## Representación de train y validación

# %%
def Representacion(history,epochnum, batchnum):
    print('Training time: %s' % (now() - t))

    #Plot the loss and accuracy
    train_loss = history.history['loss']
    val_loss = history.history['val_loss']
    acc = history.history['dsc'] 
    val_acc = history.history['val_dsc']

    epochsn = np.arange(1, len(train_loss)+1,1)
    plt.figure(figsize = (12,5))
    plt.subplot(121)
    plt.plot(epochsn,train_loss, 'b', label='Training Loss')
    plt.plot(epochsn,val_loss, 'r', label='Validation Loss')
    plt.grid(color='gray', linestyle='--')
    plt.legend()
    plt.title('LOSS, Epochs={}, Batch={}'.format(epochnum, batchnum))
    plt.xlabel('Epochs')
    plt.ylabel('Loss')

    plt.subplot(122)
    plt.plot(epochsn, acc, 'b', label='Training Dice Coefficient')
    plt.plot(epochsn, val_acc, 'r', label='Validation Dice Coefficient')
    plt.grid(color='gray', linestyle='--')
    plt.legend()            
    plt.title('DSC, Epochs={}, Batch={}'.format(epochnum, batchnum))
    plt.xlabel('Epochs')
    plt.ylabel('CSC')
    
    plt.savefig('Graph_UNET.png')
    plt.show()

# %% [markdown]
# # Attention U-NET

# %%
from sklearn.model_selection import train_test_split
import tensorflow as tf

X_train, X_test, Y_train, Y_test = train_test_split(imgs, masks_, test_size=0.3, random_state = 0)
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size = 0.2, random_state = 0)

X_train = tf.convert_to_tensor(X_train)
X_train = tf.reshape(X_train, [X_train.shape[0],X_train.shape[1],X_train.shape[2],1])

X_test = tf.convert_to_tensor(X_test)
X_test = tf.reshape(X_test, [X_test.shape[0],X_test.shape[1],X_test.shape[2],1])

Y_train = tf.convert_to_tensor(Y_train)
Y_train = tf.reshape(Y_train, [Y_train.shape[0],Y_train.shape[1],Y_train.shape[2],1])

Y_test = tf.convert_to_tensor(Y_test)
Y_test = tf.reshape(Y_test, [Y_test.shape[0],Y_test.shape[1],Y_test.shape[2],1])

X_val = tf.convert_to_tensor(X_val)
X_val = tf.reshape(X_val, [X_val.shape[0],X_val.shape[1],X_val.shape[2],1])

Y_val = tf.convert_to_tensor(Y_val)
Y_val = tf.reshape(Y_val, [Y_val.shape[0],Y_val.shape[1],Y_val.shape[2],1])

# %%
import keras_unet_collection
from keras_unet_collection._model_att_unet_2d import att_unet_2d

model = att_unet_2d(input_size, filter_num=[64, 128, 256, 512, 1024], n_labels=1, 
                           stack_num_down=2, stack_num_up=1, activation='ReLU', 
                           atten_activation='ReLU', attention='add', output_activation='Sigmoid', 
                           batch_norm=True, pool='max', unpool=False,  
                           name='attunet')

# %%
model.compile(loss=dice_loss,optimizer=keras.optimizers.Adam(learning_rate=1e-4), metrics=dsc)
import datetime
now = datetime.datetime.now
t = now()

history = model.fit(X_train, Y_train, validation_data = (X_val, Y_val), batch_size=batchnum, epochs=epochnum, verbose=1)
# Out:
# Epoch 1/120
# 7/7 [==============================] - 41s 5s/step - loss: 0.5020 - dsc: 0.4980 - val_loss: 0.5949 - val_dsc: 0.4065
# Epoch 2/120
# 7/7 [==============================] - 28s 4s/step - loss: 0.3098 - dsc: 0.6902 - val_loss: 0.5996 - val_dsc: 0.4018
# Epoch 3/120
# 7/7 [==============================] - 32s 5s/step - loss: 0.2365 - dsc: 0.7635 - val_loss: 0.6079 - val_dsc: 0.3934
# Epoch 4/120
# 7/7 [==============================] - 30s 4s/step - loss: 0.2060 - dsc: 0.7940 - val_loss: 0.6195 - val_dsc: 0.3817
# Epoch 5/120
# 7/7 [==============================] - 29s 4s/step - loss: 0.1817 - dsc: 0.8183 - val_loss: 0.6340 - val_dsc: 0.3671
# Epoch 6/120
# 7/7 [==============================] - 29s 4s/step - loss: 0.1570 - dsc: 0.8430 - val_loss: 0.6480 - val_dsc: 0.3530
# Epoch 7/120
# 7/7 [==============================] - 29s 4s/step - loss: 0.1406 - dsc: 0.8594 - val_loss: 0.6638 - val_dsc: 0.3372
# Epoch 8/120
# 7/7 [==============================] - 29s 4s/step - loss: 0.1225 - dsc: 0.8775 - val_loss: 0.6800 - val_dsc: 0.3209
# Epoch 9/120
# 7/7 [==============================] - 31s 4s/step - loss: 0.1252 - dsc: 0.8748 - val_loss: 0.6944 - val_dsc: 0.3063
# Epoch 10/120
# 7/7 [==============================] - 30s 4s/step - loss: 0.1095 - dsc: 0.8905 - val_loss: 0.7108 - val_dsc: 0.2899
# Epoch 11/120
# 7/7 [==============================] - 36s 5s/step - loss: 0.1272 - dsc: 0.8728 - val_loss: 0.7276 - val_dsc: 0.2730
# Epoch 12/120
# 7/7 [==============================] - 29s 4s/step - loss: 0.0962 - dsc: 0.9038 - val_loss: 0.7458 - val_dsc: 0.2548
# Epoch 13/120
# 7/7 [==============================] - 30s 4s/step - loss: 0.0947 - dsc: 0.9053 - val_loss: 0.7615 - val_dsc: 0.2390
# Epoch 14/120
# 7/7 [==============================] - 30s 4s/step - loss: 0.1112 - dsc: 0.8888 - val_loss: 0.7701 - val_dsc: 0.2303
# Epoch 15/120
# 7/7 [==============================] - 31s 4s/step - loss: 0.1116 - dsc: 0.8884 - val_loss: 0.7838 - val_dsc: 0.2166
# Epoch 16/120
# 7/7 [==============================] - 31s 4s/step - loss: 0.0995 - dsc: 0.9005 - val_loss: 0.8018 - val_dsc: 0.1985
# Epoch 17/120
# 7/7 [==============================] - 32s 5s/step - loss: 0.0773 - dsc: 0.9227 - val_loss: 0.8153 - val_dsc: 0.1849
# Epoch 18/120
# 7/7 [==============================] - 31s 4s/step - loss: 0.0832 - dsc: 0.9168 - val_loss: 0.8273 - val_dsc: 0.1729
# Epoch 19/120
# 7/7 [==============================] - 31s 5s/step - loss: 0.0810 - dsc: 0.9190 - val_loss: 0.8419 - val_dsc: 0.1583
# Epoch 20/120
# 7/7 [==============================] - 32s 5s/step - loss: 0.0692 - dsc: 0.9308 - val_loss: 0.8535 - val_dsc: 0.1466
# Epoch 21/120
# 7/7 [==============================] - 32s 5s/step - loss: 0.0701 - dsc: 0.9299 - val_loss: 0.8640 - val_dsc: 0.1361
# Epoch 22/120
# 7/7 [==============================] - 31s 4s/step - loss: 0.0708 - dsc: 0.9292 - val_loss: 0.8732 - val_dsc: 0.1269
# Epoch 23/120
# 7/7 [==============================] - 31s 4s/step - loss: 0.0751 - dsc: 0.9249 - val_loss: 0.8754 - val_dsc: 0.1247
# Epoch 24/120
# 7/7 [==============================] - 31s 4s/step - loss: 0.0725 - dsc: 0.9275 - val_loss: 0.8863 - val_dsc: 0.1138
# Epoch 25/120
# 7/7 [==============================] - 31s 4s/step - loss: 0.0592 - dsc: 0.9408 - val_loss: 0.8963 - val_dsc: 0.1038
# Epoch 26/120
# 7/7 [==============================] - 31s 4s/step - loss: 0.0650 - dsc: 0.9350 - val_loss: 0.9012 - val_dsc: 0.0989
# Epoch 27/120
# 7/7 [==============================] - 31s 4s/step - loss: 0.0604 - dsc: 0.9396 - val_loss: 0.9061 - val_dsc: 0.0939
# Epoch 28/120
# 7/7 [==============================] - 31s 4s/step - loss: 0.0586 - dsc: 0.9414 - val_loss: 0.9072 - val_dsc: 0.0928
# Epoch 29/120
# 7/7 [==============================] - 31s 5s/step - loss: 0.0651 - dsc: 0.9349 - val_loss: 0.9191 - val_dsc: 0.0809
# Epoch 30/120
# 7/7 [==============================] - 33s 5s/step - loss: 0.0618 - dsc: 0.9382 - val_loss: 0.9244 - val_dsc: 0.0757
# Epoch 31/120
# 7/7 [==============================] - 31s 4s/step - loss: 0.0543 - dsc: 0.9457 - val_loss: 0.9281 - val_dsc: 0.0719
# Epoch 32/120
# 7/7 [==============================] - 31s 4s/step - loss: 0.0549 - dsc: 0.9451 - val_loss: 0.9307 - val_dsc: 0.0694
# Epoch 33/120
# 7/7 [==============================] - 31s 4s/step - loss: 0.0468 - dsc: 0.9532 - val_loss: 0.9360 - val_dsc: 0.0640
# Epoch 34/120
# 7/7 [==============================] - 31s 4s/step - loss: 0.0474 - dsc: 0.9526 - val_loss: 0.9388 - val_dsc: 0.0613
# Epoch 35/120
# 7/7 [==============================] - 31s 5s/step - loss: 0.0423 - dsc: 0.9577 - val_loss: 0.9415 - val_dsc: 0.0586
# Epoch 36/120
# 7/7 [==============================] - 32s 5s/step - loss: 0.0455 - dsc: 0.9545 - val_loss: 0.9428 - val_dsc: 0.0573
# Epoch 37/120
# 7/7 [==============================] - 31s 4s/step - loss: 0.0474 - dsc: 0.9526 - val_loss: 0.9440 - val_dsc: 0.0561
# Epoch 38/120
# 7/7 [==============================] - 30s 4s/step - loss: 0.0470 - dsc: 0.9530 - val_loss: 0.9478 - val_dsc: 0.0523
# Epoch 39/120
# 7/7 [==============================] - 30s 4s/step - loss: 0.0424 - dsc: 0.9576 - val_loss: 0.9513 - val_dsc: 0.0487
# Epoch 40/120
# 7/7 [==============================] - 31s 4s/step - loss: 0.0471 - dsc: 0.9529 - val_loss: 0.9529 - val_dsc: 0.0471
# Epoch 41/120
# 7/7 [==============================] - 32s 5s/step - loss: 0.0385 - dsc: 0.9615 - val_loss: 0.9582 - val_dsc: 0.0418
# Epoch 42/120
# 7/7 [==============================] - 33s 5s/step - loss: 0.0398 - dsc: 0.9602 - val_loss: 0.9564 - val_dsc: 0.0435
# Epoch 43/120
# 7/7 [==============================] - 31s 4s/step - loss: 0.0384 - dsc: 0.9616 - val_loss: 0.9600 - val_dsc: 0.0400
# Epoch 44/120
# 7/7 [==============================] - 29s 4s/step - loss: 0.0330 - dsc: 0.9670 - val_loss: 0.9555 - val_dsc: 0.0442
# Epoch 45/120
# 7/7 [==============================] - 30s 4s/step - loss: 0.0395 - dsc: 0.9605 - val_loss: 0.9550 - val_dsc: 0.0447
# Epoch 46/120
# 7/7 [==============================] - 30s 4s/step - loss: 0.0410 - dsc: 0.9590 - val_loss: 0.9322 - val_dsc: 0.0661
# Epoch 47/120
# 7/7 [==============================] - 30s 4s/step - loss: 0.0425 - dsc: 0.9575 - val_loss: 0.9394 - val_dsc: 0.0594
# Epoch 48/120
# 7/7 [==============================] - 30s 4s/step - loss: 0.0377 - dsc: 0.9623 - val_loss: 0.9530 - val_dsc: 0.0463
# Epoch 49/120
# 7/7 [==============================] - 31s 5s/step - loss: 0.0367 - dsc: 0.9633 - val_loss: 0.9184 - val_dsc: 0.0791
# Epoch 50/120
# 7/7 [==============================] - 29s 4s/step - loss: 0.0326 - dsc: 0.9674 - val_loss: 0.9280 - val_dsc: 0.0703
# Epoch 51/120
# 7/7 [==============================] - 30s 4s/step - loss: 0.0298 - dsc: 0.9702 - val_loss: 0.9064 - val_dsc: 0.0903
# Epoch 52/120
# 7/7 [==============================] - 30s 4s/step - loss: 0.0454 - dsc: 0.9546 - val_loss: 0.8494 - val_dsc: 0.1422
# Epoch 53/120
# 7/7 [==============================] - 29s 4s/step - loss: 0.0416 - dsc: 0.9584 - val_loss: 0.6187 - val_dsc: 0.3694
# Epoch 54/120
# 7/7 [==============================] - 30s 4s/step - loss: 0.0397 - dsc: 0.9603 - val_loss: 0.6984 - val_dsc: 0.2912
# Epoch 55/120
# 7/7 [==============================] - 30s 4s/step - loss: 0.0357 - dsc: 0.9643 - val_loss: 0.7821 - val_dsc: 0.2099
# Epoch 56/120
# 7/7 [==============================] - 30s 4s/step - loss: 0.0412 - dsc: 0.9588 - val_loss: 0.5766 - val_dsc: 0.4110
# Epoch 57/120
# 7/7 [==============================] - 30s 4s/step - loss: 0.0339 - dsc: 0.9661 - val_loss: 0.5344 - val_dsc: 0.4500
# Epoch 58/120
# 7/7 [==============================] - 30s 4s/step - loss: 0.0352 - dsc: 0.9648 - val_loss: 0.6784 - val_dsc: 0.3074
# Epoch 59/120
# 7/7 [==============================] - 32s 5s/step - loss: 0.0374 - dsc: 0.9626 - val_loss: 0.5324 - val_dsc: 0.4564
# Epoch 60/120
# 7/7 [==============================] - 31s 4s/step - loss: 0.0310 - dsc: 0.9690 - val_loss: 0.4290 - val_dsc: 0.5600
# Epoch 61/120
# 7/7 [==============================] - 31s 4s/step - loss: 0.0445 - dsc: 0.9555 - val_loss: 0.2742 - val_dsc: 0.7214
# Epoch 62/120
# 7/7 [==============================] - 31s 4s/step - loss: 0.0413 - dsc: 0.9587 - val_loss: 0.2597 - val_dsc: 0.7368
# Epoch 63/120
# 7/7 [==============================] - 30s 4s/step - loss: 0.0402 - dsc: 0.9598 - val_loss: 0.3401 - val_dsc: 0.6568
# Epoch 64/120
# 7/7 [==============================] - 31s 5s/step - loss: 0.0373 - dsc: 0.9627 - val_loss: 0.2101 - val_dsc: 0.7908
# Epoch 65/120
# 7/7 [==============================] - 31s 4s/step - loss: 0.0387 - dsc: 0.9613 - val_loss: 0.1743 - val_dsc: 0.8280
# Epoch 66/120
# 7/7 [==============================] - 30s 4s/step - loss: 0.0339 - dsc: 0.9661 - val_loss: 0.1634 - val_dsc: 0.8372
# Epoch 67/120
# 7/7 [==============================] - 31s 4s/step - loss: 0.0258 - dsc: 0.9742 - val_loss: 0.1682 - val_dsc: 0.8319
# Epoch 68/120
# 7/7 [==============================] - 32s 5s/step - loss: 0.0304 - dsc: 0.9696 - val_loss: 0.1578 - val_dsc: 0.8428
# Epoch 69/120
# 7/7 [==============================] - 31s 4s/step - loss: 0.0266 - dsc: 0.9734 - val_loss: 0.1724 - val_dsc: 0.8280
# Epoch 70/120
# 7/7 [==============================] - 30s 4s/step - loss: 0.0239 - dsc: 0.9761 - val_loss: 0.1830 - val_dsc: 0.8175
# Epoch 71/120
# 7/7 [==============================] - 31s 4s/step - loss: 0.0261 - dsc: 0.9739 - val_loss: 0.1679 - val_dsc: 0.8322
# Epoch 72/120
# 7/7 [==============================] - 30s 4s/step - loss: 0.0237 - dsc: 0.9763 - val_loss: 0.1848 - val_dsc: 0.8153
# Epoch 73/120
# 7/7 [==============================] - 29s 4s/step - loss: 0.0227 - dsc: 0.9773 - val_loss: 0.1490 - val_dsc: 0.8506
# Epoch 74/120
# 7/7 [==============================] - 31s 5s/step - loss: 0.0242 - dsc: 0.9758 - val_loss: 0.1678 - val_dsc: 0.8317
# Epoch 75/120
# 7/7 [==============================] - 31s 4s/step - loss: 0.0197 - dsc: 0.9803 - val_loss: 0.1440 - val_dsc: 0.8554
# Epoch 76/120
# 7/7 [==============================] - 30s 4s/step - loss: 0.0210 - dsc: 0.9790 - val_loss: 0.1436 - val_dsc: 0.8558
# Epoch 77/120
# 7/7 [==============================] - 30s 4s/step - loss: 0.0307 - dsc: 0.9693 - val_loss: 0.1309 - val_dsc: 0.8685
# Epoch 78/120
# 7/7 [==============================] - 31s 4s/step - loss: 0.0237 - dsc: 0.9763 - val_loss: 0.1132 - val_dsc: 0.8863
# Epoch 79/120
# 7/7 [==============================] - 31s 4s/step - loss: 0.0185 - dsc: 0.9815 - val_loss: 0.1155 - val_dsc: 0.8840
# Epoch 80/120
# 7/7 [==============================] - 31s 4s/step - loss: 0.0186 - dsc: 0.9814 - val_loss: 0.1061 - val_dsc: 0.8932
# Epoch 81/120
# 7/7 [==============================] - 30s 4s/step - loss: 0.0182 - dsc: 0.9818 - val_loss: 0.1047 - val_dsc: 0.8950
# Epoch 82/120
# 7/7 [==============================] - 30s 4s/step - loss: 0.0179 - dsc: 0.9821 - val_loss: 0.1170 - val_dsc: 0.8825
# Epoch 83/120
# 7/7 [==============================] - 29s 4s/step - loss: 0.0202 - dsc: 0.9798 - val_loss: 0.1016 - val_dsc: 0.8978
# Epoch 84/120
# 7/7 [==============================] - 31s 4s/step - loss: 0.0172 - dsc: 0.9828 - val_loss: 0.1113 - val_dsc: 0.8877
# Epoch 85/120
# 7/7 [==============================] - 30s 4s/step - loss: 0.0169 - dsc: 0.9831 - val_loss: 0.1122 - val_dsc: 0.8866
# Epoch 86/120
# 7/7 [==============================] - 30s 4s/step - loss: 0.0180 - dsc: 0.9820 - val_loss: 0.1072 - val_dsc: 0.8916
# Epoch 87/120
# 7/7 [==============================] - 31s 4s/step - loss: 0.0164 - dsc: 0.9836 - val_loss: 0.1067 - val_dsc: 0.8921
# Epoch 88/120
# 7/7 [==============================] - 32s 5s/step - loss: 0.0162 - dsc: 0.9838 - val_loss: 0.0988 - val_dsc: 0.8997
# Epoch 89/120
# 7/7 [==============================] - 33s 5s/step - loss: 0.0165 - dsc: 0.9835 - val_loss: 0.1034 - val_dsc: 0.8949
# Epoch 90/120
# 7/7 [==============================] - 32s 4s/step - loss: 0.0162 - dsc: 0.9838 - val_loss: 0.1015 - val_dsc: 0.8971
# Epoch 91/120
# 7/7 [==============================] - 31s 4s/step - loss: 0.0158 - dsc: 0.9842 - val_loss: 0.0947 - val_dsc: 0.9040
# Epoch 92/120
# 7/7 [==============================] - 31s 5s/step - loss: 0.0144 - dsc: 0.9856 - val_loss: 0.0978 - val_dsc: 0.9007
# Epoch 93/120
# 7/7 [==============================] - 31s 4s/step - loss: 0.0169 - dsc: 0.9831 - val_loss: 0.0985 - val_dsc: 0.9000
# Epoch 94/120
# 7/7 [==============================] - 32s 4s/step - loss: 0.0138 - dsc: 0.9862 - val_loss: 0.0917 - val_dsc: 0.9068
# Epoch 95/120
# 7/7 [==============================] - 31s 5s/step - loss: 0.0166 - dsc: 0.9834 - val_loss: 0.0928 - val_dsc: 0.9055
# Epoch 96/120
# 7/7 [==============================] - 32s 5s/step - loss: 0.0145 - dsc: 0.9855 - val_loss: 0.0922 - val_dsc: 0.9062
# Epoch 97/120
# 7/7 [==============================] - 32s 5s/step - loss: 0.0134 - dsc: 0.9866 - val_loss: 0.0894 - val_dsc: 0.9090
# Epoch 98/120
# 7/7 [==============================] - 32s 5s/step - loss: 0.0123 - dsc: 0.9877 - val_loss: 0.0897 - val_dsc: 0.9086
# Epoch 99/120
# 7/7 [==============================] - 32s 5s/step - loss: 0.0130 - dsc: 0.9870 - val_loss: 0.0898 - val_dsc: 0.9084
# Epoch 100/120
# 7/7 [==============================] - 33s 5s/step - loss: 0.0120 - dsc: 0.9880 - val_loss: 0.0889 - val_dsc: 0.9094
# Epoch 101/120
# 7/7 [==============================] - 31s 4s/step - loss: 0.0153 - dsc: 0.9847 - val_loss: 0.0880 - val_dsc: 0.9103
# Epoch 102/120
# 7/7 [==============================] - 30s 4s/step - loss: 0.0140 - dsc: 0.9860 - val_loss: 0.0862 - val_dsc: 0.9121
# Epoch 103/120
# 7/7 [==============================] - 30s 4s/step - loss: 0.0146 - dsc: 0.9854 - val_loss: 0.0871 - val_dsc: 0.9110
# Epoch 104/120
# 7/7 [==============================] - 32s 5s/step - loss: 0.0133 - dsc: 0.9867 - val_loss: 0.0858 - val_dsc: 0.9123
# Epoch 105/120
# 7/7 [==============================] - 32s 5s/step - loss: 0.0135 - dsc: 0.9865 - val_loss: 0.0858 - val_dsc: 0.9123
# Epoch 106/120
# 7/7 [==============================] - 31s 4s/step - loss: 0.0136 - dsc: 0.9864 - val_loss: 0.0834 - val_dsc: 0.9147
# Epoch 107/120
# 7/7 [==============================] - 31s 4s/step - loss: 0.0113 - dsc: 0.9887 - val_loss: 0.0855 - val_dsc: 0.9126
# Epoch 108/120
# 7/7 [==============================] - 29s 4s/step - loss: 0.0114 - dsc: 0.9886 - val_loss: 0.0842 - val_dsc: 0.9139
# Epoch 109/120
# 7/7 [==============================] - 30s 4s/step - loss: 0.0107 - dsc: 0.9893 - val_loss: 0.0817 - val_dsc: 0.9165
# Epoch 110/120
# 7/7 [==============================] - 30s 4s/step - loss: 0.0127 - dsc: 0.9873 - val_loss: 0.0812 - val_dsc: 0.9170
# Epoch 111/120
# 7/7 [==============================] - 30s 4s/step - loss: 0.0108 - dsc: 0.9892 - val_loss: 0.0790 - val_dsc: 0.9194
# Epoch 112/120
# 7/7 [==============================] - 31s 4s/step - loss: 0.0117 - dsc: 0.9883 - val_loss: 0.0815 - val_dsc: 0.9167
# Epoch 113/120
# 7/7 [==============================] - 31s 4s/step - loss: 0.0125 - dsc: 0.9875 - val_loss: 0.0848 - val_dsc: 0.9135
# Epoch 114/120
# 7/7 [==============================] - 32s 5s/step - loss: 0.0104 - dsc: 0.9896 - val_loss: 0.0834 - val_dsc: 0.9150
# Epoch 115/120
# 7/7 [==============================] - 30s 4s/step - loss: 0.0111 - dsc: 0.9889 - val_loss: 0.0835 - val_dsc: 0.9148
# Epoch 116/120
# 7/7 [==============================] - 31s 4s/step - loss: 0.0105 - dsc: 0.9895 - val_loss: 0.0823 - val_dsc: 0.9159
# Epoch 117/120
# 7/7 [==============================] - 32s 5s/step - loss: 0.0098 - dsc: 0.9902 - val_loss: 0.0783 - val_dsc: 0.9199
# Epoch 118/120
# 7/7 [==============================] - 30s 4s/step - loss: 0.0121 - dsc: 0.9879 - val_loss: 0.0784 - val_dsc: 0.9198
# Epoch 119/120
# 7/7 [==============================] - 30s 4s/step - loss: 0.0096 - dsc: 0.9904 - val_loss: 0.0794 - val_dsc: 0.9188
# Epoch 120/120
# 7/7 [==============================] - 30s 4s/step - loss: 0.0092 - dsc: 0.9908 - val_loss: 0.0814 - val_dsc: 0.9168

# %%
# Make predictions
t = now()
preds_Att = model.predict(X_test)
print('Testing time: %s' % (now() - t))
# Out:
# 2/2 [==============================] - 4s 2s/step
# Testing time: 0:00:03.846114

# %%
Representacion(history,epochnum,batchnum)
# Out:
# Training time: 0:00:03.849049

# %%
from tensorflow.python.ops.numpy_ops import np_config
np_config.enable_numpy_behavior()
# Evaluate model
num_test = len(X_test)
# Calculate performance metrics
dsc_sc = np.zeros((num_test,1))
iou_sc = np.zeros_like(dsc_sc)
rec_sc = np.zeros_like(dsc_sc)
tn_sc = np.zeros_like(dsc_sc)
prec_sc = np.zeros_like(dsc_sc)
thresh = 0.5
for i in range(num_test):
    dsc_sc[i], iou_sc[i], rec_sc[i], prec_sc[i] = auc(Y_test[i], preds_Att[i] >thresh)
print('-'*30)
print('USING THRESHOLD', thresh)
print('\n DSC \t\t{0:^.3f} \n IOU \t\t{1:^.3f} \n Recall \t{2:^.3f} \n Precision\t{3:^.3f}'.format(
        np.sum(dsc_sc)/num_test,  
        np.sum(iou_sc)/num_test,  
        np.sum(rec_sc)/num_test,
        np.sum(prec_sc)/num_test))
    
# Confusion matrix
confusion = confusion_matrix(Y_test.ravel(),preds_Att.ravel()>thresh)
accuracy = 0
if float(np.sum(confusion))!=0:
    accuracy = float(confusion[0,0]+confusion[1,1])/float(np.sum(confusion))
print(' Global Acc \t{0:^.3f}'.format(accuracy))
    
# Area under the ROC curve
AUC_ROC = roc_auc_score(preds_Att.ravel()>thresh, Y_test.ravel())
print(' AUC ROC \t{0:^.3f}'.format(AUC_ROC))
print('\n')
print('*'*60)
    

dice_score = np.sum(dsc_sc)/num_test
iou_score = np.sum(iou_sc)/num_test
rec_score = np.sum(rec_sc)/num_test
prec_score = np.sum(prec_sc)/num_test
globacc_score = accuracy
auc_roc_score = AUC_ROC
# Out:
# ------------------------------
# USING THRESHOLD 0.5
#
#  DSC 		0.924
#  IOU 		0.863
#  Recall 	0.911
#  Precision	0.948
#  Global Acc 	0.950
#  AUC ROC 	0.952
#
#
# ************************************************************

# %%
preds_Att_val = model.predict(X_val)
num_val = len(X_val)
# Calculate performance metrics
dsc_sc = np.zeros((num_val,1))
iou_sc = np.zeros_like(dsc_sc)
rec_sc = np.zeros_like(dsc_sc)
tn_sc = np.zeros_like(dsc_sc)
prec_sc = np.zeros_like(dsc_sc)
thresh = 0.5
for i in range(num_val):
    dsc_sc[i], iou_sc[i], rec_sc[i], prec_sc[i] = auc(Y_val[i], preds_Att_val[i] >thresh)
print('-'*30)
print('USING THRESHOLD', thresh)
print('\n DSC \t\t{0:^.3f} \n IOU \t\t{1:^.3f} \n Recall \t{2:^.3f} \n Precision\t{3:^.3f}'.format(
        np.sum(dsc_sc)/num_val,  
        np.sum(iou_sc)/num_val,  
        np.sum(rec_sc)/num_val,
        np.sum(prec_sc)/num_val))
    
# Confusion matrix
confusion = confusion_matrix(Y_val.ravel(),preds_Att_val.ravel()>thresh)
accuracy = 0
if float(np.sum(confusion))!=0:
    accuracy = float(confusion[0,0]+confusion[1,1])/float(np.sum(confusion))
print(' Global Acc \t{0:^.3f}'.format(accuracy))
    
# Area under the ROC curve
AUC_ROC = roc_auc_score(preds_Att_val.ravel()>thresh, Y_val.ravel())
print(' AUC ROC \t{0:^.3f}'.format(AUC_ROC))
print('\n')
print('*'*60)
    
# Save outputs 

dice_score = np.sum(dsc_sc)/num_val
iou_score = np.sum(iou_sc)/num_val
rec_score = np.sum(rec_sc)/num_val
prec_score = np.sum(prec_sc)/num_val
globacc_score = accuracy
auc_roc_score = AUC_ROC
# Out:
# 1/1 [==============================] - 2s 2s/step
# ------------------------------
# USING THRESHOLD 0.5
#
#  DSC 		0.923
#  IOU 		0.861
#  Recall 	0.889
#  Precision	0.968
#  Global Acc 	0.950
#  AUC ROC 	0.957
#
#
# ************************************************************

# %% [markdown]
# # U-NET Dense + Attended

# %%
from keras.layers import *

def DenseBlock(channels,inputs):

    conv1_1 = Conv2D(channels, (1, 1),activation=None, padding='same')(inputs)
    conv1_1=BatchActivate(conv1_1)
    conv1_2 = Conv2D(channels//4, (3, 3), activation=None, padding='same')(conv1_1)
    conv1_2 = BatchActivate(conv1_2)

    conv2=concatenate([inputs,conv1_2])
    conv2_1 = Conv2D(channels, (1, 1), activation=None, padding='same')(conv2)
    conv2_1 = BatchActivate(conv2_1)
    conv2_2 = Conv2D(channels // 4, (3, 3), activation=None, padding='same')(conv2_1)
    conv2_2 = BatchActivate(conv2_2)

    conv3 = concatenate([inputs, conv1_2,conv2_2])
    conv3_1 = Conv2D(channels, (1, 1), activation=None, padding='same')(conv3)
    conv3_1 = BatchActivate(conv3_1)
    conv3_2 = Conv2D(channels // 4, (3, 3), activation=None, padding='same')(conv3_1)
    conv3_2 = BatchActivate(conv3_2)

    conv4 = concatenate([inputs, conv1_2, conv2_2,conv3_2])
    conv4_1 = Conv2D(channels, (1, 1), activation=None, padding='same')(conv4)
    conv4_1 = BatchActivate(conv4_1)
    conv4_2 = Conv2D(channels // 4, (3, 3), activation=None, padding='same')(conv4_1)
    conv4_2 = BatchActivate(conv4_2)
    result=concatenate([inputs,conv1_2, conv2_2,conv3_2,conv4_2])
    return result

def BatchActivate(x):
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

def Attention_gate(g, s, num_filters):
    Wg = Conv2D(num_filters, 1, padding="same")(g)
    Wg = BatchNormalization()(Wg)
 
    Ws = Conv2D(num_filters, 1, padding="same")(s)
    Ws = BatchNormalization()(Ws)
    
    w = Add()([Wg,Ws])
 
    out = Activation("relu")(w)
    out = Conv2D(num_filters, 1, padding="same")(out)
    out = Activation("sigmoid")(out)
    return Multiply()([out,s])

# %%
from keras.optimizers import *
from keras.models import *

def DenseUNet_AttGate(start_neurons=16, keep_prob=0.9,block_size=7,lr=1e-3):

    inputs = Input(shape=input_size)
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(inputs)
    conv1 = BatchActivate(conv1)
    conv1 = DenseBlock(start_neurons * 1, conv1)
    pool1 = MaxPooling2D((2, 2))(conv1)

    conv2 = DenseBlock(start_neurons * 2, pool1)
    pool2 = MaxPooling2D((2, 2))(conv2)

    conv3 = DenseBlock(start_neurons * 4, pool2)
    pool3 = MaxPooling2D((2, 2))(conv3)


    convm = DenseBlock(start_neurons * 8, pool3)


    deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same")(convm)
    Att3 = Attention_gate(conv3,deconv3,start_neurons * 4)  
    uconv3 = concatenate([deconv3, Att3])
    uconv3 = Conv2D(start_neurons * 4, (1, 1), activation=None, padding="same")(uconv3)
    uconv3 = BatchActivate(uconv3)
    uconv3 = DenseBlock(start_neurons * 4, uconv3)


    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(uconv3)
    Att2 = Attention_gate(conv2,deconv2,start_neurons * 2)  
    uconv2 = concatenate([deconv2, Att2])
    uconv2 = Conv2D(start_neurons * 2, (1, 1), activation=None, padding="same")(uconv2)
    uconv2 = BatchActivate(uconv2)
    uconv2 = DenseBlock(start_neurons * 2, uconv2)

    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv2)
    Att1 = Attention_gate(conv1,deconv1,start_neurons * 1)  
    uconv1 = concatenate([deconv1, Att1])
    uconv1 = Conv2D(start_neurons * 1, (1, 1), activation=None, padding="same")(uconv1)
    uconv1 = BatchActivate(uconv1)
    uconv1 = DenseBlock(start_neurons * 1, uconv1)

    output_layer_noActi = Conv2D(1, (1, 1), padding="same", activation=None)(uconv1)
    output_layer = Activation('sigmoid')(output_layer_noActi)
    
    model = Model(inputs=inputs, outputs=output_layer)
    model.compile(optimizer=Adam(lr=1e-3), loss=dice_loss, metrics=[dsc])

    return model

# %%
from sklearn.model_selection import train_test_split
keras.backend.clear_session()
X_train, X_test, Y_train, Y_test = train_test_split(imgs, masks_, test_size=0.3, random_state = 0)
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size = 0.2, random_state = 0)
model2 = DenseUNet_AttGate()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
t = now()

history = model2.fit(X_train, Y_train, validation_data = (X_val, Y_val), batch_size=batchnum, epochs=epochnum, verbose=1)
# Out:
# Epoch 1/120
# 7/7 [==============================] - 27s 2s/step - loss: 0.4765 - dsc: 0.5235 - val_loss: 0.5923 - val_dsc: 0.4090
# Epoch 2/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.3477 - dsc: 0.6523 - val_loss: 0.5983 - val_dsc: 0.4030
# Epoch 3/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.3084 - dsc: 0.6916 - val_loss: 0.6091 - val_dsc: 0.3921
# Epoch 4/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.2582 - dsc: 0.7418 - val_loss: 0.6241 - val_dsc: 0.3771
# Epoch 5/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.2220 - dsc: 0.7780 - val_loss: 0.6444 - val_dsc: 0.3567
# Epoch 6/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.2107 - dsc: 0.7893 - val_loss: 0.6664 - val_dsc: 0.3345
# Epoch 7/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.1919 - dsc: 0.8081 - val_loss: 0.6905 - val_dsc: 0.3103
# Epoch 8/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.1876 - dsc: 0.8124 - val_loss: 0.7135 - val_dsc: 0.2872
# Epoch 9/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.1844 - dsc: 0.8156 - val_loss: 0.7357 - val_dsc: 0.2649
# Epoch 10/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.1557 - dsc: 0.8443 - val_loss: 0.7593 - val_dsc: 0.2412
# Epoch 11/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.1445 - dsc: 0.8555 - val_loss: 0.7797 - val_dsc: 0.2207
# Epoch 12/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.1390 - dsc: 0.8610 - val_loss: 0.7992 - val_dsc: 0.2011
# Epoch 13/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.1275 - dsc: 0.8725 - val_loss: 0.8188 - val_dsc: 0.1814
# Epoch 14/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.1464 - dsc: 0.8536 - val_loss: 0.8349 - val_dsc: 0.1654
# Epoch 15/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.1423 - dsc: 0.8577 - val_loss: 0.8536 - val_dsc: 0.1466
# Epoch 16/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.1287 - dsc: 0.8713 - val_loss: 0.8700 - val_dsc: 0.1302
# Epoch 17/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.1244 - dsc: 0.8756 - val_loss: 0.8807 - val_dsc: 0.1194
# Epoch 18/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.1271 - dsc: 0.8729 - val_loss: 0.8924 - val_dsc: 0.1077
# Epoch 19/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.1276 - dsc: 0.8724 - val_loss: 0.9063 - val_dsc: 0.0938
# Epoch 20/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.0991 - dsc: 0.9009 - val_loss: 0.9126 - val_dsc: 0.0875
# Epoch 21/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.1067 - dsc: 0.8933 - val_loss: 0.9218 - val_dsc: 0.0783
# Epoch 22/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.0924 - dsc: 0.9076 - val_loss: 0.9270 - val_dsc: 0.0731
# Epoch 23/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.0997 - dsc: 0.9003 - val_loss: 0.9333 - val_dsc: 0.0668
# Epoch 24/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.1017 - dsc: 0.8983 - val_loss: 0.9410 - val_dsc: 0.0591
# Epoch 25/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0824 - dsc: 0.9176 - val_loss: 0.9441 - val_dsc: 0.0559
# Epoch 26/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.0876 - dsc: 0.9124 - val_loss: 0.9504 - val_dsc: 0.0496
# Epoch 27/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.0688 - dsc: 0.9312 - val_loss: 0.9546 - val_dsc: 0.0454
# Epoch 28/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.0847 - dsc: 0.9153 - val_loss: 0.9578 - val_dsc: 0.0423
# Epoch 29/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0766 - dsc: 0.9234 - val_loss: 0.9619 - val_dsc: 0.0381
# Epoch 30/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0718 - dsc: 0.9282 - val_loss: 0.9641 - val_dsc: 0.0359
# Epoch 31/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0643 - dsc: 0.9357 - val_loss: 0.9678 - val_dsc: 0.0322
# Epoch 32/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0630 - dsc: 0.9370 - val_loss: 0.9686 - val_dsc: 0.0314
# Epoch 33/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0581 - dsc: 0.9419 - val_loss: 0.9710 - val_dsc: 0.0290
# Epoch 34/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0613 - dsc: 0.9387 - val_loss: 0.9729 - val_dsc: 0.0271
# Epoch 35/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.0671 - dsc: 0.9329 - val_loss: 0.9736 - val_dsc: 0.0263
# Epoch 36/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0747 - dsc: 0.9253 - val_loss: 0.9770 - val_dsc: 0.0230
# Epoch 37/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.0829 - dsc: 0.9171 - val_loss: 0.9817 - val_dsc: 0.0183
# Epoch 38/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.0769 - dsc: 0.9231 - val_loss: 0.9803 - val_dsc: 0.0197
# Epoch 39/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.0655 - dsc: 0.9345 - val_loss: 0.9850 - val_dsc: 0.0150
# Epoch 40/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.0644 - dsc: 0.9356 - val_loss: 0.9842 - val_dsc: 0.0158
# Epoch 41/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.0543 - dsc: 0.9457 - val_loss: 0.9722 - val_dsc: 0.0271
# Epoch 42/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0671 - dsc: 0.9329 - val_loss: 0.9768 - val_dsc: 0.0231
# Epoch 43/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0647 - dsc: 0.9353 - val_loss: 0.9849 - val_dsc: 0.0151
# Epoch 44/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0590 - dsc: 0.9410 - val_loss: 0.9842 - val_dsc: 0.0159
# Epoch 45/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0537 - dsc: 0.9463 - val_loss: 0.9744 - val_dsc: 0.0267
# Epoch 46/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0470 - dsc: 0.9530 - val_loss: 0.9869 - val_dsc: 0.0131
# Epoch 47/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.0463 - dsc: 0.9537 - val_loss: 0.9793 - val_dsc: 0.0205
# Epoch 48/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0493 - dsc: 0.9507 - val_loss: 0.9879 - val_dsc: 0.0120
# Epoch 49/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0525 - dsc: 0.9475 - val_loss: 0.9875 - val_dsc: 0.0125
# Epoch 50/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.0451 - dsc: 0.9549 - val_loss: 0.9629 - val_dsc: 0.0373
# Epoch 51/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0462 - dsc: 0.9538 - val_loss: 0.9634 - val_dsc: 0.0375
# Epoch 52/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0423 - dsc: 0.9577 - val_loss: 0.9799 - val_dsc: 0.0190
# Epoch 53/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0393 - dsc: 0.9607 - val_loss: 0.9714 - val_dsc: 0.0281
# Epoch 54/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0364 - dsc: 0.9636 - val_loss: 0.9392 - val_dsc: 0.0623
# Epoch 55/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0359 - dsc: 0.9641 - val_loss: 0.8959 - val_dsc: 0.1018
# Epoch 56/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0358 - dsc: 0.9642 - val_loss: 0.7044 - val_dsc: 0.2817
# Epoch 57/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.0330 - dsc: 0.9670 - val_loss: 0.7123 - val_dsc: 0.2717
# Epoch 58/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0309 - dsc: 0.9691 - val_loss: 0.6583 - val_dsc: 0.3266
# Epoch 59/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0330 - dsc: 0.9670 - val_loss: 0.4414 - val_dsc: 0.5481
# Epoch 60/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0378 - dsc: 0.9622 - val_loss: 0.6155 - val_dsc: 0.3691
# Epoch 61/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.0359 - dsc: 0.9641 - val_loss: 0.6072 - val_dsc: 0.3775
# Epoch 62/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0361 - dsc: 0.9639 - val_loss: 0.5233 - val_dsc: 0.4605
# Epoch 63/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0300 - dsc: 0.9700 - val_loss: 0.5114 - val_dsc: 0.4735
# Epoch 64/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0292 - dsc: 0.9708 - val_loss: 0.5215 - val_dsc: 0.4630
# Epoch 65/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0267 - dsc: 0.9733 - val_loss: 0.4995 - val_dsc: 0.4860
# Epoch 66/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0250 - dsc: 0.9750 - val_loss: 0.3536 - val_dsc: 0.6388
# Epoch 67/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.0280 - dsc: 0.9720 - val_loss: 0.3316 - val_dsc: 0.6598
# Epoch 68/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.0260 - dsc: 0.9740 - val_loss: 0.2552 - val_dsc: 0.7380
# Epoch 69/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.0256 - dsc: 0.9744 - val_loss: 0.3086 - val_dsc: 0.6850
# Epoch 70/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0262 - dsc: 0.9738 - val_loss: 0.2899 - val_dsc: 0.7040
# Epoch 71/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.0224 - dsc: 0.9776 - val_loss: 0.2208 - val_dsc: 0.7741
# Epoch 72/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0227 - dsc: 0.9773 - val_loss: 0.2331 - val_dsc: 0.7602
# Epoch 73/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.0215 - dsc: 0.9785 - val_loss: 0.2287 - val_dsc: 0.7644
# Epoch 74/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0213 - dsc: 0.9787 - val_loss: 0.2110 - val_dsc: 0.7840
# Epoch 75/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0200 - dsc: 0.9800 - val_loss: 0.1885 - val_dsc: 0.8075
# Epoch 76/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0232 - dsc: 0.9768 - val_loss: 0.1606 - val_dsc: 0.8363
# Epoch 77/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0234 - dsc: 0.9766 - val_loss: 0.1203 - val_dsc: 0.8784
# Epoch 78/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.0205 - dsc: 0.9795 - val_loss: 0.0994 - val_dsc: 0.8998
# Epoch 79/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.0214 - dsc: 0.9786 - val_loss: 0.0904 - val_dsc: 0.9095
# Epoch 80/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.0217 - dsc: 0.9783 - val_loss: 0.0994 - val_dsc: 0.9004
# Epoch 81/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.0223 - dsc: 0.9777 - val_loss: 0.1022 - val_dsc: 0.8965
# Epoch 82/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.0257 - dsc: 0.9743 - val_loss: 0.1020 - val_dsc: 0.8967
# Epoch 83/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0256 - dsc: 0.9744 - val_loss: 0.1210 - val_dsc: 0.8759
# Epoch 84/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0217 - dsc: 0.9783 - val_loss: 0.0642 - val_dsc: 0.9360
# Epoch 85/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0235 - dsc: 0.9765 - val_loss: 0.0796 - val_dsc: 0.9195
# Epoch 86/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0204 - dsc: 0.9796 - val_loss: 0.0799 - val_dsc: 0.9187
# Epoch 87/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.0228 - dsc: 0.9772 - val_loss: 0.0717 - val_dsc: 0.9277
# Epoch 88/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0244 - dsc: 0.9756 - val_loss: 0.1414 - val_dsc: 0.8551
# Epoch 89/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0236 - dsc: 0.9764 - val_loss: 0.0782 - val_dsc: 0.9198
# Epoch 90/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0239 - dsc: 0.9761 - val_loss: 0.1094 - val_dsc: 0.8844
# Epoch 91/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0199 - dsc: 0.9801 - val_loss: 0.1589 - val_dsc: 0.8377
# Epoch 92/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0184 - dsc: 0.9816 - val_loss: 0.1034 - val_dsc: 0.8956
# Epoch 93/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.0178 - dsc: 0.9822 - val_loss: 0.0793 - val_dsc: 0.9191
# Epoch 94/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0169 - dsc: 0.9831 - val_loss: 0.0699 - val_dsc: 0.9287
# Epoch 95/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0189 - dsc: 0.9811 - val_loss: 0.0705 - val_dsc: 0.9279
# Epoch 96/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0204 - dsc: 0.9796 - val_loss: 0.0917 - val_dsc: 0.9075
# Epoch 97/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0185 - dsc: 0.9815 - val_loss: 0.0888 - val_dsc: 0.9098
# Epoch 98/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0169 - dsc: 0.9831 - val_loss: 0.0920 - val_dsc: 0.9066
# Epoch 99/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0154 - dsc: 0.9846 - val_loss: 0.0923 - val_dsc: 0.9065
# Epoch 100/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0176 - dsc: 0.9824 - val_loss: 0.0865 - val_dsc: 0.9120
# Epoch 101/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0162 - dsc: 0.9838 - val_loss: 0.0923 - val_dsc: 0.9059
# Epoch 102/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0147 - dsc: 0.9853 - val_loss: 0.0977 - val_dsc: 0.9001
# Epoch 103/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0134 - dsc: 0.9866 - val_loss: 0.0983 - val_dsc: 0.8995
# Epoch 104/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0144 - dsc: 0.9856 - val_loss: 0.0930 - val_dsc: 0.9053
# Epoch 105/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.0137 - dsc: 0.9863 - val_loss: 0.0767 - val_dsc: 0.9217
# Epoch 106/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0124 - dsc: 0.9876 - val_loss: 0.0788 - val_dsc: 0.9193
# Epoch 107/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0114 - dsc: 0.9886 - val_loss: 0.0818 - val_dsc: 0.9160
# Epoch 108/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.0125 - dsc: 0.9875 - val_loss: 0.0811 - val_dsc: 0.9172
# Epoch 109/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0138 - dsc: 0.9862 - val_loss: 0.0711 - val_dsc: 0.9271
# Epoch 110/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.0118 - dsc: 0.9882 - val_loss: 0.0692 - val_dsc: 0.9291
# Epoch 111/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0121 - dsc: 0.9879 - val_loss: 0.0768 - val_dsc: 0.9213
# Epoch 112/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0112 - dsc: 0.9888 - val_loss: 0.0716 - val_dsc: 0.9268
# Epoch 113/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0103 - dsc: 0.9897 - val_loss: 0.0737 - val_dsc: 0.9245
# Epoch 114/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.0115 - dsc: 0.9885 - val_loss: 0.0697 - val_dsc: 0.9289
# Epoch 115/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0104 - dsc: 0.9896 - val_loss: 0.0666 - val_dsc: 0.9324
# Epoch 116/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.0104 - dsc: 0.9896 - val_loss: 0.0670 - val_dsc: 0.9318
# Epoch 117/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.0105 - dsc: 0.9895 - val_loss: 0.0670 - val_dsc: 0.9316
# Epoch 118/120
# 7/7 [==============================] - 12s 2s/step - loss: 0.0102 - dsc: 0.9898 - val_loss: 0.0689 - val_dsc: 0.9297
# Epoch 119/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.0095 - dsc: 0.9905 - val_loss: 0.0673 - val_dsc: 0.9316
# Epoch 120/120
# 7/7 [==============================] - 13s 2s/step - loss: 0.0099 - dsc: 0.9901 - val_loss: 0.0670 - val_dsc: 0.9316

# %%
# Make predictions
t = now()
preds_DA = model2.predict(X_test)
print('Testing time: %s' % (now() - t))
# Out:
# 2/2 [==============================] - 2s 524ms/step
# Testing time: 0:00:02.109554

# %%
Representacion(history,epochnum,batchnum)
# Out:
# Training time: 0:00:02.112684

# %%
# Evaluate model
num_test = len(X_test)
# Calculate performance metrics
dsc_sc = np.zeros((num_test,1))
iou_sc = np.zeros_like(dsc_sc)
rec_sc = np.zeros_like(dsc_sc)
tn_sc = np.zeros_like(dsc_sc)
prec_sc = np.zeros_like(dsc_sc)
thresh = 0.5
for i in range(num_test):
    dsc_sc[i], iou_sc[i], rec_sc[i], prec_sc[i] = auc(Y_test[i], preds_DA[i,:,:,0] >thresh)
print('-'*30)
print('USING THRESHOLD', thresh)
print('\n DSC \t\t{0:^.3f} \n IOU \t\t{1:^.3f} \n Recall \t{2:^.3f} \n Precision\t{3:^.3f}'.format(
        np.sum(dsc_sc)/num_test,  
        np.sum(iou_sc)/num_test,  
        np.sum(rec_sc)/num_test,
        np.sum(prec_sc)/num_test))
    
# Confusion matrix
confusion = confusion_matrix(Y_test.ravel(),preds_DA.ravel()>thresh)
accuracy = 0
if float(np.sum(confusion))!=0:
    accuracy = float(confusion[0,0]+confusion[1,1])/float(np.sum(confusion))
print(' Global Acc \t{0:^.3f}'.format(accuracy))
    
# Area under the ROC curve
AUC_ROC = roc_auc_score(preds_DA.ravel()>thresh, Y_test.ravel())
print(' AUC ROC \t{0:^.3f}'.format(AUC_ROC))
print('\n')
print('*'*60)
    
# Save outputs 

dice_score = np.sum(dsc_sc)/num_test
iou_score = np.sum(iou_sc)/num_test
rec_score = np.sum(rec_sc)/num_test
prec_score = np.sum(prec_sc)/num_test
globacc_score = accuracy
auc_roc_score = AUC_ROC
# Out:
# ------------------------------
# USING THRESHOLD 0.5
#
#  DSC 		0.931
#  IOU 		0.874
#  Recall 	0.932
#  Precision	0.939
#  Global Acc 	0.959
#  AUC ROC 	0.956
#
#
# ************************************************************

# %%
preds_DA_val = model2.predict(X_val)
num_val = len(X_val)
# Calculate performance metrics
dsc_sc = np.zeros((num_val,1))
iou_sc = np.zeros_like(dsc_sc)
rec_sc = np.zeros_like(dsc_sc)
tn_sc = np.zeros_like(dsc_sc)
prec_sc = np.zeros_like(dsc_sc)
thresh = 0.5
for i in range(num_val):
    dsc_sc[i], iou_sc[i], rec_sc[i], prec_sc[i] = auc(Y_val[i], preds_DA_val[i,:,:,0] >thresh)
print('-'*30)
print('USING THRESHOLD', thresh)
print('\n DSC \t\t{0:^.3f} \n IOU \t\t{1:^.3f} \n Recall \t{2:^.3f} \n Precision\t{3:^.3f}'.format(
        np.sum(dsc_sc)/num_val,  
        np.sum(iou_sc)/num_val,  
        np.sum(rec_sc)/num_val,
        np.sum(prec_sc)/num_val))
    
# Confusion matrix
confusion = confusion_matrix(Y_val.ravel(),preds_DA_val.ravel()>thresh)
accuracy = 0
if float(np.sum(confusion))!=0:
    accuracy = float(confusion[0,0]+confusion[1,1])/float(np.sum(confusion))
print(' Global Acc \t{0:^.3f}'.format(accuracy))
    
# Area under the ROC curve
AUC_ROC = roc_auc_score(preds_DA_val.ravel()>thresh, Y_val.ravel())
print(' AUC ROC \t{0:^.3f}'.format(AUC_ROC))
print('\n')
print('*'*60)
    
# Save outputs 

dice_score = np.sum(dsc_sc)/num_val
iou_score = np.sum(iou_sc)/num_val
rec_score = np.sum(rec_sc)/num_val
prec_score = np.sum(prec_sc)/num_val
globacc_score = accuracy
auc_roc_score = AUC_ROC
# Out:
# 1/1 [==============================] - 1s 521ms/step
# ------------------------------
# USING THRESHOLD 0.5
#
#  DSC 		0.934
#  IOU 		0.879
#  Recall 	0.919
#  Precision	0.956
#  Global Acc 	0.956
#  AUC ROC 	0.958
#
#
# ************************************************************

# %% [markdown]
# # Representación de las mascaras

# %%
import random

# Randomly select 10 unique indices from your test data
num_disp = random.sample(range(len(X_test)), 10)

# Create a 4x10 subplot grid (4 rows and 10 columns)
plt.figure(figsize=(20, 35))
for i, index in enumerate(num_disp):
    plt.subplot(10, 4, 4 * i + 1)
    plt.imshow(np.squeeze(X_test[index]), cmap='gray')
    plt.title('Image')

    plt.subplot(10, 4, 4 * i + 2)
    plt.imshow(np.squeeze(Y_test[index]), cmap='gray')
    plt.title('Mask')
    
    plt.subplot(10, 4, 4 * i + 3)
    plt.imshow(np.squeeze(preds_Att[index]), cmap='gray')
    plt.title('UNET Attended')
    
    plt.subplot(10, 4, 4 * i + 4)
    plt.imshow(np.squeeze(preds_DA[index]),cmap='gray')
    plt.title('UNET Dense + Att')

# Adjust the spacing between subplots for better readability
plt.tight_layout()

# Save or display the plot
plt.savefig('Masks.png')
plt.show()
