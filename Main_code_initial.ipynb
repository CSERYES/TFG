# %% [markdown]
# ## Modulos necesarios

# %%
import numpy as np
  
from keras.models import Model
from keras.layers import *
from keras.optimizers import *
import keras.backend as K
from keras.callbacks import EarlyStopping
import keras.utils as image

import tensorflow as tf

import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.metrics import roc_curve, roc_auc_score, confusion_matrix 
from sklearn.model_selection import KFold

import os
from os import listdir

import natsort # it may need to be installed by 'pip install natsort'

import datetime
now = datetime.datetime.now
# Out:
# 2023-12-05 18:22:00.347285: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-05 18:22:00.381288: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-05 18:22:00.381311: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-05 18:22:00.382323: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-05 18:22:00.387562: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-05 18:22:00.387911: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-05 18:22:03.659474: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import numpy as np
from glob import glob

from tensorflow import keras
from tensorflow.keras.backend import max
from tensorflow.keras.metrics import BinaryAccuracy
import keras_unet_collection
from keras_unet_collection import models, base, utils

# %%
import keras.backend as K

# %% [markdown]
# # Extracción de imágenes

# %%
# Introduce parameters
img_row = 128
img_col = 128
img_chan = 1
epochnum = 100
batchnum = 16 
num_imgs = 780
input_size = (img_row, img_col, img_chan)

# %%
path = r'images/'

images = []
masks = []


for f_name in os.listdir(path):
    file_name = os.path.join(path,f_name)
    for name in os.listdir(file_name):
        file = os.path.join(file_name,name)
            
        if 'lesion' in file:
            tmp_mask = image.load_img(os.path.join(file_name, name, name + ".bmp"), target_size=(img_row, img_col, img_chan))
            mask = image.img_to_array(tmp_mask)
            masks.append(mask[:,:,0]/255.0) 

        elif "Dermoscopic" in file:
            tmp_img = image.load_img(os.path.join(file_name, name, f_name + ".bmp"), target_size=(img_row, img_col, img_chan))
            img = image.img_to_array(tmp_img)
            images.append(img[:,:,0]/255.0)

# %%
num_imgs = len(images)
print(num_imgs)
num_masks = len(masks)
print(num_masks)
imgs = np.zeros((num_imgs, img_row, img_col))
masks_ = np.zeros_like(imgs)

for i in range(num_imgs):
    imgs[i] = images[i]
    
for i in range(num_imgs):
    masks_[i] = masks[i]
# Out:
# 200
# 200

# %% [markdown]
# # Métricas de evaluación y entrenamiento (DICE)

# %%
# Define loss and performance metrics
# Partially from Abraham and Khan (2019) - A Novel Focal Tversly Loss Function for Lesion Segmentation

# Dice score coefficient and Dice loss 
def dsc(y_true, y_pred):
    smooth = 1.
    # masks
    y_true_fm = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_fm * y_pred_f)
    score = (2. * intersection + smooth) / (K.sum(y_true_fm) + K.sum(y_pred_f) + smooth) 
    return score

def dice_loss(y_true, y_pred):
    loss = 1 - dsc(y_true, y_pred)
    return loss

# Performance metrics: Dice score coefficient, IOU, recall, sensitivity
def auc(y_true, y_pred):
    y_pred_pos = np.round(np.clip(y_pred, 0, 1))
    y_pred_neg = 1 - y_pred_pos
    y_pos = np.round(np.clip(y_true, 0, 1)) # ground truth
    y_neg = 1 - y_pos
    tp = np.sum(y_pos * y_pred_pos)
    tn = np.sum(y_neg * y_pred_neg)
    fp = np.sum(y_neg * y_pred_pos)
    fn = np.sum(y_pos * y_pred_neg)
    tpr = (tp + K.epsilon()) / (tp + fn + K.epsilon()) #recall
    tnr = (tn + K.epsilon()) / (tn + fp + K.epsilon())
    prec = (tp + K.epsilon()) / (tp + fp + K.epsilon()) #precision
    iou = (tp + K.epsilon()) / (tp + fn + fp + K.epsilon()) #intersection over union
    dsc = (2*tp + K.epsilon()) / (2*tp + fn + fp + K.epsilon()) #dice score
    return [dsc, iou, tpr, prec]

# %% [markdown]
# ## Separación train y test

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(imgs, masks_, test_size=0.3, random_state = 0)
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size = 0.2, random_state = 0)

# %% [markdown]
# ## Representación de train y validación

# %%
def Representacion(history,epochnum, batchnum):
    print('Training time: %s' % (now() - t))

    #Plot the loss and accuracy
    train_loss = history.history['loss']
    val_loss = history.history['val_loss']
    acc = history.history['dsc'] 
    val_acc = history.history['val_dsc']

    epochsn = np.arange(1, len(train_loss)+1,1)
    plt.figure(figsize = (12,5))
    plt.subplot(121)
    plt.plot(epochsn,train_loss, 'b', label='Training Loss')
    plt.plot(epochsn,val_loss, 'r', label='Validation Loss')
    plt.grid(color='gray', linestyle='--')
    plt.legend()
    plt.title('LOSS, Epochs={}, Batch={}'.format(epochnum, batchnum))
    plt.xlabel('Epochs')
    plt.ylabel('Loss')

    plt.subplot(122)
    plt.plot(epochsn, acc, 'b', label='Training Dice Coefficient')
    plt.plot(epochsn, val_acc, 'r', label='Validation Dice Coefficient')
    plt.grid(color='gray', linestyle='--')
    plt.legend()            
    plt.title('DSC, Epochs={}, Batch={}'.format(epochnum, batchnum))
    plt.xlabel('Epochs')
    plt.ylabel('CSC')
    
    plt.savefig('Graph_UNET.png')
    plt.show()

# %% [markdown]
# # U-NET

# %%
# Convolutional block for UNet
def ConvBlock(in_fmaps, num_fmaps):
    # Inputs: feature maps for UNet, number of output feature maps
    conv1 = Conv2D(num_fmaps, (3, 3), activation='relu', padding='same')(in_fmaps)
    conv_out = Conv2D(num_fmaps, (3, 3), activation='relu', padding='same')(conv1)
    return conv_out

# %%
# Build the model
def Network():
    
    input = Input(shape=input_size)

    conv1 = ConvBlock(input, 32)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = ConvBlock(pool1, 32)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = ConvBlock(pool2, 64)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = ConvBlock(pool3, 64)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = ConvBlock(pool4, 128)

    up6 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = ConvBlock(up6, 64)

    up7 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = ConvBlock(up7, 64)

    up8 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = ConvBlock(up8, 32)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = ConvBlock(up9, 32)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(conv9)

    model = Model(inputs = input, outputs = conv10)

    return model

# %%
model = Network()
model.compile(optimizer = Adam(learning_rate = 0.0001), loss = dice_loss, metrics = [dsc])

# %%
t = now()

history = model.fit(X_train, Y_train, validation_data = (X_val, Y_val), batch_size=batchnum, epochs=epochnum, verbose=1)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 9s 957ms/step - loss: 0.6036 - dsc: 0.3964 - val_loss: 0.5830 - val_dsc: 0.4184
# Epoch 2/100
# 7/7 [==============================] - 6s 850ms/step - loss: 0.5980 - dsc: 0.4020 - val_loss: 0.5780 - val_dsc: 0.4235
# Epoch 3/100
# 7/7 [==============================] - 6s 855ms/step - loss: 0.5931 - dsc: 0.4069 - val_loss: 0.5712 - val_dsc: 0.4303
# Epoch 4/100
# 7/7 [==============================] - 8s 1s/step - loss: 0.5836 - dsc: 0.4164 - val_loss: 0.5605 - val_dsc: 0.4411
# Epoch 5/100
# 7/7 [==============================] - 6s 898ms/step - loss: 0.5696 - dsc: 0.4304 - val_loss: 0.5390 - val_dsc: 0.4626
# Epoch 6/100
# 7/7 [==============================] - 7s 951ms/step - loss: 0.5440 - dsc: 0.4560 - val_loss: 0.4954 - val_dsc: 0.5066
# Epoch 7/100
# 7/7 [==============================] - 7s 970ms/step - loss: 0.5119 - dsc: 0.4881 - val_loss: 0.4858 - val_dsc: 0.5164
# Epoch 8/100
# 7/7 [==============================] - 6s 873ms/step - loss: 0.5147 - dsc: 0.4853 - val_loss: 0.4869 - val_dsc: 0.5153
# Epoch 9/100
# 7/7 [==============================] - 6s 839ms/step - loss: 0.5157 - dsc: 0.4843 - val_loss: 0.4866 - val_dsc: 0.5156
# Epoch 10/100
# 7/7 [==============================] - 6s 826ms/step - loss: 0.5142 - dsc: 0.4858 - val_loss: 0.4850 - val_dsc: 0.5172
# Epoch 11/100
# 7/7 [==============================] - 6s 810ms/step - loss: 0.5124 - dsc: 0.4876 - val_loss: 0.4839 - val_dsc: 0.5182
# Epoch 12/100
# 7/7 [==============================] - 6s 817ms/step - loss: 0.5132 - dsc: 0.4868 - val_loss: 0.4814 - val_dsc: 0.5207
# Epoch 13/100
# 7/7 [==============================] - 6s 810ms/step - loss: 0.5055 - dsc: 0.4945 - val_loss: 0.4761 - val_dsc: 0.5255
# Epoch 14/100
# 7/7 [==============================] - 6s 798ms/step - loss: 0.4994 - dsc: 0.5006 - val_loss: 0.4611 - val_dsc: 0.5408
# Epoch 15/100
# 7/7 [==============================] - 6s 808ms/step - loss: 0.4662 - dsc: 0.5338 - val_loss: 0.4009 - val_dsc: 0.5987
# Epoch 16/100
# 7/7 [==============================] - 6s 879ms/step - loss: 0.4108 - dsc: 0.5892 - val_loss: 0.3433 - val_dsc: 0.6538
# Epoch 17/100
# 7/7 [==============================] - 6s 821ms/step - loss: 0.3969 - dsc: 0.6031 - val_loss: 0.3693 - val_dsc: 0.6307
# Epoch 18/100
# 7/7 [==============================] - 6s 843ms/step - loss: 0.3740 - dsc: 0.6260 - val_loss: 0.3453 - val_dsc: 0.6512
# Epoch 19/100
# 7/7 [==============================] - 6s 836ms/step - loss: 0.3529 - dsc: 0.6471 - val_loss: 0.3217 - val_dsc: 0.6759
# Epoch 20/100
# 7/7 [==============================] - 6s 813ms/step - loss: 0.3421 - dsc: 0.6579 - val_loss: 0.3185 - val_dsc: 0.6779
# Epoch 21/100
# 7/7 [==============================] - 6s 826ms/step - loss: 0.3346 - dsc: 0.6654 - val_loss: 0.3158 - val_dsc: 0.6808
# Epoch 22/100
# 7/7 [==============================] - 6s 811ms/step - loss: 0.3373 - dsc: 0.6627 - val_loss: 0.3155 - val_dsc: 0.6802
# Epoch 23/100
# 7/7 [==============================] - 6s 816ms/step - loss: 0.3314 - dsc: 0.6686 - val_loss: 0.3154 - val_dsc: 0.6803
# Epoch 24/100
# 7/7 [==============================] - 6s 852ms/step - loss: 0.3328 - dsc: 0.6672 - val_loss: 0.3172 - val_dsc: 0.6801
# Epoch 25/100
# 7/7 [==============================] - 6s 814ms/step - loss: 0.3349 - dsc: 0.6651 - val_loss: 0.3099 - val_dsc: 0.6858
# Epoch 26/100
# 7/7 [==============================] - 6s 869ms/step - loss: 0.3312 - dsc: 0.6688 - val_loss: 0.3075 - val_dsc: 0.6882
# Epoch 27/100
# 7/7 [==============================] - 6s 821ms/step - loss: 0.3290 - dsc: 0.6710 - val_loss: 0.3118 - val_dsc: 0.6849
# Epoch 28/100
# 7/7 [==============================] - 6s 818ms/step - loss: 0.3322 - dsc: 0.6678 - val_loss: 0.3089 - val_dsc: 0.6876
# Epoch 29/100
# 7/7 [==============================] - 6s 819ms/step - loss: 0.3398 - dsc: 0.6602 - val_loss: 0.3065 - val_dsc: 0.6898
# Epoch 30/100
# 7/7 [==============================] - 6s 910ms/step - loss: 0.3261 - dsc: 0.6739 - val_loss: 0.3056 - val_dsc: 0.6905
# Epoch 31/100
# 7/7 [==============================] - 6s 863ms/step - loss: 0.3328 - dsc: 0.6672 - val_loss: 0.3036 - val_dsc: 0.6918
# Epoch 32/100
# 7/7 [==============================] - 6s 810ms/step - loss: 0.3243 - dsc: 0.6757 - val_loss: 0.3014 - val_dsc: 0.6942
# Epoch 33/100
# 7/7 [==============================] - 6s 806ms/step - loss: 0.3344 - dsc: 0.6656 - val_loss: 0.3022 - val_dsc: 0.6938
# Epoch 34/100
# 7/7 [==============================] - 6s 804ms/step - loss: 0.3301 - dsc: 0.6699 - val_loss: 0.3176 - val_dsc: 0.6777
# Epoch 35/100
# 7/7 [==============================] - 6s 799ms/step - loss: 0.3261 - dsc: 0.6739 - val_loss: 0.3065 - val_dsc: 0.6903
# Epoch 36/100
# 7/7 [==============================] - 6s 813ms/step - loss: 0.3298 - dsc: 0.6702 - val_loss: 0.3031 - val_dsc: 0.6924
# Epoch 37/100
# 7/7 [==============================] - 6s 868ms/step - loss: 0.3226 - dsc: 0.6774 - val_loss: 0.3048 - val_dsc: 0.6920
# Epoch 38/100
# 7/7 [==============================] - 6s 825ms/step - loss: 0.3343 - dsc: 0.6657 - val_loss: 0.2940 - val_dsc: 0.7016
# Epoch 39/100
# 7/7 [==============================] - 6s 868ms/step - loss: 0.3200 - dsc: 0.6800 - val_loss: 0.2968 - val_dsc: 0.6996
# Epoch 40/100
# 7/7 [==============================] - 6s 837ms/step - loss: 0.3060 - dsc: 0.6940 - val_loss: 0.3050 - val_dsc: 0.6905
# Epoch 41/100
# 7/7 [==============================] - 6s 814ms/step - loss: 0.3178 - dsc: 0.6822 - val_loss: 0.2861 - val_dsc: 0.7096
# Epoch 42/100
# 7/7 [==============================] - 6s 832ms/step - loss: 0.3136 - dsc: 0.6864 - val_loss: 0.2868 - val_dsc: 0.7093
# Epoch 43/100
# 7/7 [==============================] - 6s 823ms/step - loss: 0.3058 - dsc: 0.6942 - val_loss: 0.2987 - val_dsc: 0.6977
# Epoch 44/100
# 7/7 [==============================] - 6s 828ms/step - loss: 0.2988 - dsc: 0.7012 - val_loss: 0.2748 - val_dsc: 0.7211
# Epoch 45/100
# 7/7 [==============================] - 6s 816ms/step - loss: 0.2938 - dsc: 0.7062 - val_loss: 0.2765 - val_dsc: 0.7205
# Epoch 46/100
# 7/7 [==============================] - 6s 817ms/step - loss: 0.2944 - dsc: 0.7056 - val_loss: 0.2520 - val_dsc: 0.7451
# Epoch 47/100
# 7/7 [==============================] - 6s 885ms/step - loss: 0.2618 - dsc: 0.7382 - val_loss: 0.2422 - val_dsc: 0.7544
# Epoch 48/100
# 7/7 [==============================] - 6s 822ms/step - loss: 0.2475 - dsc: 0.7525 - val_loss: 0.1951 - val_dsc: 0.8025
# Epoch 49/100
# 7/7 [==============================] - 6s 834ms/step - loss: 0.2261 - dsc: 0.7739 - val_loss: 0.1746 - val_dsc: 0.8235
# Epoch 50/100
# 7/7 [==============================] - 6s 852ms/step - loss: 0.1986 - dsc: 0.8014 - val_loss: 0.1622 - val_dsc: 0.8358
# Epoch 51/100
# 7/7 [==============================] - 6s 822ms/step - loss: 0.1981 - dsc: 0.8019 - val_loss: 0.1444 - val_dsc: 0.8541
# Epoch 52/100
# 7/7 [==============================] - 6s 811ms/step - loss: 0.1857 - dsc: 0.8143 - val_loss: 0.1309 - val_dsc: 0.8688
# Epoch 53/100
# 7/7 [==============================] - 6s 817ms/step - loss: 0.1934 - dsc: 0.8066 - val_loss: 0.1400 - val_dsc: 0.8587
# Epoch 54/100
# 7/7 [==============================] - 6s 815ms/step - loss: 0.1710 - dsc: 0.8290 - val_loss: 0.1301 - val_dsc: 0.8704
# Epoch 55/100
# 7/7 [==============================] - 6s 853ms/step - loss: 0.1753 - dsc: 0.8247 - val_loss: 0.1390 - val_dsc: 0.8597
# Epoch 56/100
# 7/7 [==============================] - 6s 815ms/step - loss: 0.1701 - dsc: 0.8299 - val_loss: 0.1237 - val_dsc: 0.8759
# Epoch 57/100
# 7/7 [==============================] - 6s 846ms/step - loss: 0.1691 - dsc: 0.8309 - val_loss: 0.1270 - val_dsc: 0.8718
# Epoch 58/100
# 7/7 [==============================] - 6s 837ms/step - loss: 0.1724 - dsc: 0.8276 - val_loss: 0.1269 - val_dsc: 0.8718
# Epoch 59/100
# 7/7 [==============================] - 6s 828ms/step - loss: 0.1764 - dsc: 0.8236 - val_loss: 0.1123 - val_dsc: 0.8888
# Epoch 60/100
# 7/7 [==============================] - 6s 866ms/step - loss: 0.1572 - dsc: 0.8428 - val_loss: 0.1151 - val_dsc: 0.8843
# Epoch 61/100
# 7/7 [==============================] - 6s 823ms/step - loss: 0.1551 - dsc: 0.8449 - val_loss: 0.1129 - val_dsc: 0.8864
# Epoch 62/100
# 7/7 [==============================] - 6s 829ms/step - loss: 0.1583 - dsc: 0.8417 - val_loss: 0.1126 - val_dsc: 0.8876
# Epoch 63/100
# 7/7 [==============================] - 6s 825ms/step - loss: 0.1529 - dsc: 0.8471 - val_loss: 0.1059 - val_dsc: 0.8940
# Epoch 64/100
# 7/7 [==============================] - 6s 820ms/step - loss: 0.1501 - dsc: 0.8499 - val_loss: 0.1069 - val_dsc: 0.8925
# Epoch 65/100
# 7/7 [==============================] - 6s 823ms/step - loss: 0.1520 - dsc: 0.8480 - val_loss: 0.1135 - val_dsc: 0.8856
# Epoch 66/100
# 7/7 [==============================] - 6s 810ms/step - loss: 0.1475 - dsc: 0.8525 - val_loss: 0.1053 - val_dsc: 0.8940
# Epoch 67/100
# 7/7 [==============================] - 6s 814ms/step - loss: 0.1465 - dsc: 0.8535 - val_loss: 0.1085 - val_dsc: 0.8923
# Epoch 68/100
# 7/7 [==============================] - 6s 880ms/step - loss: 0.1496 - dsc: 0.8504 - val_loss: 0.1167 - val_dsc: 0.8827
# Epoch 69/100
# 7/7 [==============================] - 6s 818ms/step - loss: 0.1479 - dsc: 0.8521 - val_loss: 0.0989 - val_dsc: 0.9010
# Epoch 70/100
# 7/7 [==============================] - 6s 828ms/step - loss: 0.1439 - dsc: 0.8561 - val_loss: 0.1037 - val_dsc: 0.8952
# Epoch 71/100
# 7/7 [==============================] - 6s 841ms/step - loss: 0.1453 - dsc: 0.8547 - val_loss: 0.1039 - val_dsc: 0.8950
# Epoch 72/100
# 7/7 [==============================] - 6s 810ms/step - loss: 0.1379 - dsc: 0.8621 - val_loss: 0.0999 - val_dsc: 0.9009
# Epoch 73/100
# 7/7 [==============================] - 6s 815ms/step - loss: 0.1368 - dsc: 0.8632 - val_loss: 0.1062 - val_dsc: 0.8924
# Epoch 74/100
# 7/7 [==============================] - 6s 818ms/step - loss: 0.1381 - dsc: 0.8619 - val_loss: 0.1182 - val_dsc: 0.8799
# Epoch 75/100
# 7/7 [==============================] - 6s 823ms/step - loss: 0.1490 - dsc: 0.8510 - val_loss: 0.0967 - val_dsc: 0.9046
# Epoch 76/100
# 7/7 [==============================] - 6s 825ms/step - loss: 0.1337 - dsc: 0.8663 - val_loss: 0.0994 - val_dsc: 0.9001
# Epoch 77/100
# 7/7 [==============================] - 6s 808ms/step - loss: 0.1305 - dsc: 0.8695 - val_loss: 0.0964 - val_dsc: 0.9031
# Epoch 78/100
# 7/7 [==============================] - 6s 856ms/step - loss: 0.1330 - dsc: 0.8670 - val_loss: 0.0903 - val_dsc: 0.9098
# Epoch 79/100
# 7/7 [==============================] - 6s 833ms/step - loss: 0.1301 - dsc: 0.8699 - val_loss: 0.0940 - val_dsc: 0.9054
# Epoch 80/100
# 7/7 [==============================] - 6s 825ms/step - loss: 0.1245 - dsc: 0.8755 - val_loss: 0.0839 - val_dsc: 0.9167
# Epoch 81/100
# 7/7 [==============================] - 6s 869ms/step - loss: 0.1222 - dsc: 0.8778 - val_loss: 0.0909 - val_dsc: 0.9086
# Epoch 82/100
# 7/7 [==============================] - 6s 813ms/step - loss: 0.1196 - dsc: 0.8804 - val_loss: 0.0831 - val_dsc: 0.9171
# Epoch 83/100
# 7/7 [==============================] - 6s 829ms/step - loss: 0.1123 - dsc: 0.8877 - val_loss: 0.0838 - val_dsc: 0.9165
# Epoch 84/100
# 7/7 [==============================] - 6s 818ms/step - loss: 0.1130 - dsc: 0.8870 - val_loss: 0.0847 - val_dsc: 0.9150
# Epoch 85/100
# 7/7 [==============================] - 6s 820ms/step - loss: 0.1145 - dsc: 0.8855 - val_loss: 0.0873 - val_dsc: 0.9123
# Epoch 86/100
# 7/7 [==============================] - 6s 824ms/step - loss: 0.1117 - dsc: 0.8883 - val_loss: 0.0764 - val_dsc: 0.9240
# Epoch 87/100
# 7/7 [==============================] - 6s 835ms/step - loss: 0.1154 - dsc: 0.8846 - val_loss: 0.0900 - val_dsc: 0.9087
# Epoch 88/100
# 7/7 [==============================] - 6s 829ms/step - loss: 0.1129 - dsc: 0.8871 - val_loss: 0.0796 - val_dsc: 0.9209
# Epoch 89/100
# 7/7 [==============================] - 6s 873ms/step - loss: 0.1135 - dsc: 0.8865 - val_loss: 0.0833 - val_dsc: 0.9159
# Epoch 90/100
# 7/7 [==============================] - 6s 819ms/step - loss: 0.1136 - dsc: 0.8864 - val_loss: 0.0988 - val_dsc: 0.9006
# Epoch 91/100
# 7/7 [==============================] - 6s 831ms/step - loss: 0.1175 - dsc: 0.8825 - val_loss: 0.1162 - val_dsc: 0.8835
# Epoch 92/100
# 7/7 [==============================] - 6s 825ms/step - loss: 0.1203 - dsc: 0.8797 - val_loss: 0.0819 - val_dsc: 0.9176
# Epoch 93/100
# 7/7 [==============================] - 6s 815ms/step - loss: 0.1173 - dsc: 0.8827 - val_loss: 0.1033 - val_dsc: 0.8946
# Epoch 94/100
# 7/7 [==============================] - 6s 816ms/step - loss: 0.1173 - dsc: 0.8827 - val_loss: 0.0794 - val_dsc: 0.9219
# Epoch 95/100
# 7/7 [==============================] - 6s 825ms/step - loss: 0.1104 - dsc: 0.8896 - val_loss: 0.0901 - val_dsc: 0.9082
# Epoch 96/100
# 7/7 [==============================] - 6s 817ms/step - loss: 0.1114 - dsc: 0.8886 - val_loss: 0.0890 - val_dsc: 0.9100
# Epoch 97/100
# 7/7 [==============================] - 6s 823ms/step - loss: 0.1104 - dsc: 0.8896 - val_loss: 0.0914 - val_dsc: 0.9081
# Epoch 98/100
# 7/7 [==============================] - 6s 821ms/step - loss: 0.1118 - dsc: 0.8882 - val_loss: 0.0824 - val_dsc: 0.9171
# Epoch 99/100
# 7/7 [==============================] - 6s 893ms/step - loss: 0.1066 - dsc: 0.8934 - val_loss: 0.0822 - val_dsc: 0.9187
# Epoch 100/100
# 7/7 [==============================] - 6s 815ms/step - loss: 0.1024 - dsc: 0.8976 - val_loss: 0.0841 - val_dsc: 0.9151

# %%
# Make predictions
t = now()
preds_UNET = model.predict(X_test)
print('Testing time: %s' % (now() - t))
print(len(X_train[112:140]))
# Out:
# 2/2 [==============================] - 1s 207ms/step
# Testing time: 0:00:00.656761
# 0

# %%
Representacion(history,epochnum, batchnum)
# Out:
# Training time: 0:00:00.660666

# %%
train_loss = history.history['loss']
epochsn = np.arange(1, len(train_loss)+1,1)
# Evaluate model
num_test = len(X_test)

# Calculate performance metrics
dsc_sc = np.zeros((num_test,1))
iou_sc = np.zeros_like(dsc_sc)
rec_sc = np.zeros_like(dsc_sc)
tn_sc = np.zeros_like(dsc_sc)
prec_sc = np.zeros_like(dsc_sc)
thresh = 0.5
for i in range(num_test):
    dsc_sc[i], iou_sc[i], rec_sc[i], prec_sc[i] = auc(Y_test[i], preds_UNET[i,:,:,0] >thresh)
print('-'*30)
print('USING THRESHOLD', thresh)
print('\n DSC \t\t{0:^.3f} \n IOU \t\t{1:^.3f} \n Recall \t{2:^.3f} \n Precision\t{3:^.3f}'.format(
        np.sum(dsc_sc)/num_test,  
        np.sum(iou_sc)/num_test,  
        np.sum(rec_sc)/num_test,
        np.sum(prec_sc)/num_test))
    
# Confusion matrix
confusion = confusion_matrix(Y_test.ravel(),preds_UNET.ravel()>thresh)
accuracy = 0
if float(np.sum(confusion))!=0:
    accuracy = float(confusion[0,0]+confusion[1,1])/float(np.sum(confusion))
print(' Global Acc \t{0:^.3f}'.format(accuracy))
    
# Area under the ROC curve
AUC_ROC = roc_auc_score(preds_UNET.ravel()>thresh, Y_test.ravel())
print(' AUC ROC \t{0:^.3f}'.format(AUC_ROC))
print('\n')
print('*'*60)
    
# Save outputs 
numepochs = epochsn[-1]
dice_score = np.sum(dsc_sc)/num_test
iou_score = np.sum(iou_sc)/num_test
rec_score = np.sum(rec_sc)/num_test
prec_score = np.sum(prec_sc)/num_test
globacc_score = accuracy
auc_roc_score = AUC_ROC
# Out:
# ------------------------------
# USING THRESHOLD 0.5
#
#  DSC 		0.864
#  IOU 		0.771
#  Recall 	0.905
#  Precision	0.853
#  Global Acc 	0.922
#  AUC ROC 	0.908
#
#
# ************************************************************

# %%
preds_UNET_val = model.predict(X_val)
val_loss = history.history['val_loss']
epochsn = np.arange(1, len(val_loss)+1,1)
# Evaluate model
num_val = len(X_val)

# Calculate performance metrics
dsc_sc = np.zeros((num_val,1))
iou_sc = np.zeros_like(dsc_sc)
rec_sc = np.zeros_like(dsc_sc)
tn_sc = np.zeros_like(dsc_sc)
prec_sc = np.zeros_like(dsc_sc)
thresh = 0.5
for i in range(num_val):
    dsc_sc[i], iou_sc[i], rec_sc[i], prec_sc[i] = auc(Y_test[i], preds_UNET_val[i,:,:,0] >thresh)
print('-'*30)
print('USING THRESHOLD', thresh)
print('\n DSC \t\t{0:^.3f} \n IOU \t\t{1:^.3f} \n Recall \t{2:^.3f} \n Precision\t{3:^.3f}'.format(
        np.sum(dsc_sc)/num_val,  
        np.sum(iou_sc)/num_val,  
        np.sum(rec_sc)/num_val,
        np.sum(prec_sc)/num_val))
    
# Confusion matrix
confusion = confusion_matrix(Y_val.ravel(),preds_UNET_val.ravel()>thresh)
accuracy = 0
if float(np.sum(confusion))!=0:
    accuracy = float(confusion[0,0]+confusion[1,1])/float(np.sum(confusion))
print(' Global Acc \t{0:^.3f}'.format(accuracy))
    
# Area under the ROC curve
AUC_ROC = roc_auc_score(preds_UNET_val.ravel()>thresh, Y_val.ravel())
print(' AUC ROC \t{0:^.3f}'.format(AUC_ROC))
print('\n')
print('*'*60)
    
# Save outputs 
numepochs = epochsn[-1]
dice_score = np.sum(dsc_sc)/num_val
iou_score = np.sum(iou_sc)/num_val
rec_score = np.sum(rec_sc)/num_val
prec_score = np.sum(prec_sc)/num_val
globacc_score = accuracy
auc_roc_score = AUC_ROC
# Out:
# 1/1 [==============================] - 0s 265ms/step
# ------------------------------
# USING THRESHOLD 0.5
#
#  DSC 		0.492
#  IOU 		0.353
#  Recall 	0.652
#  Precision	0.628
#  Global Acc 	0.942
#  AUC ROC 	0.933
#
#
# ************************************************************

# %% [markdown]
# # U-NET Dense

# %%
from keras.layers import *

def DenseBlock(channels,inputs):

    conv1_1 = Conv2D(channels, (1, 1),activation=None, padding='same')(inputs)
    conv1_1=BatchActivate(conv1_1)
    conv1_2 = Conv2D(channels//4, (3, 3), activation=None, padding='same')(conv1_1)
    conv1_2 = BatchActivate(conv1_2)

    conv2=concatenate([inputs,conv1_2])
    conv2_1 = Conv2D(channels, (1, 1), activation=None, padding='same')(conv2)
    conv2_1 = BatchActivate(conv2_1)
    conv2_2 = Conv2D(channels // 4, (3, 3), activation=None, padding='same')(conv2_1)
    conv2_2 = BatchActivate(conv2_2)

    conv3 = concatenate([inputs, conv1_2,conv2_2])
    conv3_1 = Conv2D(channels, (1, 1), activation=None, padding='same')(conv3)
    conv3_1 = BatchActivate(conv3_1)
    conv3_2 = Conv2D(channels // 4, (3, 3), activation=None, padding='same')(conv3_1)
    conv3_2 = BatchActivate(conv3_2)

    conv4 = concatenate([inputs, conv1_2, conv2_2,conv3_2])
    conv4_1 = Conv2D(channels, (1, 1), activation=None, padding='same')(conv4)
    conv4_1 = BatchActivate(conv4_1)
    conv4_2 = Conv2D(channels // 4, (3, 3), activation=None, padding='same')(conv4_1)
    conv4_2 = BatchActivate(conv4_2)
    result=concatenate([inputs,conv1_2, conv2_2,conv3_2,conv4_2])
    return result

def BatchActivate(x):
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

# %%
from keras.optimizers import *
from keras.models import *

def DenseUNet(start_neurons=16, keep_prob=0.9,block_size=7,lr=1e-3):

    inputs = Input(shape=input_size)
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(inputs)
    conv1 = BatchActivate(conv1)
    conv1 = DenseBlock(start_neurons * 1, conv1)
    pool1 = MaxPooling2D((2, 2))(conv1)

    conv2 = DenseBlock(start_neurons * 2, pool1)
    pool2 = MaxPooling2D((2, 2))(conv2)

    conv3 = DenseBlock(start_neurons * 4, pool2)
    pool3 = MaxPooling2D((2, 2))(conv3)


    convm = DenseBlock(start_neurons * 8, pool3)


    deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same")(convm)
    uconv3 = concatenate([deconv3, conv3])
    uconv3 = Conv2D(start_neurons * 4, (1, 1), activation=None, padding="same")(uconv3)
    uconv3 = BatchActivate(uconv3)
    uconv3 = DenseBlock(start_neurons * 4, uconv3)


    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(uconv3)
    uconv2 = concatenate([deconv2, conv2])
    uconv2 = Conv2D(start_neurons * 2, (1, 1), activation=None, padding="same")(uconv2)
    uconv2 = BatchActivate(uconv2)
    uconv2 = DenseBlock(start_neurons * 2, uconv2)

    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    uconv1 = Conv2D(start_neurons * 1, (1, 1), activation=None, padding="same")(uconv1)
    uconv1 = BatchActivate(uconv1)
    uconv1 = DenseBlock(start_neurons * 1, uconv1)

    output_layer_noActi = Conv2D(1, (1, 1), padding="same", activation=None)(uconv1)
    output_layer = Activation('sigmoid')(output_layer_noActi)
    
    model = Model(inputs=inputs, outputs=output_layer)
    model.compile(optimizer=Adam(lr=1e-3), loss=dice_loss, metrics=[dsc])

    return model

# %%
model = DenseUNet()
t = now()

history = model.fit(X_train, Y_train, validation_data = (X_val, Y_val), batch_size=batchnum, epochs=epochnum, verbose=1)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/100
# 7/7 [==============================] - 25s 2s/step - loss: 0.5736 - dsc: 0.4264 - val_loss: 0.5979 - val_dsc: 0.4034
# Epoch 2/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.4173 - dsc: 0.5827 - val_loss: 0.6079 - val_dsc: 0.3934
# Epoch 3/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.3335 - dsc: 0.6665 - val_loss: 0.6261 - val_dsc: 0.3751
# Epoch 4/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.2863 - dsc: 0.7137 - val_loss: 0.6580 - val_dsc: 0.3430
# Epoch 5/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.2639 - dsc: 0.7361 - val_loss: 0.6960 - val_dsc: 0.3047
# Epoch 6/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.2500 - dsc: 0.7500 - val_loss: 0.7143 - val_dsc: 0.2864
# Epoch 7/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.2111 - dsc: 0.7889 - val_loss: 0.7515 - val_dsc: 0.2490
# Epoch 8/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.1979 - dsc: 0.8021 - val_loss: 0.7753 - val_dsc: 0.2251
# Epoch 9/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.1920 - dsc: 0.8080 - val_loss: 0.7937 - val_dsc: 0.2066
# Epoch 10/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.1647 - dsc: 0.8353 - val_loss: 0.8270 - val_dsc: 0.1733
# Epoch 11/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.1727 - dsc: 0.8273 - val_loss: 0.8484 - val_dsc: 0.1519
# Epoch 12/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.1583 - dsc: 0.8417 - val_loss: 0.7965 - val_dsc: 0.2019
# Epoch 13/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.1581 - dsc: 0.8419 - val_loss: 0.8818 - val_dsc: 0.1185
# Epoch 14/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.1423 - dsc: 0.8577 - val_loss: 0.8996 - val_dsc: 0.1005
# Epoch 15/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.1355 - dsc: 0.8645 - val_loss: 0.9129 - val_dsc: 0.0873
# Epoch 16/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.1318 - dsc: 0.8682 - val_loss: 0.9135 - val_dsc: 0.0867
# Epoch 17/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.1160 - dsc: 0.8840 - val_loss: 0.9259 - val_dsc: 0.0745
# Epoch 18/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.1148 - dsc: 0.8852 - val_loss: 0.8967 - val_dsc: 0.1030
# Epoch 19/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.1309 - dsc: 0.8691 - val_loss: 0.9165 - val_dsc: 0.0830
# Epoch 20/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.1077 - dsc: 0.8923 - val_loss: 0.9482 - val_dsc: 0.0518
# Epoch 21/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.1205 - dsc: 0.8795 - val_loss: 0.9217 - val_dsc: 0.0744
# Epoch 22/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.1040 - dsc: 0.8960 - val_loss: 0.8629 - val_dsc: 0.1320
# Epoch 23/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.1270 - dsc: 0.8730 - val_loss: 0.9613 - val_dsc: 0.0380
# Epoch 24/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.1113 - dsc: 0.8887 - val_loss: 0.9643 - val_dsc: 0.0349
# Epoch 25/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.1051 - dsc: 0.8949 - val_loss: 0.9315 - val_dsc: 0.0665
# Epoch 26/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.1019 - dsc: 0.8981 - val_loss: 0.9559 - val_dsc: 0.0425
# Epoch 27/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.0956 - dsc: 0.9044 - val_loss: 0.8659 - val_dsc: 0.1243
# Epoch 28/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.0926 - dsc: 0.9074 - val_loss: 0.8623 - val_dsc: 0.1270
# Epoch 29/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.1016 - dsc: 0.8984 - val_loss: 0.8149 - val_dsc: 0.1725
# Epoch 30/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0901 - dsc: 0.9099 - val_loss: 0.8051 - val_dsc: 0.1839
# Epoch 31/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0922 - dsc: 0.9078 - val_loss: 0.5041 - val_dsc: 0.4936
# Epoch 32/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.0829 - dsc: 0.9171 - val_loss: 0.3998 - val_dsc: 0.5941
# Epoch 33/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.0779 - dsc: 0.9221 - val_loss: 0.3552 - val_dsc: 0.6414
# Epoch 34/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.0704 - dsc: 0.9296 - val_loss: 0.6979 - val_dsc: 0.2943
# Epoch 35/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0709 - dsc: 0.9291 - val_loss: 0.6387 - val_dsc: 0.3562
# Epoch 36/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.0837 - dsc: 0.9163 - val_loss: 0.4780 - val_dsc: 0.5204
# Epoch 37/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.0711 - dsc: 0.9289 - val_loss: 0.3250 - val_dsc: 0.6755
# Epoch 38/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.0679 - dsc: 0.9321 - val_loss: 0.4907 - val_dsc: 0.5082
# Epoch 39/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0704 - dsc: 0.9296 - val_loss: 0.5123 - val_dsc: 0.4862
# Epoch 40/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0687 - dsc: 0.9313 - val_loss: 0.4040 - val_dsc: 0.5900
# Epoch 41/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0693 - dsc: 0.9307 - val_loss: 0.4896 - val_dsc: 0.5106
# Epoch 42/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.0632 - dsc: 0.9368 - val_loss: 0.5715 - val_dsc: 0.4191
# Epoch 43/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.0748 - dsc: 0.9252 - val_loss: 0.6211 - val_dsc: 0.3746
# Epoch 44/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.0707 - dsc: 0.9293 - val_loss: 0.5847 - val_dsc: 0.4105
# Epoch 45/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0593 - dsc: 0.9407 - val_loss: 0.5107 - val_dsc: 0.4835
# Epoch 46/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.0552 - dsc: 0.9448 - val_loss: 0.4236 - val_dsc: 0.5705
# Epoch 47/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.0614 - dsc: 0.9386 - val_loss: 0.3970 - val_dsc: 0.6051
# Epoch 48/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.0774 - dsc: 0.9226 - val_loss: 0.4103 - val_dsc: 0.5882
# Epoch 49/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.0717 - dsc: 0.9283 - val_loss: 0.4262 - val_dsc: 0.5702
# Epoch 50/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.0748 - dsc: 0.9252 - val_loss: 0.4169 - val_dsc: 0.5825
# Epoch 51/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0750 - dsc: 0.9250 - val_loss: 0.4218 - val_dsc: 0.5753
# Epoch 52/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0639 - dsc: 0.9361 - val_loss: 0.3206 - val_dsc: 0.6759
# Epoch 53/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0572 - dsc: 0.9428 - val_loss: 0.3328 - val_dsc: 0.6633
# Epoch 54/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0582 - dsc: 0.9418 - val_loss: 0.2584 - val_dsc: 0.7375
# Epoch 55/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0595 - dsc: 0.9405 - val_loss: 0.1868 - val_dsc: 0.8107
# Epoch 56/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0617 - dsc: 0.9383 - val_loss: 0.2351 - val_dsc: 0.7611
# Epoch 57/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0530 - dsc: 0.9470 - val_loss: 0.2198 - val_dsc: 0.7752
# Epoch 58/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.0558 - dsc: 0.9442 - val_loss: 0.2310 - val_dsc: 0.7620
# Epoch 59/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.0626 - dsc: 0.9374 - val_loss: 0.2411 - val_dsc: 0.7559
# Epoch 60/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0550 - dsc: 0.9450 - val_loss: 0.1643 - val_dsc: 0.8308
# Epoch 61/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0536 - dsc: 0.9464 - val_loss: 0.1938 - val_dsc: 0.8024
# Epoch 62/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0544 - dsc: 0.9456 - val_loss: 0.3153 - val_dsc: 0.6833
# Epoch 63/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0528 - dsc: 0.9472 - val_loss: 0.2606 - val_dsc: 0.7358
# Epoch 64/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.0476 - dsc: 0.9524 - val_loss: 0.2209 - val_dsc: 0.7741
# Epoch 65/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.0510 - dsc: 0.9490 - val_loss: 0.2069 - val_dsc: 0.7881
# Epoch 66/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0494 - dsc: 0.9506 - val_loss: 0.2310 - val_dsc: 0.7670
# Epoch 67/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0503 - dsc: 0.9497 - val_loss: 0.2075 - val_dsc: 0.7885
# Epoch 68/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0428 - dsc: 0.9572 - val_loss: 0.2550 - val_dsc: 0.7458
# Epoch 69/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.0569 - dsc: 0.9431 - val_loss: 0.1781 - val_dsc: 0.8202
# Epoch 70/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0632 - dsc: 0.9368 - val_loss: 0.2770 - val_dsc: 0.7162
# Epoch 71/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0448 - dsc: 0.9552 - val_loss: 0.2299 - val_dsc: 0.7637
# Epoch 72/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.0431 - dsc: 0.9569 - val_loss: 0.2245 - val_dsc: 0.7684
# Epoch 73/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0387 - dsc: 0.9613 - val_loss: 0.2085 - val_dsc: 0.7855
# Epoch 74/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0405 - dsc: 0.9595 - val_loss: 0.2144 - val_dsc: 0.7830
# Epoch 75/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0379 - dsc: 0.9621 - val_loss: 0.2232 - val_dsc: 0.7781
# Epoch 76/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0365 - dsc: 0.9635 - val_loss: 0.1195 - val_dsc: 0.8775
# Epoch 77/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0440 - dsc: 0.9560 - val_loss: 0.1178 - val_dsc: 0.8798
# Epoch 78/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0370 - dsc: 0.9630 - val_loss: 0.1108 - val_dsc: 0.8866
# Epoch 79/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.0347 - dsc: 0.9653 - val_loss: 0.1053 - val_dsc: 0.8920
# Epoch 80/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.0346 - dsc: 0.9654 - val_loss: 0.1102 - val_dsc: 0.8872
# Epoch 81/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0346 - dsc: 0.9654 - val_loss: 0.1161 - val_dsc: 0.8822
# Epoch 82/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0409 - dsc: 0.9591 - val_loss: 0.1355 - val_dsc: 0.8635
# Epoch 83/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0475 - dsc: 0.9525 - val_loss: 0.1095 - val_dsc: 0.8903
# Epoch 84/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0469 - dsc: 0.9531 - val_loss: 0.1129 - val_dsc: 0.8859
# Epoch 85/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.0485 - dsc: 0.9515 - val_loss: 0.1617 - val_dsc: 0.8384
# Epoch 86/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0454 - dsc: 0.9546 - val_loss: 0.1929 - val_dsc: 0.8070
# Epoch 87/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0419 - dsc: 0.9581 - val_loss: 0.1731 - val_dsc: 0.8266
# Epoch 88/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0360 - dsc: 0.9640 - val_loss: 0.1679 - val_dsc: 0.8324
# Epoch 89/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.0328 - dsc: 0.9672 - val_loss: 0.1115 - val_dsc: 0.8864
# Epoch 90/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0318 - dsc: 0.9682 - val_loss: 0.1088 - val_dsc: 0.8892
# Epoch 91/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.0325 - dsc: 0.9675 - val_loss: 0.1021 - val_dsc: 0.8960
# Epoch 92/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0321 - dsc: 0.9679 - val_loss: 0.1340 - val_dsc: 0.8646
# Epoch 93/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0284 - dsc: 0.9716 - val_loss: 0.1387 - val_dsc: 0.8591
# Epoch 94/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0267 - dsc: 0.9733 - val_loss: 0.1316 - val_dsc: 0.8675
# Epoch 95/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.0250 - dsc: 0.9750 - val_loss: 0.1075 - val_dsc: 0.8912
# Epoch 96/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.0261 - dsc: 0.9739 - val_loss: 0.1201 - val_dsc: 0.8783
# Epoch 97/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0307 - dsc: 0.9693 - val_loss: 0.1687 - val_dsc: 0.8305
# Epoch 98/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0330 - dsc: 0.9670 - val_loss: 0.1013 - val_dsc: 0.8961
# Epoch 99/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0299 - dsc: 0.9701 - val_loss: 0.0943 - val_dsc: 0.9053
# Epoch 100/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0270 - dsc: 0.9730 - val_loss: 0.0997 - val_dsc: 0.8993

# %%
# Make predictions
t = now()
preds_Dense = model.predict(X_test)
print('Testing time: %s' % (now() - t))
# Out:
# 2/2 [==============================] - 2s 433ms/step
# Testing time: 0:00:01.674531

# %%
Representacion(history,epochnum,batchnum)
# Out:
# Training time: 0:00:01.677911

# %%
from tensorflow.python.ops.numpy_ops import np_config
np_config.enable_numpy_behavior()
# Evaluate model
num_test = len(X_test)
# Calculate performance metrics
dsc_sc = np.zeros((num_test,1))
iou_sc = np.zeros_like(dsc_sc)
rec_sc = np.zeros_like(dsc_sc)
tn_sc = np.zeros_like(dsc_sc)
prec_sc = np.zeros_like(dsc_sc)
thresh = 0.5
for i in range(num_test):
    dsc_sc[i], iou_sc[i], rec_sc[i], prec_sc[i] = auc(Y_test[i], preds_Dense[i] >thresh)
print('-'*30)
print('USING THRESHOLD', thresh)
print('\n DSC \t\t{0:^.3f} \n IOU \t\t{1:^.3f} \n Recall \t{2:^.3f} \n Precision\t{3:^.3f}'.format(
        np.sum(dsc_sc)/num_test,  
        np.sum(iou_sc)/num_test,  
        np.sum(rec_sc)/num_test,
        np.sum(prec_sc)/num_test))
    
# Confusion matrix
confusion = confusion_matrix(Y_test.ravel(),preds_Dense.ravel()>thresh)
accuracy = 0
if float(np.sum(confusion))!=0:
    accuracy = float(confusion[0,0]+confusion[1,1])/float(np.sum(confusion))
print(' Global Acc \t{0:^.3f}'.format(accuracy))
    
# Area under the ROC curve
AUC_ROC = roc_auc_score(preds_Dense.ravel()>thresh, Y_test.ravel())
print(' AUC ROC \t{0:^.3f}'.format(AUC_ROC))
print('\n')
print('*'*60)
    
# Save outputs 
numepochs = epochsn[-1]
dice_score = np.sum(dsc_sc)/num_test
iou_score = np.sum(iou_sc)/num_test
rec_score = np.sum(rec_sc)/num_test
prec_score = np.sum(prec_sc)/num_test
globacc_score = accuracy
auc_roc_score = AUC_ROC
# Out:
# ------------------------------
# USING THRESHOLD 0.5
#
#  DSC 		0.392
#  IOU 		0.266
#  Recall 	0.372
#  Precision	0.469
#  Global Acc 	0.923
#  AUC ROC 	0.932
#
#
# ************************************************************

# %%
preds_Dense_val = model.predict(X_val)
# Evaluate model
num_val = len(X_val)
# Calculate performance metrics
dsc_sc = np.zeros((num_test,1))
iou_sc = np.zeros_like(dsc_sc)
rec_sc = np.zeros_like(dsc_sc)
tn_sc = np.zeros_like(dsc_sc)
prec_sc = np.zeros_like(dsc_sc)
thresh = 0.5
for i in range(num_val):
    dsc_sc[i], iou_sc[i], rec_sc[i], prec_sc[i] = auc(Y_val[i], preds_Dense_val[i] >thresh)
print('-'*30)
print('USING THRESHOLD', thresh)
print('\n DSC \t\t{0:^.3f} \n IOU \t\t{1:^.3f} \n Recall \t{2:^.3f} \n Precision\t{3:^.3f}'.format(
        np.sum(dsc_sc)/num_val,  
        np.sum(iou_sc)/num_val,  
        np.sum(rec_sc)/num_val,
        np.sum(prec_sc)/num_val))
    
# Confusion matrix
confusion = confusion_matrix(Y_val.ravel(),preds_Dense_val.ravel()>thresh)
accuracy = 0
if float(np.sum(confusion))!=0:
    accuracy = float(confusion[0,0]+confusion[1,1])/float(np.sum(confusion))
print(' Global Acc \t{0:^.3f}'.format(accuracy))
    
# Area under the ROC curve
AUC_ROC = roc_auc_score(preds_Dense_val.ravel()>thresh, Y_val.ravel())
print(' AUC ROC \t{0:^.3f}'.format(AUC_ROC))
print('\n')
print('*'*60)
    
# Save outputs 
numepochs = epochsn[-1]
dice_score = np.sum(dsc_sc)/num_val
iou_score = np.sum(iou_sc)/num_val
rec_score = np.sum(rec_sc)/num_val
prec_score = np.sum(prec_sc)/num_val
globacc_score = accuracy
auc_roc_score = AUC_ROC
# Out:
# 1/1 [==============================] - 0s 417ms/step
# ------------------------------
# USING THRESHOLD 0.5
#
#  DSC 		0.433
#  IOU 		0.297
#  Recall 	0.417
#  Precision	0.460
#  Global Acc 	0.936
#  AUC ROC 	0.941
#
#
# ************************************************************

# %% [markdown]
# # Attention U-NET

# %%
from sklearn.model_selection import train_test_split
import tensorflow as tf

X_train, X_test, Y_train, Y_test = train_test_split(imgs, masks_, test_size=0.3, random_state = 0)
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size = 0.2, random_state = 0)

X_train = tf.convert_to_tensor(X_train)
X_train = tf.reshape(X_train, [X_train.shape[0],X_train.shape[1],X_train.shape[2],1])

X_test = tf.convert_to_tensor(X_test)
X_test = tf.reshape(X_test, [X_test.shape[0],X_test.shape[1],X_test.shape[2],1])

Y_train = tf.convert_to_tensor(Y_train)
Y_train = tf.reshape(Y_train, [Y_train.shape[0],Y_train.shape[1],Y_train.shape[2],1])

Y_test = tf.convert_to_tensor(Y_test)
Y_test = tf.reshape(Y_test, [Y_test.shape[0],Y_test.shape[1],Y_test.shape[2],1])

X_val = tf.convert_to_tensor(X_val)
X_val = tf.reshape(X_val, [X_val.shape[0],X_val.shape[1],X_val.shape[2],1])

Y_val = tf.convert_to_tensor(Y_val)
Y_val = tf.reshape(Y_val, [Y_val.shape[0],Y_val.shape[1],Y_val.shape[2],1])

# %%
import keras_unet_collection
from keras_unet_collection._model_att_unet_2d import att_unet_2d

model = att_unet_2d(input_size, filter_num=[64, 128, 256, 512, 1024], n_labels=1, 
                           stack_num_down=2, stack_num_up=1, activation='ReLU', 
                           atten_activation='ReLU', attention='add', output_activation='Sigmoid', 
                           batch_norm=True, pool='max', unpool=False,  
                           name='attunet')

# %%
model.compile(loss=dice_loss,optimizer=keras.optimizers.Adam(learning_rate=1e-4), metrics=dsc)
import datetime
now = datetime.datetime.now
t = now()

history = model.fit(X_train, Y_train, validation_data = (X_val, Y_val), batch_size=batchnum, epochs=epochnum, verbose=1)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 38s 5s/step - loss: 0.4888 - dsc: 0.5112 - val_loss: 0.5942 - val_dsc: 0.4072
# Epoch 2/100
# 7/7 [==============================] - 36s 5s/step - loss: 0.3295 - dsc: 0.6705 - val_loss: 0.5987 - val_dsc: 0.4027
# Epoch 3/100
# 7/7 [==============================] - 31s 5s/step - loss: 0.2694 - dsc: 0.7306 - val_loss: 0.6055 - val_dsc: 0.3958
# Epoch 4/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.2084 - dsc: 0.7916 - val_loss: 0.6152 - val_dsc: 0.3861
# Epoch 5/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.2068 - dsc: 0.7932 - val_loss: 0.6270 - val_dsc: 0.3741
# Epoch 6/100
# 7/7 [==============================] - 31s 5s/step - loss: 0.1904 - dsc: 0.8096 - val_loss: 0.6418 - val_dsc: 0.3593
# Epoch 7/100
# 7/7 [==============================] - 31s 5s/step - loss: 0.1841 - dsc: 0.8159 - val_loss: 0.6564 - val_dsc: 0.3446
# Epoch 8/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.1663 - dsc: 0.8337 - val_loss: 0.6713 - val_dsc: 0.3296
# Epoch 9/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.1540 - dsc: 0.8460 - val_loss: 0.6863 - val_dsc: 0.3145
# Epoch 10/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.1374 - dsc: 0.8626 - val_loss: 0.7023 - val_dsc: 0.2985
# Epoch 11/100
# 7/7 [==============================] - 31s 5s/step - loss: 0.1207 - dsc: 0.8793 - val_loss: 0.7161 - val_dsc: 0.2846
# Epoch 12/100
# 7/7 [==============================] - 33s 5s/step - loss: 0.1139 - dsc: 0.8861 - val_loss: 0.7271 - val_dsc: 0.2735
# Epoch 13/100
# 7/7 [==============================] - 31s 4s/step - loss: 0.1181 - dsc: 0.8819 - val_loss: 0.7402 - val_dsc: 0.2604
# Epoch 14/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.1247 - dsc: 0.8753 - val_loss: 0.7543 - val_dsc: 0.2462
# Epoch 15/100
# 7/7 [==============================] - 31s 5s/step - loss: 0.1032 - dsc: 0.8968 - val_loss: 0.7716 - val_dsc: 0.2288
# Epoch 16/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0884 - dsc: 0.9116 - val_loss: 0.7819 - val_dsc: 0.2186
# Epoch 17/100
# 7/7 [==============================] - 31s 4s/step - loss: 0.0847 - dsc: 0.9153 - val_loss: 0.7944 - val_dsc: 0.2060
# Epoch 18/100
# 7/7 [==============================] - 32s 4s/step - loss: 0.1037 - dsc: 0.8963 - val_loss: 0.7994 - val_dsc: 0.2009
# Epoch 19/100
# 7/7 [==============================] - 31s 5s/step - loss: 0.0820 - dsc: 0.9180 - val_loss: 0.8124 - val_dsc: 0.1879
# Epoch 20/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0935 - dsc: 0.9065 - val_loss: 0.8288 - val_dsc: 0.1715
# Epoch 21/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0882 - dsc: 0.9118 - val_loss: 0.8383 - val_dsc: 0.1619
# Epoch 22/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0820 - dsc: 0.9180 - val_loss: 0.8486 - val_dsc: 0.1517
# Epoch 23/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0884 - dsc: 0.9116 - val_loss: 0.8555 - val_dsc: 0.1447
# Epoch 24/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0833 - dsc: 0.9167 - val_loss: 0.8745 - val_dsc: 0.1258
# Epoch 25/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0667 - dsc: 0.9333 - val_loss: 0.8748 - val_dsc: 0.1254
# Epoch 26/100
# 7/7 [==============================] - 31s 4s/step - loss: 0.0655 - dsc: 0.9345 - val_loss: 0.8829 - val_dsc: 0.1173
# Epoch 27/100
# 7/7 [==============================] - 33s 5s/step - loss: 0.0769 - dsc: 0.9231 - val_loss: 0.8889 - val_dsc: 0.1113
# Epoch 28/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0680 - dsc: 0.9320 - val_loss: 0.8947 - val_dsc: 0.1055
# Epoch 29/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0735 - dsc: 0.9265 - val_loss: 0.8950 - val_dsc: 0.1051
# Epoch 30/100
# 7/7 [==============================] - 31s 4s/step - loss: 0.0676 - dsc: 0.9324 - val_loss: 0.9077 - val_dsc: 0.0924
# Epoch 31/100
# 7/7 [==============================] - 33s 5s/step - loss: 0.0695 - dsc: 0.9305 - val_loss: 0.9159 - val_dsc: 0.0843
# Epoch 32/100
# 7/7 [==============================] - 33s 5s/step - loss: 0.0622 - dsc: 0.9378 - val_loss: 0.9216 - val_dsc: 0.0785
# Epoch 33/100
# 7/7 [==============================] - 33s 5s/step - loss: 0.0557 - dsc: 0.9443 - val_loss: 0.9270 - val_dsc: 0.0731
# Epoch 34/100
# 7/7 [==============================] - 33s 5s/step - loss: 0.0589 - dsc: 0.9411 - val_loss: 0.9307 - val_dsc: 0.0694
# Epoch 35/100
# 7/7 [==============================] - 34s 5s/step - loss: 0.0592 - dsc: 0.9408 - val_loss: 0.9337 - val_dsc: 0.0664
# Epoch 36/100
# 7/7 [==============================] - 36s 5s/step - loss: 0.0660 - dsc: 0.9340 - val_loss: 0.9383 - val_dsc: 0.0618
# Epoch 37/100
# 7/7 [==============================] - 37s 5s/step - loss: 0.0502 - dsc: 0.9498 - val_loss: 0.9325 - val_dsc: 0.0677
# Epoch 38/100
# 7/7 [==============================] - 36s 5s/step - loss: 0.0562 - dsc: 0.9438 - val_loss: 0.9427 - val_dsc: 0.0576
# Epoch 39/100
# 7/7 [==============================] - 34s 5s/step - loss: 0.0491 - dsc: 0.9509 - val_loss: 0.9397 - val_dsc: 0.0605
# Epoch 40/100
# 7/7 [==============================] - 34s 5s/step - loss: 0.0487 - dsc: 0.9513 - val_loss: 0.9309 - val_dsc: 0.0686
# Epoch 41/100
# 7/7 [==============================] - 35s 5s/step - loss: 0.0516 - dsc: 0.9484 - val_loss: 0.9262 - val_dsc: 0.0729
# Epoch 42/100
# 7/7 [==============================] - 36s 5s/step - loss: 0.0438 - dsc: 0.9562 - val_loss: 0.9415 - val_dsc: 0.0581
# Epoch 43/100
# 7/7 [==============================] - 34s 5s/step - loss: 0.0424 - dsc: 0.9576 - val_loss: 0.9258 - val_dsc: 0.0731
# Epoch 44/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0400 - dsc: 0.9600 - val_loss: 0.9113 - val_dsc: 0.0865
# Epoch 45/100
# 7/7 [==============================] - 33s 5s/step - loss: 0.0397 - dsc: 0.9603 - val_loss: 0.9158 - val_dsc: 0.0822
# Epoch 46/100
# 7/7 [==============================] - 38s 6s/step - loss: 0.0401 - dsc: 0.9599 - val_loss: 0.9126 - val_dsc: 0.0851
# Epoch 47/100
# 7/7 [==============================] - 34s 5s/step - loss: 0.0355 - dsc: 0.9645 - val_loss: 0.8926 - val_dsc: 0.1035
# Epoch 48/100
# 7/7 [==============================] - 35s 5s/step - loss: 0.0351 - dsc: 0.9649 - val_loss: 0.8630 - val_dsc: 0.1308
# Epoch 49/100
# 7/7 [==============================] - 36s 5s/step - loss: 0.0370 - dsc: 0.9630 - val_loss: 0.8648 - val_dsc: 0.1292
# Epoch 50/100
# 7/7 [==============================] - 36s 5s/step - loss: 0.0356 - dsc: 0.9644 - val_loss: 0.8535 - val_dsc: 0.1396
# Epoch 51/100
# 7/7 [==============================] - 33s 5s/step - loss: 0.0345 - dsc: 0.9655 - val_loss: 0.8028 - val_dsc: 0.1865
# Epoch 52/100
# 7/7 [==============================] - 33s 5s/step - loss: 0.0297 - dsc: 0.9703 - val_loss: 0.7955 - val_dsc: 0.1940
# Epoch 53/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0294 - dsc: 0.9706 - val_loss: 0.7442 - val_dsc: 0.2439
# Epoch 54/100
# 7/7 [==============================] - 35s 5s/step - loss: 0.0345 - dsc: 0.9655 - val_loss: 0.7182 - val_dsc: 0.2693
# Epoch 55/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0321 - dsc: 0.9679 - val_loss: 0.7794 - val_dsc: 0.2098
# Epoch 56/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0344 - dsc: 0.9656 - val_loss: 0.6842 - val_dsc: 0.3048
# Epoch 57/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0328 - dsc: 0.9672 - val_loss: 0.6014 - val_dsc: 0.3908
# Epoch 58/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0364 - dsc: 0.9636 - val_loss: 0.5667 - val_dsc: 0.4271
# Epoch 59/100
# 7/7 [==============================] - 33s 5s/step - loss: 0.0281 - dsc: 0.9719 - val_loss: 0.4927 - val_dsc: 0.5034
# Epoch 60/100
# 7/7 [==============================] - 33s 5s/step - loss: 0.0337 - dsc: 0.9663 - val_loss: 0.4523 - val_dsc: 0.5468
# Epoch 61/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0266 - dsc: 0.9734 - val_loss: 0.4187 - val_dsc: 0.5820
# Epoch 62/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0240 - dsc: 0.9760 - val_loss: 0.3848 - val_dsc: 0.6160
# Epoch 63/100
# 7/7 [==============================] - 33s 5s/step - loss: 0.0358 - dsc: 0.9642 - val_loss: 0.3433 - val_dsc: 0.6576
# Epoch 64/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0525 - dsc: 0.9475 - val_loss: 0.2073 - val_dsc: 0.7897
# Epoch 65/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0586 - dsc: 0.9414 - val_loss: 0.1879 - val_dsc: 0.8091
# Epoch 66/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0519 - dsc: 0.9481 - val_loss: 0.1892 - val_dsc: 0.8079
# Epoch 67/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0515 - dsc: 0.9485 - val_loss: 0.1860 - val_dsc: 0.8106
# Epoch 68/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0466 - dsc: 0.9533 - val_loss: 0.1710 - val_dsc: 0.8283
# Epoch 69/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0393 - dsc: 0.9607 - val_loss: 0.1819 - val_dsc: 0.8181
# Epoch 70/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0358 - dsc: 0.9642 - val_loss: 0.1960 - val_dsc: 0.8046
# Epoch 71/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0274 - dsc: 0.9726 - val_loss: 0.1696 - val_dsc: 0.8303
# Epoch 72/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0270 - dsc: 0.9730 - val_loss: 0.1699 - val_dsc: 0.8295
# Epoch 73/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0259 - dsc: 0.9741 - val_loss: 0.1654 - val_dsc: 0.8340
# Epoch 74/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0279 - dsc: 0.9721 - val_loss: 0.1725 - val_dsc: 0.8267
# Epoch 75/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0277 - dsc: 0.9723 - val_loss: 0.2033 - val_dsc: 0.7962
# Epoch 76/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0256 - dsc: 0.9744 - val_loss: 0.1869 - val_dsc: 0.8131
# Epoch 77/100
# 7/7 [==============================] - 31s 5s/step - loss: 0.0246 - dsc: 0.9754 - val_loss: 0.1690 - val_dsc: 0.8308
# Epoch 78/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0267 - dsc: 0.9733 - val_loss: 0.1769 - val_dsc: 0.8222
# Epoch 79/100
# 7/7 [==============================] - 31s 5s/step - loss: 0.0212 - dsc: 0.9788 - val_loss: 0.1805 - val_dsc: 0.8185
# Epoch 80/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0222 - dsc: 0.9778 - val_loss: 0.1736 - val_dsc: 0.8255
# Epoch 81/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0256 - dsc: 0.9744 - val_loss: 0.1624 - val_dsc: 0.8370
# Epoch 82/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0220 - dsc: 0.9780 - val_loss: 0.1825 - val_dsc: 0.8163
# Epoch 83/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0209 - dsc: 0.9791 - val_loss: 0.1645 - val_dsc: 0.8341
# Epoch 84/100
# 7/7 [==============================] - 31s 5s/step - loss: 0.0254 - dsc: 0.9746 - val_loss: 0.1486 - val_dsc: 0.8500
# Epoch 85/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0216 - dsc: 0.9784 - val_loss: 0.1702 - val_dsc: 0.8278
# Epoch 86/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0210 - dsc: 0.9790 - val_loss: 0.1447 - val_dsc: 0.8535
# Epoch 87/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0180 - dsc: 0.9820 - val_loss: 0.1553 - val_dsc: 0.8427
# Epoch 88/100
# 7/7 [==============================] - 31s 5s/step - loss: 0.0185 - dsc: 0.9815 - val_loss: 0.1527 - val_dsc: 0.8453
# Epoch 89/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0168 - dsc: 0.9832 - val_loss: 0.1432 - val_dsc: 0.8549
# Epoch 90/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0182 - dsc: 0.9818 - val_loss: 0.1479 - val_dsc: 0.8498
# Epoch 91/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0182 - dsc: 0.9818 - val_loss: 0.1310 - val_dsc: 0.8671
# Epoch 92/100
# 7/7 [==============================] - 31s 5s/step - loss: 0.0183 - dsc: 0.9817 - val_loss: 0.1331 - val_dsc: 0.8650
# Epoch 93/100
# 7/7 [==============================] - 33s 5s/step - loss: 0.0157 - dsc: 0.9843 - val_loss: 0.1283 - val_dsc: 0.8698
# Epoch 94/100
# 7/7 [==============================] - 31s 5s/step - loss: 0.0172 - dsc: 0.9828 - val_loss: 0.1239 - val_dsc: 0.8739
# Epoch 95/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0174 - dsc: 0.9826 - val_loss: 0.1193 - val_dsc: 0.8785
# Epoch 96/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0170 - dsc: 0.9830 - val_loss: 0.1226 - val_dsc: 0.8751
# Epoch 97/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0184 - dsc: 0.9816 - val_loss: 0.1262 - val_dsc: 0.8713
# Epoch 98/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0151 - dsc: 0.9849 - val_loss: 0.1197 - val_dsc: 0.8779
# Epoch 99/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0148 - dsc: 0.9852 - val_loss: 0.1172 - val_dsc: 0.8804
# Epoch 100/100
# 7/7 [==============================] - 32s 5s/step - loss: 0.0151 - dsc: 0.9849 - val_loss: 0.1175 - val_dsc: 0.8800

# %%
# Make predictions
t = now()
preds_Att = model.predict(X_test)
print('Testing time: %s' % (now() - t))
# Out:
# 2/2 [==============================] - 4s 2s/step
# Testing time: 0:00:04.156968

# %%
Representacion(history,epochnum,batchnum)
# Out:
# Training time: 0:00:04.160133

# %%
# Evaluate model
num_test = len(X_test)
# Calculate performance metrics
dsc_sc = np.zeros((num_test,1))
iou_sc = np.zeros_like(dsc_sc)
rec_sc = np.zeros_like(dsc_sc)
tn_sc = np.zeros_like(dsc_sc)
prec_sc = np.zeros_like(dsc_sc)
thresh = 0.5
for i in range(num_test):
    dsc_sc[i], iou_sc[i], rec_sc[i], prec_sc[i] = auc(Y_test[i], preds_Att[i] >thresh)
print('-'*30)
print('USING THRESHOLD', thresh)
print('\n DSC \t\t{0:^.3f} \n IOU \t\t{1:^.3f} \n Recall \t{2:^.3f} \n Precision\t{3:^.3f}'.format(
        np.sum(dsc_sc)/num_test,  
        np.sum(iou_sc)/num_test,  
        np.sum(rec_sc)/num_test,
        np.sum(prec_sc)/num_test))
    
# Confusion matrix
confusion = confusion_matrix(Y_test.ravel(),preds_Att.ravel()>thresh)
accuracy = 0
if float(np.sum(confusion))!=0:
    accuracy = float(confusion[0,0]+confusion[1,1])/float(np.sum(confusion))
print(' Global Acc \t{0:^.3f}'.format(accuracy))
    
# Area under the ROC curve
AUC_ROC = roc_auc_score(preds_Att.ravel()>thresh, Y_test.ravel())
print(' AUC ROC \t{0:^.3f}'.format(AUC_ROC))
print('\n')
print('*'*60)
    
# Save outputs 
numepochs = epochsn[-1]
dice_score = np.sum(dsc_sc)/num_test
iou_score = np.sum(iou_sc)/num_test
rec_score = np.sum(rec_sc)/num_test
prec_score = np.sum(prec_sc)/num_test
globacc_score = accuracy
auc_roc_score = AUC_ROC
# Out:
# ------------------------------
# USING THRESHOLD 0.5
#
#  DSC 		0.862
#  IOU 		0.774
#  Recall 	0.818
#  Precision	0.946
#  Global Acc 	0.924
#  AUC ROC 	0.935
#
#
# ************************************************************

# %%
preds_Att_val = model.predict(X_val)
num_val = len(X_val)
# Calculate performance metrics
dsc_sc = np.zeros((num_val,1))
iou_sc = np.zeros_like(dsc_sc)
rec_sc = np.zeros_like(dsc_sc)
tn_sc = np.zeros_like(dsc_sc)
prec_sc = np.zeros_like(dsc_sc)
thresh = 0.5
for i in range(num_val):
    dsc_sc[i], iou_sc[i], rec_sc[i], prec_sc[i] = auc(Y_val[i], preds_Att_val[i] >thresh)
print('-'*30)
print('USING THRESHOLD', thresh)
print('\n DSC \t\t{0:^.3f} \n IOU \t\t{1:^.3f} \n Recall \t{2:^.3f} \n Precision\t{3:^.3f}'.format(
        np.sum(dsc_sc)/num_val,  
        np.sum(iou_sc)/num_val,  
        np.sum(rec_sc)/num_val,
        np.sum(prec_sc)/num_val))
    
# Confusion matrix
confusion = confusion_matrix(Y_val.ravel(),preds_Att_val.ravel()>thresh)
accuracy = 0
if float(np.sum(confusion))!=0:
    accuracy = float(confusion[0,0]+confusion[1,1])/float(np.sum(confusion))
print(' Global Acc \t{0:^.3f}'.format(accuracy))
    
# Area under the ROC curve
AUC_ROC = roc_auc_score(preds_Att_val.ravel()>thresh, Y_val.ravel())
print(' AUC ROC \t{0:^.3f}'.format(AUC_ROC))
print('\n')
print('*'*60)
    
# Save outputs 
numepochs = epochsn[-1]
dice_score = np.sum(dsc_sc)/num_val
iou_score = np.sum(iou_sc)/num_val
rec_score = np.sum(rec_sc)/num_val
prec_score = np.sum(prec_sc)/num_val
globacc_score = accuracy
auc_roc_score = AUC_ROC
# Out:
# 1/1 [==============================] - 2s 2s/step
# ------------------------------
# USING THRESHOLD 0.5
#
#  DSC 		0.886
#  IOU 		0.803
#  Recall 	0.827
#  Precision	0.970
#  Global Acc 	0.930
#  AUC ROC 	0.945
#
#
# ************************************************************

# %% [markdown]
# # U-NET Dense + Attended

# %%
from keras.layers import *

def DenseBlock(channels,inputs):

    conv1_1 = Conv2D(channels, (1, 1),activation=None, padding='same')(inputs)
    conv1_1=BatchActivate(conv1_1)
    conv1_2 = Conv2D(channels//4, (3, 3), activation=None, padding='same')(conv1_1)
    conv1_2 = BatchActivate(conv1_2)

    conv2=concatenate([inputs,conv1_2])
    conv2_1 = Conv2D(channels, (1, 1), activation=None, padding='same')(conv2)
    conv2_1 = BatchActivate(conv2_1)
    conv2_2 = Conv2D(channels // 4, (3, 3), activation=None, padding='same')(conv2_1)
    conv2_2 = BatchActivate(conv2_2)

    conv3 = concatenate([inputs, conv1_2,conv2_2])
    conv3_1 = Conv2D(channels, (1, 1), activation=None, padding='same')(conv3)
    conv3_1 = BatchActivate(conv3_1)
    conv3_2 = Conv2D(channels // 4, (3, 3), activation=None, padding='same')(conv3_1)
    conv3_2 = BatchActivate(conv3_2)

    conv4 = concatenate([inputs, conv1_2, conv2_2,conv3_2])
    conv4_1 = Conv2D(channels, (1, 1), activation=None, padding='same')(conv4)
    conv4_1 = BatchActivate(conv4_1)
    conv4_2 = Conv2D(channels // 4, (3, 3), activation=None, padding='same')(conv4_1)
    conv4_2 = BatchActivate(conv4_2)
    result=concatenate([inputs,conv1_2, conv2_2,conv3_2,conv4_2])
    return result

def BatchActivate(x):
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

def Attention_gate(g, s, num_filters):
    Wg = Conv2D(num_filters, 1, padding="same")(g)
    Wg = BatchNormalization()(Wg)
 
    Ws = Conv2D(num_filters, 1, padding="same")(s)
    Ws = BatchNormalization()(Ws)
    
    w = Add()([Wg,Ws])
 
    out = Activation("relu")(w)
    out = Conv2D(num_filters, 1, padding="same")(out)
    out = Activation("sigmoid")(out)
    return Multiply()([out,s])

# %%
from keras.optimizers import *
from keras.models import *

def DenseUNet_AttGate(start_neurons=16, keep_prob=0.9,block_size=7,lr=1e-3):

    inputs = Input(shape=input_size)
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(inputs)
    conv1 = BatchActivate(conv1)
    conv1 = DenseBlock(start_neurons * 1, conv1)
    pool1 = MaxPooling2D((2, 2))(conv1)

    conv2 = DenseBlock(start_neurons * 2, pool1)
    pool2 = MaxPooling2D((2, 2))(conv2)

    conv3 = DenseBlock(start_neurons * 4, pool2)
    pool3 = MaxPooling2D((2, 2))(conv3)


    convm = DenseBlock(start_neurons * 8, pool3)


    deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same")(convm)
    Att3 = Attention_gate(conv3,deconv3,start_neurons * 4)  
    uconv3 = concatenate([deconv3, Att3])
    uconv3 = Conv2D(start_neurons * 4, (1, 1), activation=None, padding="same")(uconv3)
    uconv3 = BatchActivate(uconv3)
    uconv3 = DenseBlock(start_neurons * 4, uconv3)


    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(uconv3)
    Att2 = Attention_gate(conv2,deconv2,start_neurons * 2)  
    uconv2 = concatenate([deconv2, Att2])
    uconv2 = Conv2D(start_neurons * 2, (1, 1), activation=None, padding="same")(uconv2)
    uconv2 = BatchActivate(uconv2)
    uconv2 = DenseBlock(start_neurons * 2, uconv2)

    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv2)
    Att1 = Attention_gate(conv1,deconv1,start_neurons * 1)  
    uconv1 = concatenate([deconv1, Att1])
    uconv1 = Conv2D(start_neurons * 1, (1, 1), activation=None, padding="same")(uconv1)
    uconv1 = BatchActivate(uconv1)
    uconv1 = DenseBlock(start_neurons * 1, uconv1)

    output_layer_noActi = Conv2D(1, (1, 1), padding="same", activation=None)(uconv1)
    output_layer = Activation('sigmoid')(output_layer_noActi)
    
    model = Model(inputs=inputs, outputs=output_layer)
    model.compile(optimizer=Adam(lr=1e-3), loss=dice_loss, metrics=[dsc])

    return model

# %%
from sklearn.model_selection import train_test_split
keras.backend.clear_session()
X_train, X_test, Y_train, Y_test = train_test_split(imgs, masks_, test_size=0.3, random_state = 0)
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size = 0.2, random_state = 0)
model2 = DenseUNet_AttGate()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
t = now()

history = model2.fit(X_train, Y_train, validation_data = (X_val, Y_val), batch_size=batchnum, epochs=epochnum, verbose=1)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 27s 2s/step - loss: 0.5248 - dsc: 0.4752 - val_loss: 0.5902 - val_dsc: 0.4112
# Epoch 2/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.3809 - dsc: 0.6191 - val_loss: 0.5927 - val_dsc: 0.4086
# Epoch 3/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.2959 - dsc: 0.7041 - val_loss: 0.6025 - val_dsc: 0.3989
# Epoch 4/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.2491 - dsc: 0.7509 - val_loss: 0.6130 - val_dsc: 0.3882
# Epoch 5/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.2340 - dsc: 0.7660 - val_loss: 0.6303 - val_dsc: 0.3709
# Epoch 6/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.2375 - dsc: 0.7625 - val_loss: 0.6475 - val_dsc: 0.3535
# Epoch 7/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.2215 - dsc: 0.7785 - val_loss: 0.6695 - val_dsc: 0.3315
# Epoch 8/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.2079 - dsc: 0.7921 - val_loss: 0.7407 - val_dsc: 0.2599
# Epoch 9/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.1738 - dsc: 0.8262 - val_loss: 0.7485 - val_dsc: 0.2520
# Epoch 10/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.1655 - dsc: 0.8345 - val_loss: 0.7518 - val_dsc: 0.2488
# Epoch 11/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.1629 - dsc: 0.8371 - val_loss: 0.7859 - val_dsc: 0.2145
# Epoch 12/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.1614 - dsc: 0.8386 - val_loss: 0.8345 - val_dsc: 0.1657
# Epoch 13/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.1603 - dsc: 0.8397 - val_loss: 0.8382 - val_dsc: 0.1621
# Epoch 14/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.1537 - dsc: 0.8463 - val_loss: 0.8570 - val_dsc: 0.1432
# Epoch 15/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.1365 - dsc: 0.8635 - val_loss: 0.8824 - val_dsc: 0.1177
# Epoch 16/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.1280 - dsc: 0.8720 - val_loss: 0.8910 - val_dsc: 0.1091
# Epoch 17/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.1150 - dsc: 0.8850 - val_loss: 0.8969 - val_dsc: 0.1032
# Epoch 18/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.1164 - dsc: 0.8836 - val_loss: 0.9070 - val_dsc: 0.0931
# Epoch 19/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.1181 - dsc: 0.8819 - val_loss: 0.9245 - val_dsc: 0.0755
# Epoch 20/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.1242 - dsc: 0.8758 - val_loss: 0.9145 - val_dsc: 0.0855
# Epoch 21/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.1001 - dsc: 0.8999 - val_loss: 0.9460 - val_dsc: 0.0540
# Epoch 22/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0978 - dsc: 0.9022 - val_loss: 0.9463 - val_dsc: 0.0537
# Epoch 23/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.1119 - dsc: 0.8881 - val_loss: 0.9470 - val_dsc: 0.0530
# Epoch 24/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0932 - dsc: 0.9068 - val_loss: 0.9551 - val_dsc: 0.0450
# Epoch 25/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0944 - dsc: 0.9056 - val_loss: 0.9587 - val_dsc: 0.0414
# Epoch 26/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0843 - dsc: 0.9157 - val_loss: 0.9648 - val_dsc: 0.0352
# Epoch 27/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0913 - dsc: 0.9087 - val_loss: 0.9650 - val_dsc: 0.0350
# Epoch 28/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0845 - dsc: 0.9155 - val_loss: 0.9662 - val_dsc: 0.0338
# Epoch 29/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0696 - dsc: 0.9304 - val_loss: 0.9704 - val_dsc: 0.0296
# Epoch 30/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0796 - dsc: 0.9204 - val_loss: 0.9721 - val_dsc: 0.0279
# Epoch 31/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0737 - dsc: 0.9263 - val_loss: 0.9727 - val_dsc: 0.0273
# Epoch 32/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0676 - dsc: 0.9324 - val_loss: 0.9749 - val_dsc: 0.0249
# Epoch 33/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0718 - dsc: 0.9282 - val_loss: 0.9749 - val_dsc: 0.0246
# Epoch 34/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0701 - dsc: 0.9299 - val_loss: 0.9742 - val_dsc: 0.0257
# Epoch 35/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0652 - dsc: 0.9348 - val_loss: 0.9739 - val_dsc: 0.0250
# Epoch 36/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0723 - dsc: 0.9277 - val_loss: 0.9838 - val_dsc: 0.0162
# Epoch 37/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0877 - dsc: 0.9123 - val_loss: 0.9693 - val_dsc: 0.0297
# Epoch 38/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0718 - dsc: 0.9282 - val_loss: 0.9386 - val_dsc: 0.0605
# Epoch 39/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0620 - dsc: 0.9380 - val_loss: 0.9115 - val_dsc: 0.0866
# Epoch 40/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0640 - dsc: 0.9360 - val_loss: 0.7346 - val_dsc: 0.2623
# Epoch 41/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0824 - dsc: 0.9176 - val_loss: 0.8018 - val_dsc: 0.1937
# Epoch 42/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0744 - dsc: 0.9256 - val_loss: 0.6999 - val_dsc: 0.2962
# Epoch 43/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0756 - dsc: 0.9244 - val_loss: 0.7778 - val_dsc: 0.2145
# Epoch 44/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0693 - dsc: 0.9307 - val_loss: 0.7095 - val_dsc: 0.2834
# Epoch 45/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0581 - dsc: 0.9419 - val_loss: 0.6026 - val_dsc: 0.3923
# Epoch 46/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0552 - dsc: 0.9448 - val_loss: 0.5366 - val_dsc: 0.4562
# Epoch 47/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0526 - dsc: 0.9474 - val_loss: 0.4830 - val_dsc: 0.5129
# Epoch 48/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0609 - dsc: 0.9391 - val_loss: 0.5601 - val_dsc: 0.4340
# Epoch 49/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0560 - dsc: 0.9440 - val_loss: 0.5585 - val_dsc: 0.4349
# Epoch 50/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0568 - dsc: 0.9432 - val_loss: 0.5704 - val_dsc: 0.4237
# Epoch 51/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0612 - dsc: 0.9388 - val_loss: 0.5207 - val_dsc: 0.4714
# Epoch 52/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0555 - dsc: 0.9445 - val_loss: 0.4136 - val_dsc: 0.5803
# Epoch 53/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0502 - dsc: 0.9498 - val_loss: 0.3524 - val_dsc: 0.6384
# Epoch 54/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0497 - dsc: 0.9503 - val_loss: 0.3026 - val_dsc: 0.6909
# Epoch 55/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0460 - dsc: 0.9540 - val_loss: 0.2455 - val_dsc: 0.7466
# Epoch 56/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0482 - dsc: 0.9518 - val_loss: 0.3103 - val_dsc: 0.6793
# Epoch 57/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0458 - dsc: 0.9542 - val_loss: 0.4531 - val_dsc: 0.5368
# Epoch 58/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0449 - dsc: 0.9551 - val_loss: 0.2133 - val_dsc: 0.7812
# Epoch 59/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0469 - dsc: 0.9531 - val_loss: 0.1420 - val_dsc: 0.8558
# Epoch 60/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0426 - dsc: 0.9574 - val_loss: 0.2532 - val_dsc: 0.7427
# Epoch 61/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0426 - dsc: 0.9574 - val_loss: 0.4064 - val_dsc: 0.5808
# Epoch 62/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0369 - dsc: 0.9631 - val_loss: 0.3327 - val_dsc: 0.6568
# Epoch 63/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0333 - dsc: 0.9667 - val_loss: 0.3154 - val_dsc: 0.6754
# Epoch 64/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0312 - dsc: 0.9688 - val_loss: 0.3109 - val_dsc: 0.6796
# Epoch 65/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0354 - dsc: 0.9646 - val_loss: 0.2341 - val_dsc: 0.7619
# Epoch 66/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0328 - dsc: 0.9672 - val_loss: 0.1889 - val_dsc: 0.8067
# Epoch 67/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0326 - dsc: 0.9674 - val_loss: 0.1676 - val_dsc: 0.8280
# Epoch 68/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0278 - dsc: 0.9722 - val_loss: 0.1479 - val_dsc: 0.8480
# Epoch 69/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0309 - dsc: 0.9691 - val_loss: 0.1173 - val_dsc: 0.8788
# Epoch 70/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0340 - dsc: 0.9660 - val_loss: 0.1379 - val_dsc: 0.8577
# Epoch 71/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0268 - dsc: 0.9732 - val_loss: 0.1467 - val_dsc: 0.8478
# Epoch 72/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0249 - dsc: 0.9751 - val_loss: 0.1414 - val_dsc: 0.8525
# Epoch 73/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0283 - dsc: 0.9717 - val_loss: 0.1293 - val_dsc: 0.8658
# Epoch 74/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0261 - dsc: 0.9739 - val_loss: 0.1406 - val_dsc: 0.8533
# Epoch 75/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0279 - dsc: 0.9721 - val_loss: 0.1141 - val_dsc: 0.8824
# Epoch 76/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0262 - dsc: 0.9738 - val_loss: 0.0958 - val_dsc: 0.9008
# Epoch 77/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0265 - dsc: 0.9735 - val_loss: 0.0962 - val_dsc: 0.9003
# Epoch 78/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0237 - dsc: 0.9763 - val_loss: 0.0996 - val_dsc: 0.8968
# Epoch 79/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0220 - dsc: 0.9780 - val_loss: 0.1002 - val_dsc: 0.8967
# Epoch 80/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0240 - dsc: 0.9760 - val_loss: 0.0925 - val_dsc: 0.9048
# Epoch 81/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0234 - dsc: 0.9766 - val_loss: 0.0846 - val_dsc: 0.9129
# Epoch 82/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0227 - dsc: 0.9773 - val_loss: 0.0866 - val_dsc: 0.9137
# Epoch 83/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0237 - dsc: 0.9763 - val_loss: 0.0956 - val_dsc: 0.9029
# Epoch 84/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0217 - dsc: 0.9783 - val_loss: 0.0915 - val_dsc: 0.9084
# Epoch 85/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0209 - dsc: 0.9791 - val_loss: 0.0960 - val_dsc: 0.9021
# Epoch 86/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0195 - dsc: 0.9805 - val_loss: 0.0905 - val_dsc: 0.9066
# Epoch 87/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0209 - dsc: 0.9791 - val_loss: 0.0925 - val_dsc: 0.9054
# Epoch 88/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0183 - dsc: 0.9817 - val_loss: 0.0893 - val_dsc: 0.9076
# Epoch 89/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0186 - dsc: 0.9814 - val_loss: 0.1007 - val_dsc: 0.8954
# Epoch 90/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0185 - dsc: 0.9815 - val_loss: 0.1010 - val_dsc: 0.8960
# Epoch 91/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0185 - dsc: 0.9815 - val_loss: 0.0954 - val_dsc: 0.9010
# Epoch 92/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0168 - dsc: 0.9832 - val_loss: 0.0906 - val_dsc: 0.9052
# Epoch 93/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0169 - dsc: 0.9831 - val_loss: 0.0905 - val_dsc: 0.9055
# Epoch 94/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0180 - dsc: 0.9820 - val_loss: 0.0917 - val_dsc: 0.9044
# Epoch 95/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0154 - dsc: 0.9846 - val_loss: 0.0868 - val_dsc: 0.9125
# Epoch 96/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0174 - dsc: 0.9826 - val_loss: 0.0913 - val_dsc: 0.9063
# Epoch 97/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.0169 - dsc: 0.9831 - val_loss: 0.0941 - val_dsc: 0.9057
# Epoch 98/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0169 - dsc: 0.9831 - val_loss: 0.1170 - val_dsc: 0.8824
# Epoch 99/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0145 - dsc: 0.9855 - val_loss: 0.0905 - val_dsc: 0.9089
# Epoch 100/100
# 7/7 [==============================] - 13s 2s/step - loss: 0.0142 - dsc: 0.9858 - val_loss: 0.0898 - val_dsc: 0.9094

# %%
# Make predictions
t = now()
preds_DA = model2.predict(X_test)
print('Testing time: %s' % (now() - t))
# Out:
# 2/2 [==============================] - 2s 459ms/step
# Testing time: 0:00:01.927037

# %%
Representacion(history,epochnum,batchnum)
# Out:
# Training time: 0:00:01.930526

# %%
# Evaluate model
num_test = len(X_test)
# Calculate performance metrics
dsc_sc = np.zeros((num_test,1))
iou_sc = np.zeros_like(dsc_sc)
rec_sc = np.zeros_like(dsc_sc)
tn_sc = np.zeros_like(dsc_sc)
prec_sc = np.zeros_like(dsc_sc)
thresh = 0.5
for i in range(num_test):
    dsc_sc[i], iou_sc[i], rec_sc[i], prec_sc[i] = auc(Y_test[i], preds_DA[i,:,:,0] >thresh)
print('-'*30)
print('USING THRESHOLD', thresh)
print('\n DSC \t\t{0:^.3f} \n IOU \t\t{1:^.3f} \n Recall \t{2:^.3f} \n Precision\t{3:^.3f}'.format(
        np.sum(dsc_sc)/num_test,  
        np.sum(iou_sc)/num_test,  
        np.sum(rec_sc)/num_test,
        np.sum(prec_sc)/num_test))
    
# Confusion matrix
confusion = confusion_matrix(Y_test.ravel(),preds_DA.ravel()>thresh)
accuracy = 0
if float(np.sum(confusion))!=0:
    accuracy = float(confusion[0,0]+confusion[1,1])/float(np.sum(confusion))
print(' Global Acc \t{0:^.3f}'.format(accuracy))
    
# Area under the ROC curve
AUC_ROC = roc_auc_score(preds_DA.ravel()>thresh, Y_test.ravel())
print(' AUC ROC \t{0:^.3f}'.format(AUC_ROC))
print('\n')
print('*'*60)
    
# Save outputs 
numepochs = epochsn[-1]
dice_score = np.sum(dsc_sc)/num_test
iou_score = np.sum(iou_sc)/num_test
rec_score = np.sum(rec_sc)/num_test
prec_score = np.sum(prec_sc)/num_test
globacc_score = accuracy
auc_roc_score = AUC_ROC
# Out:
# ------------------------------
# USING THRESHOLD 0.5
#
#  DSC 		0.875
#  IOU 		0.789
#  Recall 	0.928
#  Precision	0.846
#  Global Acc 	0.935
#  AUC ROC 	0.921
#
#
# ************************************************************

# %%
preds_DA_val = model2.predict(X_val)
num_val = len(X_val)
# Calculate performance metrics
dsc_sc = np.zeros((num_val,1))
iou_sc = np.zeros_like(dsc_sc)
rec_sc = np.zeros_like(dsc_sc)
tn_sc = np.zeros_like(dsc_sc)
prec_sc = np.zeros_like(dsc_sc)
thresh = 0.5
for i in range(num_val):
    dsc_sc[i], iou_sc[i], rec_sc[i], prec_sc[i] = auc(Y_val[i], preds_DA_val[i,:,:,0] >thresh)
print('-'*30)
print('USING THRESHOLD', thresh)
print('\n DSC \t\t{0:^.3f} \n IOU \t\t{1:^.3f} \n Recall \t{2:^.3f} \n Precision\t{3:^.3f}'.format(
        np.sum(dsc_sc)/num_val,  
        np.sum(iou_sc)/num_val,  
        np.sum(rec_sc)/num_val,
        np.sum(prec_sc)/num_val))
    
# Confusion matrix
confusion = confusion_matrix(Y_val.ravel(),preds_DA_val.ravel()>thresh)
accuracy = 0
if float(np.sum(confusion))!=0:
    accuracy = float(confusion[0,0]+confusion[1,1])/float(np.sum(confusion))
print(' Global Acc \t{0:^.3f}'.format(accuracy))
    
# Area under the ROC curve
AUC_ROC = roc_auc_score(preds_DA_val.ravel()>thresh, Y_val.ravel())
print(' AUC ROC \t{0:^.3f}'.format(AUC_ROC))
print('\n')
print('*'*60)
    
# Save outputs 
numepochs = epochsn[-1]
dice_score = np.sum(dsc_sc)/num_val
iou_score = np.sum(iou_sc)/num_val
rec_score = np.sum(rec_sc)/num_val
prec_score = np.sum(prec_sc)/num_val
globacc_score = accuracy
auc_roc_score = AUC_ROC
# Out:
# 1/1 [==============================] - 0s 474ms/step
# ------------------------------
# USING THRESHOLD 0.5
#
#  DSC 		0.886
#  IOU 		0.812
#  Recall 	0.929
#  Precision	0.876
#  Global Acc 	0.938
#  AUC ROC 	0.930
#
#
# ************************************************************

# %% [markdown]
# # U-NET 3+

# %%
from keras_unet_collection import models, base, utils
model = models.unet_3plus_2d(input_size, n_labels=1, filter_num_down=[64, 128, 256, 512], 
                             filter_num_skip='auto', filter_num_aggregate='auto', 
                             stack_num_down=2, stack_num_up=1, activation='ReLU', output_activation='Sigmoid',
                             batch_norm=True, pool='max', unpool=False, deep_supervision=False, name='unet3plus')
# Out:
# Automated hyper-parameter determination is applied with the following details:
# ----------
# 	Number of convolution filters after each full-scale skip connection: filter_num_skip = [64, 64, 64]
# 	Number of channels of full-scale aggregated feature maps: filter_num_aggregate = 256

# %%
model.compile(loss=dice_loss,optimizer=keras.optimizers.Adam(learning_rate=1e-4), metrics=[dsc]) # lr adaptativo

import datetime
now = datetime.datetime.now
t = now()

history = model.fit(X_train, Y_train, validation_data = (X_val, Y_val), batch_size=batchnum, epochs=epochnum, verbose=1)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 53s 7s/step - loss: 0.4979 - dsc: 0.5021 - val_loss: 0.5927 - val_dsc: 0.4087
# Epoch 2/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.2723 - dsc: 0.7277 - val_loss: 0.5955 - val_dsc: 0.4059
# Epoch 3/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.1976 - dsc: 0.8024 - val_loss: 0.6065 - val_dsc: 0.3948
# Epoch 4/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.1631 - dsc: 0.8369 - val_loss: 0.6249 - val_dsc: 0.3763
# Epoch 5/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.1616 - dsc: 0.8384 - val_loss: 0.6501 - val_dsc: 0.3509
# Epoch 6/100
# 7/7 [==============================] - 50s 7s/step - loss: 0.1671 - dsc: 0.8329 - val_loss: 0.6731 - val_dsc: 0.3278
# Epoch 7/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.1399 - dsc: 0.8601 - val_loss: 0.6971 - val_dsc: 0.3037
# Epoch 8/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.1401 - dsc: 0.8599 - val_loss: 0.7248 - val_dsc: 0.2758
# Epoch 9/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.1262 - dsc: 0.8738 - val_loss: 0.7580 - val_dsc: 0.2425
# Epoch 10/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.1162 - dsc: 0.8838 - val_loss: 0.7806 - val_dsc: 0.2198
# Epoch 11/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.1174 - dsc: 0.8826 - val_loss: 0.8126 - val_dsc: 0.1877
# Epoch 12/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.1118 - dsc: 0.8882 - val_loss: 0.8321 - val_dsc: 0.1681
# Epoch 13/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.1023 - dsc: 0.8977 - val_loss: 0.8575 - val_dsc: 0.1427
# Epoch 14/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.1107 - dsc: 0.8893 - val_loss: 0.8730 - val_dsc: 0.1272
# Epoch 15/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.1049 - dsc: 0.8951 - val_loss: 0.8884 - val_dsc: 0.1117
# Epoch 16/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.1020 - dsc: 0.8980 - val_loss: 0.9078 - val_dsc: 0.0923
# Epoch 17/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0933 - dsc: 0.9067 - val_loss: 0.9261 - val_dsc: 0.0739
# Epoch 18/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0908 - dsc: 0.9092 - val_loss: 0.9343 - val_dsc: 0.0658
# Epoch 19/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0786 - dsc: 0.9214 - val_loss: 0.9396 - val_dsc: 0.0604
# Epoch 20/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0799 - dsc: 0.9201 - val_loss: 0.9472 - val_dsc: 0.0529
# Epoch 21/100
# 7/7 [==============================] - 50s 7s/step - loss: 0.0782 - dsc: 0.9218 - val_loss: 0.9560 - val_dsc: 0.0440
# Epoch 22/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0988 - dsc: 0.9012 - val_loss: 0.9578 - val_dsc: 0.0423
# Epoch 23/100
# 7/7 [==============================] - 50s 7s/step - loss: 0.0773 - dsc: 0.9227 - val_loss: 0.9642 - val_dsc: 0.0358
# Epoch 24/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0711 - dsc: 0.9289 - val_loss: 0.9716 - val_dsc: 0.0284
# Epoch 25/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0766 - dsc: 0.9234 - val_loss: 0.9780 - val_dsc: 0.0220
# Epoch 26/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0816 - dsc: 0.9184 - val_loss: 0.9795 - val_dsc: 0.0205
# Epoch 27/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0695 - dsc: 0.9305 - val_loss: 0.9832 - val_dsc: 0.0168
# Epoch 28/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0921 - dsc: 0.9079 - val_loss: 0.9851 - val_dsc: 0.0149
# Epoch 29/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0584 - dsc: 0.9416 - val_loss: 0.9885 - val_dsc: 0.0115
# Epoch 30/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0687 - dsc: 0.9313 - val_loss: 0.9887 - val_dsc: 0.0113
# Epoch 31/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0518 - dsc: 0.9482 - val_loss: 0.9898 - val_dsc: 0.0102
# Epoch 32/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0521 - dsc: 0.9479 - val_loss: 0.9919 - val_dsc: 0.0081
# Epoch 33/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0584 - dsc: 0.9416 - val_loss: 0.9924 - val_dsc: 0.0076
# Epoch 34/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0554 - dsc: 0.9446 - val_loss: 0.9929 - val_dsc: 0.0071
# Epoch 35/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0486 - dsc: 0.9514 - val_loss: 0.9934 - val_dsc: 0.0066
# Epoch 36/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0476 - dsc: 0.9524 - val_loss: 0.9939 - val_dsc: 0.0061
# Epoch 37/100
# 7/7 [==============================] - 48s 7s/step - loss: 0.0477 - dsc: 0.9523 - val_loss: 0.9943 - val_dsc: 0.0057
# Epoch 38/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0390 - dsc: 0.9610 - val_loss: 0.9958 - val_dsc: 0.0042
# Epoch 39/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0463 - dsc: 0.9537 - val_loss: 0.9955 - val_dsc: 0.0045
# Epoch 40/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0604 - dsc: 0.9396 - val_loss: 0.9968 - val_dsc: 0.0032
# Epoch 41/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0559 - dsc: 0.9441 - val_loss: 0.9969 - val_dsc: 0.0031
# Epoch 42/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0551 - dsc: 0.9449 - val_loss: 0.9975 - val_dsc: 0.0025
# Epoch 43/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0474 - dsc: 0.9526 - val_loss: 0.9857 - val_dsc: 0.0131
# Epoch 44/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0466 - dsc: 0.9534 - val_loss: 0.9978 - val_dsc: 0.0021
# Epoch 45/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0427 - dsc: 0.9573 - val_loss: 0.9978 - val_dsc: 0.0021
# Epoch 46/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0331 - dsc: 0.9669 - val_loss: 0.9897 - val_dsc: 0.0093
# Epoch 47/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0315 - dsc: 0.9685 - val_loss: 0.9886 - val_dsc: 0.0105
# Epoch 48/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0332 - dsc: 0.9668 - val_loss: 0.9695 - val_dsc: 0.0290
# Epoch 49/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0317 - dsc: 0.9683 - val_loss: 0.9593 - val_dsc: 0.0397
# Epoch 50/100
# 7/7 [==============================] - 50s 7s/step - loss: 0.0313 - dsc: 0.9687 - val_loss: 0.9570 - val_dsc: 0.0414
# Epoch 51/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0298 - dsc: 0.9702 - val_loss: 0.9594 - val_dsc: 0.0383
# Epoch 52/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0311 - dsc: 0.9689 - val_loss: 0.9456 - val_dsc: 0.0529
# Epoch 53/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0261 - dsc: 0.9739 - val_loss: 0.9222 - val_dsc: 0.0770
# Epoch 54/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0226 - dsc: 0.9774 - val_loss: 0.8839 - val_dsc: 0.1141
# Epoch 55/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0220 - dsc: 0.9780 - val_loss: 0.8870 - val_dsc: 0.1112
# Epoch 56/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0238 - dsc: 0.9762 - val_loss: 0.8330 - val_dsc: 0.1626
# Epoch 57/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0258 - dsc: 0.9742 - val_loss: 0.7688 - val_dsc: 0.2226
# Epoch 58/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0227 - dsc: 0.9773 - val_loss: 0.8040 - val_dsc: 0.1891
# Epoch 59/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0261 - dsc: 0.9739 - val_loss: 0.6978 - val_dsc: 0.2935
# Epoch 60/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0264 - dsc: 0.9736 - val_loss: 0.4891 - val_dsc: 0.5027
# Epoch 61/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0266 - dsc: 0.9734 - val_loss: 0.5244 - val_dsc: 0.4646
# Epoch 62/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0221 - dsc: 0.9779 - val_loss: 0.5396 - val_dsc: 0.4479
# Epoch 63/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0201 - dsc: 0.9799 - val_loss: 0.4813 - val_dsc: 0.5084
# Epoch 64/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0215 - dsc: 0.9785 - val_loss: 0.4191 - val_dsc: 0.5727
# Epoch 65/100
# 7/7 [==============================] - 50s 7s/step - loss: 0.0227 - dsc: 0.9773 - val_loss: 0.4932 - val_dsc: 0.5007
# Epoch 66/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0209 - dsc: 0.9791 - val_loss: 0.4650 - val_dsc: 0.5308
# Epoch 67/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0206 - dsc: 0.9794 - val_loss: 0.3746 - val_dsc: 0.6205
# Epoch 68/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0201 - dsc: 0.9799 - val_loss: 0.3276 - val_dsc: 0.6676
# Epoch 69/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0184 - dsc: 0.9816 - val_loss: 0.2783 - val_dsc: 0.7165
# Epoch 70/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0193 - dsc: 0.9807 - val_loss: 0.2714 - val_dsc: 0.7256
# Epoch 71/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0174 - dsc: 0.9826 - val_loss: 0.2288 - val_dsc: 0.7678
# Epoch 72/100
# 7/7 [==============================] - 50s 7s/step - loss: 0.0169 - dsc: 0.9831 - val_loss: 0.1899 - val_dsc: 0.8070
# Epoch 73/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0143 - dsc: 0.9857 - val_loss: 0.1982 - val_dsc: 0.7993
# Epoch 74/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0161 - dsc: 0.9839 - val_loss: 0.2209 - val_dsc: 0.7765
# Epoch 75/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0139 - dsc: 0.9861 - val_loss: 0.1738 - val_dsc: 0.8243
# Epoch 76/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0152 - dsc: 0.9848 - val_loss: 0.1631 - val_dsc: 0.8351
# Epoch 77/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0154 - dsc: 0.9846 - val_loss: 0.1371 - val_dsc: 0.8602
# Epoch 78/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0135 - dsc: 0.9865 - val_loss: 0.1258 - val_dsc: 0.8721
# Epoch 79/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0151 - dsc: 0.9849 - val_loss: 0.1253 - val_dsc: 0.8722
# Epoch 80/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0125 - dsc: 0.9875 - val_loss: 0.1227 - val_dsc: 0.8749
# Epoch 81/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0136 - dsc: 0.9864 - val_loss: 0.1134 - val_dsc: 0.8843
# Epoch 82/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0116 - dsc: 0.9884 - val_loss: 0.1131 - val_dsc: 0.8842
# Epoch 83/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0118 - dsc: 0.9882 - val_loss: 0.1159 - val_dsc: 0.8816
# Epoch 84/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0131 - dsc: 0.9869 - val_loss: 0.1001 - val_dsc: 0.8977
# Epoch 85/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0103 - dsc: 0.9897 - val_loss: 0.1005 - val_dsc: 0.8971
# Epoch 86/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0101 - dsc: 0.9899 - val_loss: 0.1009 - val_dsc: 0.8969
# Epoch 87/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0112 - dsc: 0.9888 - val_loss: 0.0946 - val_dsc: 0.9034
# Epoch 88/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0103 - dsc: 0.9897 - val_loss: 0.0922 - val_dsc: 0.9055
# Epoch 89/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0096 - dsc: 0.9904 - val_loss: 0.0935 - val_dsc: 0.9043
# Epoch 90/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0101 - dsc: 0.9899 - val_loss: 0.0917 - val_dsc: 0.9057
# Epoch 91/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0102 - dsc: 0.9898 - val_loss: 0.0858 - val_dsc: 0.9120
# Epoch 92/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0098 - dsc: 0.9902 - val_loss: 0.0904 - val_dsc: 0.9069
# Epoch 93/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0093 - dsc: 0.9907 - val_loss: 0.0877 - val_dsc: 0.9102
# Epoch 94/100
# 7/7 [==============================] - 50s 7s/step - loss: 0.0116 - dsc: 0.9884 - val_loss: 0.0917 - val_dsc: 0.9057
# Epoch 95/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0101 - dsc: 0.9899 - val_loss: 0.0869 - val_dsc: 0.9107
# Epoch 96/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0104 - dsc: 0.9896 - val_loss: 0.0845 - val_dsc: 0.9131
# Epoch 97/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0088 - dsc: 0.9912 - val_loss: 0.0809 - val_dsc: 0.9173
# Epoch 98/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0094 - dsc: 0.9906 - val_loss: 0.0832 - val_dsc: 0.9146
# Epoch 99/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0092 - dsc: 0.9908 - val_loss: 0.0827 - val_dsc: 0.9150
# Epoch 100/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.0097 - dsc: 0.9903 - val_loss: 0.0843 - val_dsc: 0.9135

# %%
# Make predictions
t = now()
preds_3p = model.predict(X_test)
print('Testing time: %s' % (now() - t))
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f100bf1c160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f100bf1c160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 6s 3s/step
# Testing time: 0:00:05.971480

# %%
Representacion(history,epochnum,batchnum)
# Out:
# Training time: 0:00:05.975883

# %%
# Evaluate model
num_test = len(X_test)
# Calculate performance metrics
dsc_sc = np.zeros((num_test,1))
iou_sc = np.zeros_like(dsc_sc)
rec_sc = np.zeros_like(dsc_sc)
tn_sc = np.zeros_like(dsc_sc)
prec_sc = np.zeros_like(dsc_sc)
thresh = 0.5
for i in range(num_test):
    dsc_sc[i], iou_sc[i], rec_sc[i], prec_sc[i] = auc(Y_test[i], preds_3p[i] >thresh)
print('-'*30)
print('USING THRESHOLD', thresh)
print('\n DSC \t\t{0:^.3f} \n IOU \t\t{1:^.3f} \n Recall \t{2:^.3f} \n Precision\t{3:^.3f}'.format(
        np.sum(dsc_sc)/num_test,  
        np.sum(iou_sc)/num_test,  
        np.sum(rec_sc)/num_test,
        np.sum(prec_sc)/num_test))
    
# Confusion matrix
confusion = confusion_matrix(Y_test.ravel(),preds_3p.ravel()>thresh)
accuracy = 0
if float(np.sum(confusion))!=0:
    accuracy = float(confusion[0,0]+confusion[1,1])/float(np.sum(confusion))
print(' Global Acc \t{0:^.3f}'.format(accuracy))
    
# Area under the ROC curve
AUC_ROC = roc_auc_score(preds_3p.ravel()>thresh, Y_test.ravel())
print(' AUC ROC \t{0:^.3f}'.format(AUC_ROC))
print('\n')
print('*'*60)
    
# Save outputs 
numepochs = epochsn[-1]
dice_score = np.sum(dsc_sc)/num_test
iou_score = np.sum(iou_sc)/num_test
rec_score = np.sum(rec_sc)/num_test
prec_score = np.sum(prec_sc)/num_test
globacc_score = accuracy
auc_roc_score = AUC_ROC
# Out:
# ------------------------------
# USING THRESHOLD 0.5
#
#  DSC 		0.418
#  IOU 		0.284
#  Recall 	0.407
#  Precision	0.440
#  Global Acc 	0.935
#  AUC ROC 	0.935
#
#
# ************************************************************

# %%
preds_3p_val = model.predict(X_val)
# Evaluate model
num_val = len(X_val)
# Calculate performance metrics
dsc_sc = np.zeros((num_val,1))
iou_sc = np.zeros_like(dsc_sc)
rec_sc = np.zeros_like(dsc_sc)
tn_sc = np.zeros_like(dsc_sc)
prec_sc = np.zeros_like(dsc_sc)
thresh = 0.5
for i in range(num_val):
    dsc_sc[i], iou_sc[i], rec_sc[i], prec_sc[i] = auc(Y_val[i], preds_3p_val[i] >thresh)
print('-'*30)
print('USING THRESHOLD', thresh)
print('\n DSC \t\t{0:^.3f} \n IOU \t\t{1:^.3f} \n Recall \t{2:^.3f} \n Precision\t{3:^.3f}'.format(
        np.sum(dsc_sc)/num_val,  
        np.sum(iou_sc)/num_val,  
        np.sum(rec_sc)/num_val,
        np.sum(prec_sc)/num_val))
    
# Confusion matrix
confusion = confusion_matrix(Y_val.ravel(),preds_3p_val.ravel()>thresh)
accuracy = 0
if float(np.sum(confusion))!=0:
    accuracy = float(confusion[0,0]+confusion[1,1])/float(np.sum(confusion))
print(' Global Acc \t{0:^.3f}'.format(accuracy))
    
# Area under the ROC curve
AUC_ROC = roc_auc_score(preds_3p_val.ravel()>thresh, Y_val.ravel())
print(' AUC ROC \t{0:^.3f}'.format(AUC_ROC))
print('\n')
print('*'*60)
    
# Save outputs 
numepochs = epochsn[-1]
dice_score = np.sum(dsc_sc)/num_val
iou_score = np.sum(iou_sc)/num_val
rec_score = np.sum(rec_sc)/num_val
prec_score = np.sum(prec_sc)/num_val
globacc_score = accuracy
auc_roc_score = AUC_ROC
# Out:
# 1/1 [==============================] - 3s 3s/step
# ------------------------------
# USING THRESHOLD 0.5
#
#  DSC 		0.440
#  IOU 		0.303
#  Recall 	0.427
#  Precision	0.460
#  Global Acc 	0.944
#  AUC ROC 	0.948
#
#
# ************************************************************

# %% [markdown]
# # Representación de las mascaras

# %%
# To plot a set of images with predicted masks uncomment these lines
j = 0
import random
n1 = random.randint(0,len(X_test)-1)
n2 = random.randint(0,len(X_test)-1)
n3 = random.randint(0,len(X_test)-1)
n4 = random.randint(0,len(X_test)-1)
n5 = random.randint(0,len(X_test)-1)
n6 = random.randint(0,len(X_test)-1)
n7 = random.randint(0,len(X_test)-1)
n8 = random.randint(0,len(X_test)-1)
n9 = random.randint(0,len(X_test)-1)
n10 = random.randint(0,len(X_test)-1)

num_disp = [n1,n2,n3,n4,n5,n6,n7,n8,n9,n10]
j=1
plt.figure(figsize = (20,35))
for i in num_disp:
    plt.subplot(10,7,j)
    plt.imshow(np.squeeze(X_test[i]), cmap='gray')
    plt.title('Image')
    j +=1
    plt.subplot(10,7,j)
    plt.imshow(np.squeeze(Y_test[i]),cmap='gray')
    plt.title('Mask')
    j +=1
    plt.subplot(10,7,j)
    plt.imshow(np.squeeze(preds_UNET[i]),cmap='gray')
    plt.title('UNET')
    j +=1
    plt.subplot(10,7,j)
    plt.imshow(np.squeeze(preds_Dense[i]),cmap='gray')
    plt.title('UNET Dense')
    j +=1
    plt.subplot(10,7,j)
    plt.imshow(np.squeeze(preds_Att[i]),cmap='gray')
    plt.title('UNET Attended')
    j +=1
    plt.subplot(10,7,j)
    plt.imshow(np.squeeze(preds_DA[i]),cmap='gray')
    plt.title('UNET Dense + Att')
    j +=1
    plt.subplot(10,7,j)
    plt.imshow(np.squeeze(preds_3p[i]),cmap='gray')
    plt.title('UNET 3+')
    j +=1
    

plt.savefig('Masks.png')
plt.show()
